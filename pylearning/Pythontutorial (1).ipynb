# %%
print("hello world")

# %% [markdown]
# # first notebook

# %% [markdown]
# #variables in python

# %%
x = 22

print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = 'am good'

# %%
type(y)
# Out:
# str

# %%
x,y,z = 'vanilla', 'mint', 'hello'

print(x)
print(y)
print(z)
# Out:
# vanilla
# mint
# hello

# %% [markdown]
# # list

# %%
ice_cream = ['chocolate','Vanilla', 'Rocky road']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# chocolate
# Vanilla
# Rocky road

# %%
# the best way to write a varioable
# 1 by using underscore infront or between the words

ice_cream = 'Vanilla'
_icecream = 'Vanilla'
_ice_cream = 'Vanilla'


#the wrong ways to write variables
# 1 beginning variables with numbers

_icecream = 'vanilla'

# %% [markdown]
# # python data types

# %%
#numeric data types
#1 integers = this are whole numbers both positive and negative

type(-12+44)
# Out:
# int

# %%
#2 float = this are numerics that have decimal places 

type(10.5)
type(12+12.6)
# Out:
# float

# %%
#3 complex = this are numerical data with letters in them that are like imaginary numbers
#  J is the only letter that is used in complex (if you use anyother letter you will get an error)

type(12+5j)
# Out:
# complex

# %%
# Boolean 
# this are only used to produce either a true or false results

type(True)
type(False)

#example use case

type(1 > 5)
# Out:
# bool

# %%
1 > 5
# Out:
# False

# %%
# strings
# when assigning strings to a variable you should use Quatation marks

y = 'hae, eveyone'
type(y)
# Out:
# str

# %%
#when using strings there are use of single quatation and double quatation which are used to do the same task

x = 'life is good'
x = "life is good"

# %%
#triple quatations are used when you want to write a large amount of text like a poem or paragraph

multiline = """
The ice cream vanquished
my longing for sweets,
upon this diet i look away,
it no longer exists on this day
"""

# %%
print(multiline)
# Out:
# The ice cream vanquished
# my longing for sweets,
# upon this diet i look away,
# it no longer exists on this day

# %%
type(multiline)
# Out:
# str

# %%
a= 'hello world'
print(a[:5])
# Out:
# hello

# %% [markdown]
# # list

# %%
#list
#stores multuiple values list are stored in brackets[]
# list are positioned just as strings and a position 0 we have 1

[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['BMW','Mercedes','Bently','Ferrari','Maybach']
# Out:
# ['BMW', 'Mercedes', 'Bently', 'Ferrari', 'Maybach']

# %%
#to add a value to a list you use (.append) this adds to the furthest part

cars = ['BMW','Mercedes','Bently','Ferrari','Maybach']
cars.append('Buggati')
cars
# Out:
# ['BMW', 'Mercedes', 'Bently', 'Ferrari', 'Maybach', 'Buggati']

# %%
# to delete elements in a list you use (.pop)- this is used to remove a value by its index
#also the (remove) function can be used and in that you provide the value to be removed from the list

#(.pop)
numbers = [1,2,3,4,5,6,7,88,9]
numbers.pop(0)
# Out:
# 1

# %%
print(numbers)
# Out:
# [2, 3, 4, 5, 6, 7, 88, 9]

# %%
#(.remove)

bill = [99,87,65,44,33,23,54]
bill.remove(44)
print(bill)
# Out:
# [99, 87, 65, 33, 23, 54]

# %%
#changing things in a list
cars[0]= 'Tesla'
cars
# Out:
# ['Tesla', 'Mercedes', 'Bently', 'Ferrari', 'Maybach', 'Buggati']

# %%
#nested list = this is a list within a list
nest_list = ['Vanilla',3,['Scoops','spoon'], True, 'Good']
nest_list[2]
# Out:
# ['Scoops', 'spoon']

# %% [markdown]
# # tuple

# %%
#tuples -can not be modified or changed after it has been created
#tuples are created using open parenthesis
#tuples are used when the data in them are not expected to change

good_day = (1,2,3,4,5,6)
type(good_day)
# Out:
# tuple

# %%
for bum in good_day:
    print(bum)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# # set

# %%
#sets
#values within a set cannot be accessed using index because its unordered

daily_stoic={1,2,3,4}
type(daily_stoic)
# Out:
# set

# %%
#sets do not hold duplicate values
#used when one wants to avoid duplicates


daily_pint = {1,2,3}

# %%
type(daily_pint)
# Out:
# set

# %%
print(daily_pint)
# Out:
# {1, 2, 3}

# %%
good_day = {1,2,3,5,7,8,77,2,3,7,4,5,6}  #you can see that during the print sets do not print duplicate values
print(good_day)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 77}

# %%
#sets can be used to compare values between different sets

daily_log = {1,2,31,2,3,4,1,2,5,6,3,2}
wife_daily_log = {1,3,5,7,3,24,5,7,3,2,0}

# %%
#when you want to find unique values from both daily_log and wife_daily_log

print(daily_log | wife_daily_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 24, 31}

# %%
#when you want to find value that are present in both daily_log and wife_daily_log

print(daily_log & wife_daily_log)
# Out:
# {1, 2, 3, 5}

# %%
#when you want to know the values that are not present in both daily_log and wife_daily_log

print(daily_log - wife_daily_log)
# Out:
# {4, 6, 31}

# %% [markdown]
# # dictionaries

# %%
#dictionaries
#has a key/value pair

dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
dict_cream.values()
# Out:
# dict_values(['Brian Michael', 5, ['Bently', 'Buggati', 'Mercedes']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite car'])

# %%
#dictionaries are called by the key

dict_cream['name']
# Out:
# 'Brian Michael'

# %%
#you can also update the values within a dictionary

dict_cream['name'] = 'Bimax Motors'

print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'weekly intake': 5, 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
#you can also update the whole dictionary the one we did before was on updating a single value

dict_cream.update({'name': 'Bimax Motors', 'production cost': 'five million', 'favourite car': ['Genim F12', 'Coldera01', 'Feyup']})

print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'weekly intake': 5, 'favourite car': ['Genim F12', 'Coldera01', 'Feyup'], 'production cost': 'five million'}

# %%
# to delete a value from the dictionary use del before the variable

del dict_cream['weekly intake']
print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'favourite car': ['Genim F12', 'Coldera01', 'Feyup'], 'production cost': 'five million'}

# %% [markdown]
# # comparison,logical and membership operators in python

# %%
#this contains mathematical operators

# equal to (==)

10 == 10
# Out:
# True

# %%
#not equal to (!=)

10 != 40
# Out:
# True

# %%
'Vanilla' == 'Vanilla'
# Out:
# True

# %%
x = 'Brian'
y = 'Michael'

x != y
# Out:
# True

# %%
# less than (<)

10 < 40
# Out:
# True

# %% [markdown]
# # logical operators

# %%
#logical operators often compined with logical operators

#And -----returns True if both statements are true
#Or ------Returns True if one of the statements is true
#Not -----Reverse the result, returns False if the statement is true

# %%
(10 > 50) and (50 < 40)
# Out:
# False

# %%
(70 > 30) and (10 < 30)
# Out:
# True

# %%
(10 > 60) or (0.5 <20)
# Out:
# True

# %%
not(50 > 10)
# Out:
# False

# %% [markdown]
# # membership operators

# %%
#used to check if a value or string is within another value or sequence


#In -------Returns True if a sequence with the specified value is present in the object
#Not in -----Returns True if a sequence with the specified value is not present in the object

# %%
brian_michael = 'i love cars soo much my guy'
'guy' in brian_michael #its like we are looking for the word guy in 'i love cars soo much my guy'
# Out:
# True

# %%
'guy' in 'i love cars soo much my guy'
# Out:
# True

# %%
_muranga = [1,2,3,34,4,4,5]

67 not in _muranga
# Out:
# True

# %% [markdown]
# # If  -  Elif  -  Else  statements

# %%
x = 25000000
if x == 25000000:
    print('am rich!')
# Out:
# am rich!

# %%
x = 25000000
if x > 25000000:
    print('am rich!')
else:
    print('work harder bro!')
# Out:
# work harder bro!

# %%
x = 25000000
if x > 25000000:
    print('am rich!')
elif x < 50000000:
    print('good job to me!')
else:
    print('work harder bro!')
# Out:
# good job to me!

# %%
#onother way to write if else statement

print('it worked!') if 10 > 30 else print('it did not work ....')
# Out:
# it did not work ....

# %%
#nested if statement

# %% [markdown]
# # for loops

# %%
#used to do something repeatedly until untill a condition is met

# %%
# Syntax  =  For var_name in sequence:                          for the var_name choose something meaningful
                #statement(s)

puke = ['jenny','Ram', 'Rahul', 'Pagal']


for names in puke:
    print(names)
# Out:
# jenny
# Ram
# Rahul
# Pagal

# %%
# for loops for dictonaries

dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}

# %%
for bull in dict_cream.values():    #to print values
    print(bull)
# Out:
# Brian Michael
# 5
# ['Bently', 'Buggati', 'Mercedes']

# %%
for pig in dict_cream.keys():      #to print keys
    print(pig)
# Out:
# name
# weekly intake
# favourite car

# %%
for keys,value in dict_cream.items():   # to print out both keys and values
    print(keys,'->',value)
# Out:
# name -> Brian Michael
# weekly intake -> 5
# favourite car -> ['Bently', 'Buggati', 'Mercedes']

# %%
#nested for loop

# %%
flavors = ['Vanilla', 'Chocolate', 'Cookie Dough']
toppings = ['Hot Fudge', 'Oreos', 'Marshmallo']

# %%
for one in flavors:
    for two in toppings:
        print(one, 'topped with', two)
# Out:
# Vanilla topped with Hot Fudge
# Vanilla topped with Oreos
# Vanilla topped with Marshmallo
# Chocolate topped with Hot Fudge
# Chocolate topped with Oreos
# Chocolate topped with Marshmallo
# Cookie Dough topped with Hot Fudge
# Cookie Dough topped with Oreos
# Cookie Dough topped with Marshmallo

# %% [markdown]
# # while loops

# %%
num = 0

while num < 5:
    print(num)
    num = num + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# breaking while loop  --- you use break to break out of a loop even if the statement is true


num = 0

while num < 7:
    print(num)
    if num == 4:
        break
    num = num + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#else statement in a while loop

num = 0
while num < 5:
    print(num)
    if num == 7:
        break
    num = num+1
else:
    print('no longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# no longer < 5

# %%
# this will lead to a infinate loop

num = 0
while num < 5:
    print(num)
    if num == 3:
        continue
    num = num+1
else:
    print('no longer < 5')

# %%
# 3 won't be printed out

num = 0
while num < 5:
    num = num+1
    if num == 3:
        continue
    print(num)
else:
    print('no longer < 5')

# %% [markdown]
# # functions

# %%
#they are only run when called
#example

def first_function():
    print('i finaly did it!')

# %%
#calling the function above
first_function()

# %%
#aguments in functions

def num_cool(number):
    print(number**2)

# %%
#calling the function

num_cool(6)   # 6 is the agument passed to the function

# %%
#passing more than one argument

def num_pass(number,power):
    print(number**power)

# %%
num_pass(5,2)

# %%
#abatury arguments   used when you are not sure about the number of arguments you want to pass

def num_arg(*number):
    print(number[0]*number[1])

# %%
num_arg(6,5,7,8,9)

# %%
#another example of how you can write the code above

tu_ple = (6,5,7,8,9)

def num_apt(*number):
    print(number[0]*number[1])

# %%
num_apt(*tu_ple)

# %%
#keyword Arguments   =  you define the values of the arguments

def num_one(power,number):
    print(number**power)

# %%
num_one(number = 3, power = 5)

# %%
#arbitary keyword argument
#in the arbitary argument we have one star here we are going to have two of them

def bri_an(**number):
    print('My number is: ' + number['brim'])

# %%
bri_an(brim = '356')

# %%
# when dealing with more than one

def muk_on(**arg):
    print('My number is: ' + arg['brim'] + ' My other number is: ' + arg['trim'])

# %%
muk_on(brim = '356', trim = '987')

# %% [markdown]
# # converting data types

# %%
#converting integer and strings

# %%
num_int = 9
type(num_int)

# %%
num_str = '8'
type(num_str)

# %%
# when converting string to integer

str_con = int(num_str)

# %%
type(str_con)

# %%
#converting lists, sets and tuples

# %%
#converting list to tuple

list_type = [1,2,3,4,5,6]
type(list_type)

# %%
tuple(list_type)

# %%
type(tuple(list_type))

# %%
#converting a list into a set
#when converting a list into a set only the unique data will be selected because set eliminates duplicates

list_type = [1,2,3,4,3,4,2,3,9,78,5,4,5,2,1,0,4,6]
set(list_type)

# %%
type(set(list_type))

# %%
#converting dictionaries
dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}
type(dict_cream)

# %%
dict_cream.items()

# %%
dict_cream.values()

# %%
dict_cream.keys()

# %%
#converting keys to a list
list(dict_cream.keys())

# %%
type(list(dict_cream.keys()))

# %%
#converting long strings into a list

puma = 'i love getting things done the right way'
list(puma)

# %%
type(list(puma))

# %% [markdown]
# # BMI calculator (body mass index)

# %% [markdown]
# #BMI Calculator reference
# https://mercer-health.com/services/weight-management-center/bmi-calculator#:~:text=Body%20Mass%20Index%2C%20or%20BMI,inches%20x%20height%20in%20inches

# %%
# BMI = (weight in kilogram) / (height in meters x height in meters)

#Under 18.5	Underweight	Minimal
#18.5 - 24.9	Normal Weight	Minimal
#25 - 29.9	Overweight	Increased
#30 - 34.9	Obese	High
#35 - 39.9	Severely Obese	Very High
#40 and over	Morbidly Obese	Extremely High

Name = input('Enter your Name: ')
weight = float(input('Enter your weight in kilograms: '))
height = float(input('Enter your height in meters: '))
BMI = (weight) / (height**2)
print(BMI)


if BMI < 18.5:
    print(Name + ', You are underweight')
elif BMI <= 24.9:
    print(Name + ', You have a normal weight')
elif BMI <= 29.9:
    print(Name + ', You are overweight')
elif BMI <= 34.9:
    print(Name + ', You are Obese')
elif BMI <= 39.9:
    print(Name + ', You are Severly Obese')
else:
    print(Name + ', You are Morbidly Obese')

# %% [markdown]
# # Automatic file sorter in File explorer

# %%
# the OS module       (that is what i should learn before doing this project)

# %% [markdown]
# # Key data structrures for data science

# %% [markdown]
# # string functions
#
# # 1.lower and Upper

# %%
#used to change strings to lower case or upper case

scum = 'Everything you see around you'
scum.upper()

# %%
Town = 'WHERE THERE ARE MANY OPPOTUNITIES TO MAKE MONEY'
Town.lower()

# %% [markdown]
# # 2. Strip

# %%
#used to get rid of white space and even new lines in a string

sing = '  everything is cool\n'
print(sing)

# %%
sing.strip()

# %%
#also used to get rid of other values within a string

make = '*****2345*****'
print(make)

# %%
make.strip('*')

# %% [markdown]
# # 3. split

# %%
#used to return a list of words in a long string

lop = 'let us all play with the new guy'
lop.split(' ')

# %% [markdown]
# # 4.string formatting

# %%
#uses the format function   ---- used to add some words to a string

statement = 'we love {} {}'
statement.format('data','stealing')
print(statement.format('data','stealing'))

# %% [markdown]
# # Numpy

# %% [markdown]
# ## numpy array

# %%
#numpy can be used to store a bunch of data in multidimensional array (1,2,3)
#numpy is used because it tends to be faster than using list

# %% [markdown]
# ## application of Numpy
#
# Mathematics(MATLAB Replacement),
# Plotting (Matplotlib),
# It is Backend of (Pandas, Connect 4, Digital Photography),
# Machine Learning

# %%
import numpy as np

# %% [markdown]
# ### Basics

# %%
#how to initialise an array

a = np.array([1,2,3])          # this is a one dimensional array
print(a)

# %%
b = np.array([[9.0,8.2,7.5,1.0],[5.3,8.0,9.0,1.2]])     # this is a two dimensional array of data type floats
print(b)

# %%
# how to get the dimension of your array
a.ndim

# %%
b.ndim

# %%
# to get the shape 
a.shape

# %%
b.shape     #(2,4) = says two rows and four columns

# %%
# to get type
b.dtype

# %%
# to get size
b.itemsize

# %% [markdown]
# ## Accessing/ changing specific elements, rows, columns e.t.c

# %%
a = np.array([[8,6,5,3,8,9,1],[7,5,3,1,9,5,3]])
print(a)

# %%
a.shape

# %%
# geting a specific element  [row,column] (first row and column are 0)
# lets get 7

a[1,0]

# %%
# to get an entire row
a[0, :]

# %%
# to get a specific column
a[:, 4]

# %%
a[0, 1:6]

# %%
# changing elements (lets change 7 to 13)
a[1,0]=13
print(a)

# %% [markdown]
# * 3D example

# %%
b = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(b)

# %%
b.size

# %%
b.ndim

# %%
# getting specuific element

b[0,0,1]

# %% [markdown]
# ## Initializing Different types of Arrays

# %%
# All zeros(0s) matrix  (return a new array of a given shape and type, filled with zeros)

np.zeros((2,3))

# %%
np.zeros((4,4,2))

# %%
# All ones(1s) matrix (returns a new array filled with 1s)

np.ones((2,3,4))

# %%
# Any other number matrix   (you specify the shape and also the values)

np.full((3,2,2), 22)     #(22 is the value to be filled that i have specified)

# %%
# Any other number (np.full_like)  (enables us to take a shape that has already been build)
a = np.array([[8,6,5,3,8,9,1],[7,5,3,1,9,5,3]])
a

# %%
np.full_like(a, 3)

# %%
#Random decimal numbers(random.rand)

np.random.rand(3,2)

# %%
#Random integer values(np.random.randint)
# 2 --- is the position argument

np.random.randint(9,size=(4,3))

# %%
#The identity matrix (its always a square so it requires one agument)

np.identity(4)

# %%
# Repeat a array (i have used in in a two dimensional array)

arr = np.array([[5,4,3,2]])
r1 = np.repeat(arr,3, axis=0)
print(r1)

# %%
arg = np.array([[5,6,7,8],[9,7,8,5]])
print(arg)

# %%
output = np.ones((5,5))
print(output)

z = np.zeros((3,3))
z[1,1]=9
print(z)
output[1:4,1:4] = z
print(output)

# %% [markdown]
# ### when copying contents of another variable

# %%
# when you want to copy the contents of another variable you need to use the (.copy())
#the example below

a = np.array([1,2,3,4])
b = a
b[0] =1000
b
a

# %%
# when copying to use it diferrently

a = np.array([5,4,6,8])
b = a.copy()
b[0]= 100
b
a

# %% [markdown]
# ## Mathematics using numpy

# %%
a = np.array([1,2,3,4])
a

# %%
#addition
# this adds it to all the values within the array

a+2

# %%
#subtraction(also subtracts everything from the array)

a - 4

# %%
#multiplication
a * 4

# %%
#division
a / 2

# %%
b = np.array([3,4,5,8])
a + b

# %%
np.sin(a)

# %%
np.cos(a)

# %% [markdown]
# #### Numpy mathematical Documentation
# ####  For a lot more (https://docs.scipy.org/doc/numpy/reference/routines.math.html)

# %%
a = np .array([7,4,7,9,7,5])
a

# %%
a * 10

# %%
a

# %%
a += 10
a

# %%
a

# %%
a = np.arange(9)
a

# %%
a <= 3

# %%
a > 6

# %%
a.mean()

# %% [markdown]
# ### Linear Algebra

# %%
# Linear Algebra is the one of the most important part in machine learning

a = np.ones((2,3))
print(a)

b = np.full((3,2), 2)
print(b)

np.matmul(a,b)

# %%
### DO MORE ABOUT LINEAR ALGEBRA AND NUMPY THAT WILL ALSO BE USED IN MACHINE LEARNING

# %% [markdown]
# ### Statistics

# %%
## Mean, mediun, Max, min

doo = np.array([[5,4,6,7],[8,7,9,6]])
doo

# %%
np.min(doo)

# %%
np.sum(doo)

# %% [markdown]
# ## Reorganizing Arrays

# %%
# This is used to mainly change the shapes of arrays(Use the .reshape)

hell = np.array([[5,6,8,9,2],[7,9,4,6,2]])
print(hell)

hello = hell.reshape((5,2))
print(hello)

# %%
# Vertically stacking vectors

v1 = np.array([1,2,3,4])
v2 = np.array([5,6,7,8])

np.vstack([v1,v2])
np.vstack([v1,v2,v2,v1])

# %%
# horizontal stack

h1 = np.ones((2,4))
h2 = np.zeros((2,2))

np.hstack((h1,h2))

# %% [markdown]
# ## Miscellaneous
# ### Load Data from file

# %%
np.genfromcsv('Excel project')

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Importing Data into Jupyter notebook

# %%
# To import data you have to give the route that the data is supossed to follow use the (pd.read_csv)(csv is a file name)

df = pd.read_csv('desktop/pandas/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
# to get to know the number of column and rows in your data (use the .shape attribute)

df.shape
# Out:
# (73268, 79)

# %% [markdown]
# ## Data types in pandas in our dataset
# #### Object means string
# #### Int64 is integer that stored in a 64 bit
# #### and float

# %%
#To get more information about the data you are using use (.info())
#This gives you the columns and the data types that you are using

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %%
# To view all the columns in our dataset (.set_option('display.max_columns',_number of columns_))

df = pd.read_csv('desktop/pandas/survey_results_public.csv')
pd.set_option('display.max_columns', 79)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
# i want to put a schema file that we have that have matching questions to the dataset that we have
# so we will load in the schema file

schema_df = pd.read_csv('desktop/pandas/survey_results_schema.csv')
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# ..        ...   ...      ...
# 74        NaN    MC     MAVR
# 75        NaN    MC     MAVR
# 76        NaN    MC     MAVR
# 77        NaN    MC     MAVR
# 78        NaN    MC     MAVR
#
# [79 rows x 6 columns]

# %%
# to view all rows of your dataset(pd.set_option('display.max_rows'_number of rows_))

pd.set_option('display.max_rows', 79)
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# ..        ...   ...      ...
# 74        NaN    MC     MAVR
# 75        NaN    MC     MAVR
# 76        NaN    MC     MAVR
# 77        NaN    MC     MAVR
# 78        NaN    MC     MAVR
#
# [79 rows x 6 columns]

# %%
# when you want to just see a certain amount of data(.head()) this for viewing the first 10 items

schema_df.head(10)
# Out:
#       qid             qname  \
# 0   QID16                S0
# 1   QID12          MetaInfo
# 2    QID1                S1
# 3    QID2        MainBranch
# 4  QID296        Employment
# 5  QID308        RemoteWork
# 6  QID297  CodingActivities
# 7  QID190                S2
# 8   QID25           EdLevel
# 9  QID276         LearnCode
#
#                                             question force_resp  type selector
# 0  <div><span style="font-size:19px;"><strong>Hel...      False    DB       TB
# 1                                  Browser Meta Info      False  Meta  Browser
# 2  <span style="font-size:22px; font-family: aria...      False    DB       TB
# 3  Which of the following options best describes ...       True    MC     SAVR
# 4  Which of the following best describes your cur...      False    MC     MAVR
# 5  Which best describes your current work situation?      False    MC     SAVR
# 6  Which of the following best describes the code...      False    MC     MAVR
# 7  <span style="font-size:22px; font-family: aria...      False    DB       TB
# 8  Which of the following best describes the high...      False    MC     SAVR
# 9  How did you learn to code? Select all that apply.      False    MC     MAVR

# %%
#viewing the last 10(.tail())
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# 73260             Employed, full-time;Student, part-time
# 73261                                Employed, full-time
# 73262             Student, full-time;Employed, part-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73258  Hybrid (some remote, some in-person)
# 73259  Hybrid (some remote, some in-person)
# 73260  Hybrid (some remote, some in-person)
# 73261  Hybrid (some remote, some in-person)
# 73262  Hybrid (some remote, some in-person)
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73258                                              Hobby
# 73259                            Other (please specify):
# 73260                            School or academic work
# 73261                                              Hobby
# 73262                            School or academic work
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73259    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73260       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73262  Secondary school (e.g. American high school, G...
# 73263       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73258  Other online resources (e.g., videos, blogs, f...
# 73259  Books / Physical media;Other online resources ...
# 73260            School (i.e., University, College, etc)
# 73261  Books / Physical media;Other online resources ...
# 73262  Other online resources (e.g., videos, blogs, f...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73258  Stack Overflow;Video-based Online Courses;Onli...
# 73259  Technical documentation;Blogs;Written Tutorial...
# 73260                                                NaN
# 73261  Technical documentation;Blogs;Programming Game...
# 73262  Technical documentation;Written Tutorials;Stac...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 73258                    Coursera;Udemy         5            1
# 73259                               NaN         6            2
# 73260                               NaN         8          NaN
# 73261      Udemy;Codecademy;Pluralsight         9            2
# 73262                               NaN         4          NaN
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 73258                                Developer, back-end
# 73259                                Developer, back-end
# 73260                        Developer, back-end;Student
# 73261                              Developer, full-stack
# 73262                       Developer, front-end;Student
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                         OrgSize                 PurchaseInfluence  \
# 73258      100 to 499 employees             I have some influence
# 73259        10 to 19 employees     I have little or no influence
# 73260                       NaN                               NaN
# 73261  10,000 or more employees     I have little or no influence
# 73262                       NaN                               NaN
# 73263      100 to 499 employees             I have some influence
# 73264              I don’t know     I have little or no influence
# 73265        20 to 99 employees  I have a great deal of influence
# 73266        10 to 19 employees  I have a great deal of influence
# 73267                       NaN                               NaN
#
#                                               BuyNewTool  \
# 73258  Start a free trial;Ask developers I know/work ...
# 73259  Start a free trial;Ask developers I know/work ...
# 73260  Visit developer communities like Stack Overflo...
# 73261  Start a free trial;Visit developer communities...
# 73262                                                NaN
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 73258                                              India
# 73259                                             Poland
# 73260                                            Belgium
# 73261                                             France
# 73262                                            Germany
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 73258          INR\tIndian rupee  3200000.0   Yearly
# 73259          PLN\tPolish zloty     8000.0  Monthly
# 73260                        NaN        NaN      NaN
# 73261          EUR European Euro    36000.0   Yearly
# 73262                        NaN        NaN      NaN
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 73258                                        Go;Java;SQL
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73262                     Assembly;C;C++;Java;TypeScript
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 73258                              JavaScript;TypeScript
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# 73262                                           C++;Java
# 73263     Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                         HTML/CSS;JavaScript;Python
# 73265              C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                             Delphi
# 73267                         PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 73258                                      MongoDB;MySQL
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                                              MySQL
# 73262                                                NaN
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 73258                                        MySQL;Redis
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                  Elasticsearch;MongoDB;MySQL;Redis
# 73262                                                NaN
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 73258                                     AWS
# 73259                              AWS;Heroku
# 73260                         Microsoft Azure
# 73261                         Microsoft Azure
# 73262                                     NaN
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 73258                                       Google Cloud
# 73259                                                AWS
# 73260                                    Microsoft Azure
# 73261                                    Microsoft Azure
# 73262                                                NaN
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 73258                                           NaN
# 73259                                jQuery;Phoenix
# 73260                         ASP.NET;ASP.NET Core
# 73261             Angular;Angular.js;Drupal;Node.js
# 73262                                       Node.js
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 73258                                                NaN
# 73259                                            Phoenix
# 73260                               ASP.NET Core ;Blazor
# 73261                                    Angular;Node.js
# 73262                                                NaN
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 73258                                Apache Kafka;Spring
# 73259                                       React Native
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 73258                                                NaN
# 73259                                                NaN
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 73258          Docker;Homebrew;Kubernetes;npm
# 73259                       Docker;Kubernetes
# 73260                                  Docker
# 73261                              Docker;npm
# 73262                                     npm
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                                  ToolsTechWantToWorkWith  \
# 73258                                         Kubernetes
# 73259                                  Docker;Kubernetes
# 73260                                  Docker;Kubernetes
# 73261  Ansible;Chef;Docker;Kubernetes;npm;Terraform;Yarn
# 73262                                                NaN
# 73263                     Docker;Homebrew;Kubernetes;npm
# 73264                                                NaN
# 73265                                  npm;Unreal Engine
# 73266                                                NaN
# 73267             Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 73258              Eclipse;GoLand;Vim;Visual Studio Code
# 73259                                 Visual Studio Code
# 73260                   Visual Studio;Visual Studio Code
# 73261               Eclipse;Notepad++;Visual Studio Code
# 73262                         Eclipse;Visual Studio Code
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith  \
# 73258                   GoLand;Vim;Visual Studio Code
# 73259                              Visual Studio Code
# 73260                Visual Studio;Visual Studio Code
# 73261                     IntelliJ;Visual Studio Code
# 73262               Android Studio;Visual Studio Code
# 73263             Sublime Text;Vim;Visual Studio Code
# 73264         Notepad++;Spyder;Vim;Visual Studio Code
# 73265         Spyder;Visual Studio;Visual Studio Code
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                       Neovim;Visual Studio Code
#
#                                    OpSysProfessional use  \
# 73258                                              macOS
# 73259                                              macOS
# 73260                                            Windows
# 73261  Linux-based;Windows;Windows Subsystem for Linu...
# 73262                                                NaN
# 73263                                              macOS
# 73264                                Linux-based;Windows
# 73265                                            Windows
# 73266                                            Windows
# 73267                                Linux-based;Windows
#
#                                OpSysPersonal use VersionControlSystem  \
# 73258                        Linux-based;Windows                  Git
# 73259  Windows;Windows Subsystem for Linux (WSL)                  Git
# 73260                                    Windows                  Git
# 73261  Windows;Windows Subsystem for Linux (WSL)                  Git
# 73262                        Linux-based;Windows                  Git
# 73263                          Linux-based;macOS                  Git
# 73264                        Linux-based;Windows                  Git
# 73265                                    Windows                  Git
# 73266                                    Windows                  SVN
# 73267                        Linux-based;Windows                  Git
#
#                                            VCInteraction  \
# 73258                                       Command-line
# 73259                           Code editor;Command-line
# 73260  Code editor;Command-line;Version control hosti...
# 73261  Code editor;Command-line;Version control hosti...
# 73262                                       Command-line
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 73258                    NaN                        NaN
# 73259                    NaN                        NaN
# 73260                    NaN                        NaN
# 73261                    NaN                        NaN
# 73262                    NaN                        NaN
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 73258                                        Notion
# 73259                  ClickUp;Jira Work Management
# 73260                                        Notion
# 73261                          Jira Work Management
# 73262                                        Notion
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 73258                            NaN                    Slack;Zoom
# 73259           Jira Work Management         Microsoft Teams;Slack
# 73260                        ClickUp          Microsoft Teams;Zoom
# 73261                            NaN               Microsoft Teams
# 73262                         Notion                    Slack;Zoom
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 73258                           NaN    Very favorable
# 73259                         Slack            Unsure
# 73260               Microsoft Teams       Unfavorable
# 73261               Microsoft Teams       Unfavorable
# 73262                           NaN            Unsure
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 73258                      Stack Overflow;Stack Exchange
# 73259                                     Stack Overflow
# 73260                                     Stack Overflow
# 73261                                     Stack Overflow
# 73262                                     Stack Overflow
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 73258   Daily or almost daily                      Yes
# 73259    A few times per week                      Yes
# 73260   Daily or almost daily                      Yes
# 73261   Daily or almost daily                      Yes
# 73262    A few times per week                      Yes
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 73258                Less than once per month or monthly    Yes, somewhat
# 73259  I have never participated in Q&A on Stack Over...   No, not at all
# 73260                Less than once per month or monthly    Yes, somewhat
# 73261  I have never participated in Q&A on Stack Over...   No, not really
# 73262                Less than once per month or monthly   No, not really
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 73258  18-24 years old    Man    No  Straight / Heterosexual
# 73259  25-34 years old    Man    No  Straight / Heterosexual
# 73260  18-24 years old    Man    No  Straight / Heterosexual
# 73261  18-24 years old    Man    No                      NaN
# 73262  18-24 years old    Man    No  Straight / Heterosexual
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 73258                   Asian                NaN
# 73259          White;European  None of the above
# 73260                European  None of the above
# 73261                European  None of the above
# 73262                European  None of the above
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 73258                                  None of the above     Yes
# 73259                                  None of the above     Yes
# 73260  I have a concentration and/or memory disorder ...     Yes
# 73261                                  None of the above     Yes
# 73262  I have a mood or emotional disorder (e.g., dep...     NaN
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp                 Knowledge_1  \
# 73258  Independent contributor      1.0              Strongly agree
# 73259  Independent contributor      2.0                       Agree
# 73260  Independent contributor      3.0  Neither agree nor disagree
# 73261  Independent contributor      2.0                       Agree
# 73262                      NaN      NaN                         NaN
# 73263  Independent contributor      5.0                       Agree
# 73264  Independent contributor      6.0                       Agree
# 73265  Independent contributor     42.0                    Disagree
# 73266                      NaN      NaN                         NaN
# 73267                      NaN      NaN                         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 73258                    Disagree              Strongly agree           Agree
# 73259                    Disagree                       Agree  Strongly agree
# 73260                       Agree                       Agree           Agree
# 73261                       Agree                       Agree           Agree
# 73262                         NaN                         NaN             NaN
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#                       Knowledge_5                 Knowledge_6  \
# 73258  Neither agree nor disagree                       Agree
# 73259              Strongly agree  Neither agree nor disagree
# 73260  Neither agree nor disagree                       Agree
# 73261                       Agree  Neither agree nor disagree
# 73262                         NaN                         NaN
# 73263              Strongly agree              Strongly agree
# 73264                    Disagree                       Agree
# 73265                       Agree                       Agree
# 73266                         NaN                         NaN
# 73267                         NaN                         NaN
#
#                       Knowledge_7       Frequency_1        Frequency_2  \
# 73258                       Agree  1-2 times a week   10+ times a week
# 73259              Strongly agree             Never   1-2 times a week
# 73260              Strongly agree             Never   1-2 times a week
# 73261                    Disagree  1-2 times a week   3-5 times a week
# 73262                         NaN               NaN                NaN
# 73263  Neither agree nor disagree             Never              Never
# 73264                       Agree  1-2 times a week  6-10 times a week
# 73265  Neither agree nor disagree             Never              Never
# 73266                         NaN               NaN                NaN
# 73267                         NaN               NaN                NaN
#
#             Frequency_3        TimeSearching               TimeAnswering  \
# 73258             Never  15-30 minutes a day         15-30 minutes a day
# 73259               NaN  15-30 minutes a day  Less than 15 minutes a day
# 73260  1-2 times a week  15-30 minutes a day         30-60 minutes a day
# 73261  1-2 times a week  15-30 minutes a day         15-30 minutes a day
# 73262               NaN                  NaN                         NaN
# 73263             Never  30-60 minutes a day  Less than 15 minutes a day
# 73264  10+ times a week  15-30 minutes a day        60-120 minutes a day
# 73265             Never  30-60 minutes a day        60-120 minutes a day
# 73266               NaN                  NaN                         NaN
# 73267               NaN                  NaN                         NaN
#
#            Onboarding                                   ProfessionalTech  \
# 73258      Just right  DevOps function;Microservices;Developer portal...
# 73259  Somewhat short  DevOps function;Continuous integration (CI) an...
# 73260       Very long  DevOps function;Developer portal or other cent...
# 73261   Somewhat long  Innersource initiative;DevOps function;Microse...
# 73262             NaN                                                NaN
# 73263      Just right  DevOps function;Microservices;Developer portal...
# 73264       Very long                                      None of these
# 73265      Just right                                      None of these
# 73266             NaN                                                NaN
# 73267             NaN                                                NaN
#
#       TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 73258         Yes         Yes         Yes               Too long
# 73259         Yes         Yes         Yes  Appropriate in length
# 73260          No          No         Yes  Appropriate in length
# 73261         Yes         Yes         Yes  Appropriate in length
# 73262         NaN         NaN         NaN  Appropriate in length
# 73263         Yes         Yes         Yes               Too long
# 73264          No         Yes         Yes               Too long
# 73265          No          No          No  Appropriate in length
# 73266         NaN         NaN         NaN  Appropriate in length
# 73267         NaN         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 73258  Neither easy nor difficult                  NaN
# 73259  Neither easy nor difficult                  NaN
# 73260                        Easy                  NaN
# 73261                        Easy                  NaN
# 73262  Neither easy nor difficult                  NaN
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN

# %% [markdown]
# # dataframe and series data type

# %% [markdown]
# ### dataframes

# %%
# dataframe is madeup of multiple rows and also multiple columns ()
# Dataframes are like storing data in python Dictionaries 

#example of data stored in a python dictionary

dict_cream = {'name': ['Brian Michael','Owen Kelly', 'Candy Pange'], 'weekly intake': [5,6,9], 'favourite car':['Bently','Buggati','Mercedes']}
print(dict_cream)
# Out:
# {'name': ['Brian Michael', 'Owen Kelly', 'Candy Pange'], 'weekly intake': [5, 6, 9], 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
# Example of the same data stored using dataframes in pandas

cp = pd.DataFrame(dict_cream)
cp
# Out:
#             name  weekly intake favourite car
# 0  Brian Michael              5        Bently
# 1     Owen Kelly              6       Buggati
# 2    Candy Pange              9      Mercedes

# %%
cp['name']
# Out:
# 0    Brian Michael
# 1       Owen Kelly
# 2      Candy Pange
# Name: name, dtype: object

# %% [markdown]
# ## Series

# %%
# This is a list of Data . Its rows of data
# Dataframe is rows and columns while a series is just rows

# %%
# Data in one row is called is series
cp.name
# Out:
# 0    Brian Michael
# 1       Owen Kelly
# 2      Candy Pange
# Name: name, dtype: object

# %%
#accessing multiple columns using dataframe

cp[['name', 'weekly intake']]
# Out:
#             name  weekly intake
# 0  Brian Michael              5
# 1     Owen Kelly              6
# 2    Candy Pange              9

# %%
# Accessing rows use (loc) and (iloc) iloc means index location
# when using (iloc) you search by integer location while in (loc) you search by label

cp.iloc[[0,1]]
# Out:
#             name  weekly intake favourite car
# 0  Brian Michael              5        Bently
# 1     Owen Kelly              6       Buggati

# %%
# to select just a specific column in defferent row

cp.iloc[[0,2], 2]
# Out:
# 0      Bently
# 2    Mercedes
# Name: favourite car, dtype: object

# %%
cp.loc[0]
# Out:
# name             Brian Michael
# weekly intake                5
# favourite car           Bently
# Name: 0, dtype: object

# %%
cp.loc[[0,1,2], 'favourite car']
# Out:
# 0      Bently
# 1     Buggati
# 2    Mercedes
# Name: favourite car, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
df.shape
# Out:
# (73268, 79)

# %%
su=df['RemoteWork']
su.loc[0:50]
# Out:
# 0                                      NaN
# 1                             Fully remote
# 2     Hybrid (some remote, some in-person)
# 3                             Fully remote
# 4     Hybrid (some remote, some in-person)
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8     Hybrid (some remote, some in-person)
# 9                             Fully remote
# 10    Hybrid (some remote, some in-person)
# 11                            Fully remote
# 12    Hybrid (some remote, some in-person)
# 13                            Fully remote
# 14                            Fully remote
# 15                            Fully remote
# 16    Hybrid (some remote, some in-person)
# 17                            Fully remote
# 18    Hybrid (some remote, some in-person)
# 19                                     NaN
# 20    Hybrid (some remote, some in-person)
# 21    Hybrid (some remote, some in-person)
# 22                            Fully remote
# 23    Hybrid (some remote, some in-person)
# 24                            Fully remote
# 25    Hybrid (some remote, some in-person)
# 26    Hybrid (some remote, some in-person)
# 27                                     NaN
# 28    Hybrid (some remote, some in-person)
# 29                            Fully remote
# 30                                     NaN
# 31                            Fully remote
# 32                          Full in-person
# 33                          Full in-person
# 34                            Fully remote
# 35                                     NaN
# 36                            Fully remote
# 37                            Fully remote
# 38                                     NaN
# 39    Hybrid (some remote, some in-person)
# 40    Hybrid (some remote, some in-person)
# 41    Hybrid (some remote, some in-person)
# 42                                     NaN
# 43                          Full in-person
# 44                                     NaN
# 45    Hybrid (some remote, some in-person)
# 46                                     NaN
# 47                            Fully remote
# 48    Hybrid (some remote, some in-person)
# 49                            Fully remote
# 50                          Full in-person
# Name: RemoteWork, dtype: object

# %%
# Counts values in a column(.value_counts())

df['RemoteWork'].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64

# %%
df.loc[0 : 1000, 'CompTotal' : 'LanguageHaveWorkedWith']
# Out:
#       CompTotal CompFreq                             LanguageHaveWorkedWith
# 0           NaN      NaN                                                NaN
# 1           NaN      NaN                              JavaScript;TypeScript
# 2       32000.0   Yearly                  C#;C++;HTML/CSS;JavaScript;Python
# 3       60000.0  Monthly                       C#;JavaScript;SQL;TypeScript
# 4           NaN      NaN        C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...         ...      ...                                                ...
# 996         NaN      NaN  Bash/Shell;C;Elixir;JavaScript;Rust;SQL;TypeSc...
# 997    181000.0   Yearly     Bash/Shell;C#;JavaScript;PowerShell;Python;SQL
# 998    145000.0   Yearly                                           Java;PHP
# 999         NaN      NaN                                     C#;Dart;Python
# 1000  1200000.0  Monthly  C;C#;C++;HTML/CSS;JavaScript;PowerShell;Rust;T...
#
# [1001 rows x 3 columns]

# %% [markdown]
# ## Indexes - How to set, Reset and use indexes

# %%
# Indexes are the numbering that are automatically given to data at the far left side
# we will first use a small amount of dataframe as an example

dict_cream = {'name': ['Brian Michael','Owen Kelly', 'Candy Pange'], 'weekly intake': [5,6,9],'Email':['bri01@gmail.com','owen66@gmail.com','pang02@gmail.com'] ,'favourite car':['Bently','Buggati','Mercedes']}
print(dict_cream)
# Out:
# {'name': ['Brian Michael', 'Owen Kelly', 'Candy Pange'], 'weekly intake': [5, 6, 9], 'Email': ['bri01@gmail.com', 'owen66@gmail.com', 'pang02@gmail.com'], 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
poo = pd.DataFrame(dict_cream)
poo
# Out:
#             name  weekly intake             Email favourite car
# 0  Brian Michael              5   bri01@gmail.com        Bently
# 1     Owen Kelly              6  owen66@gmail.com       Buggati
# 2    Candy Pange              9  pang02@gmail.com      Mercedes

# %%
# Indexes is what identifies each and every data within our data
# So lets set Email as our indexes because its unique on each and every person
#use(.set_index)


poo.set_index('Email')
# Out:
#                            name  weekly intake favourite car
# Email
# bri01@gmail.com   Brian Michael              5        Bently
# owen66@gmail.com     Owen Kelly              6       Buggati
# pang02@gmail.com    Candy Pange              9      Mercedes

# %%
poo
# Out:
#             name  weekly intake             Email favourite car
# 0  Brian Michael              5   bri01@gmail.com        Bently
# 1     Owen Kelly              6  owen66@gmail.com       Buggati
# 2    Candy Pange              9  pang02@gmail.com      Mercedes

# %%
# To make the indexing permarnent use (.set_index('name of column', inplace=True))

poo.set_index('Email', inplace=True)
poo
# Out:
#                            name  weekly intake favourite car
# Email
# bri01@gmail.com   Brian Michael              5        Bently
# owen66@gmail.com     Owen Kelly              6       Buggati
# pang02@gmail.com    Candy Pange              9      Mercedes

# %%
poo.index
# Out:
# Index(['bri01@gmail.com', 'owen66@gmail.com', 'pang02@gmail.com'], dtype='object', name='Email')

# %%
# use can use the email indexes to obtain data about a specific person

poo.loc['owen66@gmail.com']
# Out:
# name             Owen Kelly
# weekly intake             6
# favourite car       Buggati
# Name: owen66@gmail.com, dtype: object

# %%
# How to reset the indexes (.reset_index(inplace=True))

poo.reset_index(inplace=True)
poo
# Out:
#    index             Email           name  weekly intake favourite car
# 0      0   bri01@gmail.com  Brian Michael              5        Bently
# 1      1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2      2  pang02@gmail.com    Candy Pange              9      Mercedes

# %%
df = pd.read_csv('desktop/pandas/survey_results_public.csv')
schema_df = pd.read_csv('desktop/pandas/survey_results_schema.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# ..        ...   ...      ...
# 74        NaN    MC     MAVR
# 75        NaN    MC     MAVR
# 76        NaN    MC     MAVR
# 77        NaN    MC     MAVR
# 78        NaN    MC     MAVR
#
# [79 rows x 6 columns]

# %%
pd.set_option('display.max_column', 79)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
df.loc[0 : 70, 'Country' : 'LanguageHaveWorkedWith']
# Out:
#                                               Country  \
# 0                                                 NaN
# 1                                              Canada
# 2   United Kingdom of Great Britain and Northern I...
# 3                                              Israel
# 4                            United States of America
# 5                                             Germany
# 6                                               India
# 7                                               India
# 8                                         Netherlands
# 9                                             Croatia
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
# 12                           United States of America
# 13                                          Australia
# 14                           United States of America
# 15                                 Russian Federation
# 16                                     Czech Republic
# 17                                            Austria
# 18                                            Austria
# 19                                             Serbia
# 20                                            Austria
# 21                                              Italy
# 22                                             Canada
# 23                                        Netherlands
# 24                                             Israel
# 25                                            Germany
# 26                           United States of America
# 27                                             Israel
# 28                           United States of America
# 29                                            Ireland
# 30                                                NaN
# 31                           United States of America
# 32                                             Canada
# 33                                             Israel
# 34                                             Poland
# 35                                             Israel
# 36                                             Canada
# 37                                             Israel
# 38                                           Slovenia
# 39                                     Czech Republic
# 40                           United States of America
# 41                                             Israel
# 42                                               Iraq
# 43                                             Sweden
# 44                                            Austria
# 45                                         Madagascar
# 46                                             Norway
# 47                           United States of America
# 48                                            Germany
# 49                                            Germany
# 50                                     Czech Republic
# 51                                             Poland
# 52                                     Czech Republic
# 53                           United States of America
# 54                                             Norway
# 55                           United States of America
# 56                                             Taiwan
# 57                                        Netherlands
# 58                                 Hong Kong (S.A.R.)
# 59                                            Germany
# 60                                             Canada
# 61                                             Mexico
# 62                                             France
# 63                           United States of America
# 64                                             France
# 65                                              India
# 66                                             Brazil
# 67                                          Australia
# 68                                          Lithuania
# 69                                            Uruguay
# 70                                             Serbia
#
#                      Currency  CompTotal CompFreq  \
# 0                         NaN        NaN      NaN
# 1        CAD\tCanadian dollar        NaN      NaN
# 2         GBP\tPound sterling    32000.0   Yearly
# 3     ILS\tIsraeli new shekel    60000.0  Monthly
# 4   USD\tUnited States dollar        NaN      NaN
# 5                         NaN        NaN      NaN
# 6                         NaN        NaN      NaN
# 7                         NaN        NaN      NaN
# 8           EUR European Euro    46000.0   Yearly
# 9          HRK\tCroatian kuna        NaN      NaN
# 10        GBP\tPound sterling    48000.0   Yearly
# 11  USD\tUnited States dollar   194400.0   Yearly
# 12  USD\tUnited States dollar    65000.0   Yearly
# 13     AUD\tAustralian dollar        NaN      NaN
# 14  USD\tUnited States dollar   110000.0   Yearly
# 15         RUB\tRussian ruble        NaN   Weekly
# 16          CZK\tCzech koruna    37000.0  Monthly
# 17          EUR European Euro   190000.0   Yearly
# 18          EUR European Euro     4000.0  Monthly
# 19                        NaN        NaN      NaN
# 20                        NaN        NaN      NaN
# 21          EUR European Euro    32000.0   Yearly
# 22       CAD\tCanadian dollar   125000.0   Yearly
# 23          EUR European Euro        NaN      NaN
# 24    ILS\tIsraeli new shekel        NaN      NaN
# 25          EUR European Euro    85000.0   Yearly
# 26  USD\tUnited States dollar   106960.0   Yearly
# 27                        NaN        NaN      NaN
# 28  USD\tUnited States dollar   130000.0   Yearly
# 29          EUR European Euro   130000.0  Monthly
# 30                        NaN        NaN      NaN
# 31  USD\tUnited States dollar   102000.0   Yearly
# 32                        NaN        NaN      NaN
# 33                        NaN        NaN      NaN
# 34          PLN\tPolish zloty    30000.0  Monthly
# 35                        NaN        NaN      NaN
# 36       CAD\tCanadian dollar        NaN      NaN
# 37    ILS\tIsraeli new shekel        NaN      NaN
# 38                        NaN        NaN      NaN
# 39          CZK\tCzech koruna        NaN  Monthly
# 40  USD\tUnited States dollar   130000.0   Yearly
# 41    ILS\tIsraeli new shekel    19000.0  Monthly
# 42                        NaN        NaN      NaN
# 43                        NaN        NaN      NaN
# 44                        NaN        NaN      NaN
# 45          EUR European Euro      400.0  Monthly
# 46                        NaN        NaN      NaN
# 47  USD\tUnited States dollar   135000.0   Yearly
# 48          EUR European Euro   100000.0   Yearly
# 49          EUR European Euro     4000.0  Monthly
# 50                        NaN        NaN      NaN
# 51          PLN\tPolish zloty    14000.0  Monthly
# 52                        NaN        NaN      NaN
# 53  USD\tUnited States dollar   170000.0   Yearly
# 54       NOK\tNorwegian krone  1000000.0   Yearly
# 55  USD\tUnited States dollar   141000.0   Yearly
# 56     TWD\tNew Taiwan dollar  1632000.0   Yearly
# 57          EUR European Euro     3650.0  Monthly
# 58      HKD\tHong Kong dollar        NaN  Monthly
# 59          EUR European Euro    60000.0   Yearly
# 60       CAD\tCanadian dollar    85000.0   Yearly
# 61                        NaN        NaN      NaN
# 62          EUR European Euro    70000.0   Yearly
# 63  USD\tUnited States dollar   150000.0   Yearly
# 64                        NaN        NaN      NaN
# 65          INR\tIndian rupee        NaN  Monthly
# 66        BRL\tBrazilian real    10000.0  Monthly
# 67                        NaN        NaN      NaN
# 68                        NaN        NaN      NaN
# 69        UYU\tUruguayan peso   130000.0  Monthly
# 70         RSD\tSerbian dinar        NaN      NaN
#
#                                LanguageHaveWorkedWith
# 0                                                 NaN
# 1                               JavaScript;TypeScript
# 2                   C#;C++;HTML/CSS;JavaScript;Python
# 3                        C#;JavaScript;SQL;TypeScript
# 4         C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                             C++;Lua
# 6       C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 7                  C;C++;HTML/CSS;Java;JavaScript;SQL
# 8                                                 NaN
# 9                                   Delphi;Java;Swift
# 10   Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# 11  C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 12               C;HTML/CSS;Rust;SQL;Swift;TypeScript
# 13  Elixir;Erlang;HTML/CSS;JavaScript;Ruby;SQL;Typ...
# 14        HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 15      Bash/Shell;HTML/CSS;JavaScript;SQL;TypeScript
# 16                               C#;Java;PHP;Python;R
# 17                                         Python;SQL
# 18                                  C#;PowerShell;SQL
# 19                C++;HTML/CSS;Java;JavaScript;Python
# 20  Bash/Shell;C#;HTML/CSS;Java;JavaScript;PowerSh...
# 21                              Python;SQL;TypeScript
# 22                                  C#;SQL;TypeScript
# 23                                                VBA
# 24                   C#;C++;JavaScript;PHP;TypeScript
# 25               Dart;Go;Java;Kotlin;Swift;TypeScript
# 26     Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;SQL
# 27             C#;HTML/CSS;JavaScript;Rust;TypeScript
# 28                                              C;C++
# 29                       C#;JavaScript;PowerShell;SQL
# 30                                                NaN
# 31                         C#;HTML/CSS;JavaScript;SQL
# 32                                         C++;Python
# 33                                      C++;Go;Python
# 34          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 35                                      MATLAB;Python
# 36  C#;C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL
# 37                HTML/CSS;JavaScript;PHP;Python;Ruby
# 38                     HTML/CSS;JavaScript;Python;SQL
# 39  Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Per...
# 40      C#;C++;HTML/CSS;JavaScript;SQL;TypeScript;VBA
# 41                     Bash/Shell;HTML/CSS;Python;SQL
# 42                C#;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 43                                                NaN
# 44  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# 45                              JavaScript;TypeScript
# 46                   Bash/Shell;C;C++;Java;Lua;Python
# 47                 Java;JavaScript;PHP;SQL;TypeScript
# 48                                  Haskell;Java;Rust
# 49              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 50                            Bash/Shell;Julia;Python
# 51  Bash/Shell;HTML/CSS;Java;JavaScript;Python;Rus...
# 52                          Bash/Shell;Go;Java;Python
# 53              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 54  Bash/Shell;C#;HTML/CSS;Java;JavaScript;LISP;Po...
# 55  C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 56                                                C++
# 57   Bash/Shell;C#;HTML/CSS;PowerShell;SQL;TypeScript
# 58                   Dart;HTML/CSS;Java;Kotlin;Python
# 59  Assembly;Bash/Shell;C;HTML/CSS;JavaScript;PHP;...
# 60  Bash/Shell;C#;C++;HTML/CSS;Java;JavaScript;Kot...
# 61                         Bash/Shell;HTML/CSS;Python
# 62                                 Groovy;Java;Kotlin
# 63  Bash/Shell;C;Go;HTML/CSS;Java;JavaScript;Pytho...
# 64                C;C#;HTML/CSS;Java;JavaScript;PHP;R
# 65                                                 C#
# 66              C;C++;Delphi;HTML/CSS;Java;JavaScript
# 67                     C#;HTML/CSS;JavaScript;PHP;SQL
# 68  C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;...
# 69  Bash/Shell;HTML/CSS;Java;JavaScript;SQL;TypeSc...
# 70                                    Java;Kotlin;PHP

# %%
# how to set a column as the index when you are loading in the data (, index_col = 'name of the column')

df = pd.read_csv('desktop/pandas/survey_results_public.csv', index_col = 'Employment')
df.head()
# Out:
#                      ResponseId  \
# Employment
# NaN                           1
# Employed, full-time           2
# Employed, full-time           3
# Employed, full-time           4
# Employed, full-time           5
#
#                                                             MainBranch  \
# Employment
# NaN                                                      None of these
# Employed, full-time                     I am a developer by profession
# Employed, full-time  I am not primarily a developer, but I write co...
# Employed, full-time                     I am a developer by profession
# Employed, full-time                     I am a developer by profession
#
#                                                RemoteWork  \
# Employment
# NaN                                                   NaN
# Employed, full-time                          Fully remote
# Employed, full-time  Hybrid (some remote, some in-person)
# Employed, full-time                          Fully remote
# Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# Employment
# NaN                                                       NaN
# Employed, full-time  Hobby;Contribute to open-source projects
# Employed, full-time                                     Hobby
# Employed, full-time              I don’t code outside of work
# Employed, full-time                                     Hobby
#
#                                                              EdLevel  \
# Employment
# NaN                                                              NaN
# Employed, full-time                                              NaN
# Employed, full-time  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employed, full-time     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employed, full-time     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                              LearnCode  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time  Books / Physical media;Friend or family member...
# Employed, full-time  Books / Physical media;School (i.e., Universit...
# Employed, full-time  Other online resources (e.g., videos, blogs, f...
#
#                                                        LearnCodeOnline  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time  Technical documentation;Blogs;Programming Game...
# Employed, full-time                                                NaN
# Employed, full-time  Technical documentation;Blogs;Stack Overflow;O...
#
#                     LearnCodeCoursesCert YearsCode YearsCodePro  \
# Employment
# NaN                                  NaN       NaN          NaN
# Employed, full-time                  NaN       NaN          NaN
# Employed, full-time                  NaN        14            5
# Employed, full-time                  NaN        20           17
# Employed, full-time                  NaN         8            3
#
#                                                                DevType  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time  Data scientist or machine learning specialist;...
# Employed, full-time                              Developer, full-stack
# Employed, full-time  Developer, front-end;Developer, full-stack;Dev...
#
#                                   OrgSize      PurchaseInfluence  \
# Employment
# NaN                                   NaN                    NaN
# Employed, full-time                   NaN                    NaN
# Employed, full-time    20 to 99 employees  I have some influence
# Employed, full-time  100 to 499 employees  I have some influence
# Employed, full-time    20 to 99 employees  I have some influence
#
#                                                             BuyNewTool  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time                            Other (please specify):
# Employed, full-time  Start a free trial;Visit developer communities...
#
#                                                                Country  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                             Canada
# Employed, full-time  United Kingdom of Great Britain and Northern I...
# Employed, full-time                                             Israel
# Employed, full-time                           United States of America
#
#                                       Currency  CompTotal CompFreq  \
# Employment
# NaN                                        NaN        NaN      NaN
# Employed, full-time       CAD\tCanadian dollar        NaN      NaN
# Employed, full-time        GBP\tPound sterling    32000.0   Yearly
# Employed, full-time    ILS\tIsraeli new shekel    60000.0  Monthly
# Employed, full-time  USD\tUnited States dollar        NaN      NaN
#
#                                           LanguageHaveWorkedWith  \
# Employment
# NaN                                                          NaN
# Employed, full-time                        JavaScript;TypeScript
# Employed, full-time            C#;C++;HTML/CSS;JavaScript;Python
# Employed, full-time                 C#;JavaScript;SQL;TypeScript
# Employed, full-time  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                                          LanguageWantToWorkWith  \
# Employment
# NaN                                                         NaN
# Employed, full-time                             Rust;TypeScript
# Employed, full-time       C#;C++;HTML/CSS;JavaScript;TypeScript
# Employed, full-time                           C#;SQL;TypeScript
# Employed, full-time  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                                                 DatabaseHaveWorkedWith  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time                               Microsoft SQL Server
# Employed, full-time                               Microsoft SQL Server
# Employed, full-time  Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                                                 DatabaseWantToWorkWith  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time                               Microsoft SQL Server
# Employed, full-time                               Microsoft SQL Server
# Employed, full-time  Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#                        PlatformHaveWorkedWith    PlatformWantToWorkWith  \
# Employment
# NaN                                       NaN                       NaN
# Employed, full-time                       NaN                       NaN
# Employed, full-time                       NaN                       NaN
# Employed, full-time                       NaN                       NaN
# Employed, full-time  Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                                            WebframeHaveWorkedWith  \
# Employment
# NaN                                                           NaN
# Employed, full-time                                           NaN
# Employed, full-time                                    Angular.js
# Employed, full-time                         ASP.NET;ASP.NET Core
# Employed, full-time  Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                                    WebframeWantToWorkWith  \
# Employment
# NaN                                                   NaN
# Employed, full-time                                   NaN
# Employed, full-time                    Angular;Angular.js
# Employed, full-time                 ASP.NET;ASP.NET Core
# Employed, full-time  Angular;ASP.NET Core ;Blazor;Node.js
#
#                     MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# Employment
# NaN                                    NaN                    NaN
# Employed, full-time                    NaN                    NaN
# Employed, full-time                 Pandas                   .NET
# Employed, full-time                   .NET                   .NET
# Employed, full-time                   .NET      .NET;Apache Kafka
#
#                     ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# Employment
# NaN                                     NaN                     NaN
# Employed, full-time                     NaN                     NaN
# Employed, full-time                     NaN                     NaN
# Employed, full-time                     NaN                     NaN
# Employed, full-time                     npm       Docker;Kubernetes
#
#                                          NEWCollabToolsHaveWorkedWith  \
# Employment
# NaN                                                               NaN
# Employed, full-time                                               NaN
# Employed, full-time                           Notepad++;Visual Studio
# Employed, full-time        Notepad++;Visual Studio;Visual Studio Code
# Employed, full-time  Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                                    NEWCollabToolsWantToWorkWith  \
# Employment
# NaN                                                         NaN
# Employed, full-time                                         NaN
# Employed, full-time                     Notepad++;Visual Studio
# Employed, full-time  Notepad++;Visual Studio;Visual Studio Code
# Employed, full-time      Rider;Visual Studio;Visual Studio Code
#
#                     OpSysProfessional use                  OpSysPersonal use  \
# Employment
# NaN                                   NaN                                NaN
# Employed, full-time                 macOS  Windows Subsystem for Linux (WSL)
# Employed, full-time               Windows                            Windows
# Employed, full-time               Windows                            Windows
# Employed, full-time               Windows                      macOS;Windows
#
#                             VersionControlSystem  \
# Employment
# NaN                                          NaN
# Employed, full-time                          Git
# Employed, full-time                          Git
# Employed, full-time                          Git
# Employed, full-time  Git;Other (please specify):
#
#                                                          VCInteraction  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time                                        Code editor
# Employed, full-time  Code editor;Command-line;Version control hosti...
# Employed, full-time                                        Code editor
#
#                      VCHostingPersonal use  VCHostingProfessional use  \
# Employment
# NaN                                    NaN                        NaN
# Employed, full-time                    NaN                        NaN
# Employed, full-time                    NaN                        NaN
# Employed, full-time                    NaN                        NaN
# Employed, full-time                    NaN                        NaN
#
#                     OfficeStackAsyncHaveWorkedWith  \
# Employment
# NaN                                            NaN
# Employed, full-time                            NaN
# Employed, full-time                            NaN
# Employed, full-time    Jira Work Management;Trello
# Employed, full-time                            NaN
#
#                     OfficeStackAsyncWantToWorkWith  \
# Employment
# NaN                                            NaN
# Employed, full-time                            NaN
# Employed, full-time                            NaN
# Employed, full-time    Jira Work Management;Trello
# Employed, full-time                            NaN
#
#                     OfficeStackSyncHaveWorkedWith  \
# Employment
# NaN                                           NaN
# Employed, full-time                           NaN
# Employed, full-time               Microsoft Teams
# Employed, full-time                    Slack;Zoom
# Employed, full-time          Microsoft Teams;Zoom
#
#                     OfficeStackSyncWantToWorkWith        Blockchain  \
# Employment
# NaN                                           NaN               NaN
# Employed, full-time                           NaN  Very unfavorable
# Employed, full-time               Microsoft Teams  Very unfavorable
# Employed, full-time                    Slack;Zoom  Very unfavorable
# Employed, full-time                           NaN       Unfavorable
#
#                                                             NEWSOSites  \
# Employment
# NaN                                                                NaN
# Employed, full-time  Collectives on Stack Overflow;Stack Overflow f...
# Employed, full-time  Collectives on Stack Overflow;Stack Overflow;S...
# Employed, full-time  Collectives on Stack Overflow;Stack Overflow f...
# Employed, full-time  Collectives on Stack Overflow;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount              SOPartFreq  \
# Employment
# NaN                                     NaN       NaN                     NaN
# Employed, full-time   Daily or almost daily       Yes   Daily or almost daily
# Employed, full-time  Multiple times per day       Yes  Multiple times per day
# Employed, full-time   Daily or almost daily       Yes    A few times per week
# Employed, full-time  Multiple times per day       Yes   Daily or almost daily
#
#                               SOComm              Age Gender Trans  \
# Employment
# NaN                              NaN              NaN    NaN   NaN
# Employed, full-time         Not sure              NaN    NaN   NaN
# Employed, full-time          Neutral  25-34 years old    Man    No
# Employed, full-time  Yes, definitely  35-44 years old    Man    No
# Employed, full-time  Yes, definitely  25-34 years old    NaN   NaN
#
#                                    Sexuality Ethnicity      Accessibility  \
# Employment
# NaN                                      NaN       NaN                NaN
# Employed, full-time                      NaN       NaN                NaN
# Employed, full-time                 Bisexual     White  None of the above
# Employed, full-time  Straight / Heterosexual     White  None of the above
# Employed, full-time                      NaN       NaN                NaN
#
#                                                           MentalHealth  \
# Employment
# NaN                                                                NaN
# Employed, full-time                                                NaN
# Employed, full-time  I have a mood or emotional disorder (e.g., dep...
# Employed, full-time                                  None of the above
# Employed, full-time                                                NaN
#
#                     TBranch ICorPM  WorkExp Knowledge_1 Knowledge_2  \
# Employment
# NaN                     NaN    NaN      NaN         NaN         NaN
# Employed, full-time      No    NaN      NaN         NaN         NaN
# Employed, full-time      No    NaN      NaN         NaN         NaN
# Employed, full-time      No    NaN      NaN         NaN         NaN
# Employed, full-time      No    NaN      NaN         NaN         NaN
#
#                     Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6  \
# Employment
# NaN                         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
#
#                     Knowledge_7 Frequency_1 Frequency_2 Frequency_3  \
# Employment
# NaN                         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN         NaN
#
#                     TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# Employment
# NaN                           NaN           NaN        NaN              NaN
# Employed, full-time           NaN           NaN        NaN              NaN
# Employed, full-time           NaN           NaN        NaN              NaN
# Employed, full-time           NaN           NaN        NaN              NaN
# Employed, full-time           NaN           NaN        NaN              NaN
#
#                     TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# Employment
# NaN                         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN
# Employed, full-time         NaN         NaN         NaN
#
#                               SurveyLength                  SurveyEase  \
# Employment
# NaN                                    NaN                         NaN
# Employed, full-time               Too long                   Difficult
# Employed, full-time  Appropriate in length  Neither easy nor difficult
# Employed, full-time  Appropriate in length                        Easy
# Employed, full-time               Too long                        Easy
#
#                      ConvertedCompYearly
# Employment
# NaN                                  NaN
# Employed, full-time                  NaN
# Employed, full-time              40205.0
# Employed, full-time             215232.0
# Employed, full-time                  NaN

# %%
df['NEWCollabToolsWantToWorkWith'].value_counts()
# Out:
# Visual Studio Code                                                                                   8815
# Visual Studio;Visual Studio Code                                                                     2907
# Vim;Visual Studio Code                                                                               1794
# Notepad++;Visual Studio;Visual Studio Code                                                           1519
# IntelliJ;Visual Studio Code                                                                          1360
#                                                                                                      ...
# CLion;IPython/Jupyter;PyCharm;Visual Studio;Webstorm                                                    1
# Android Studio;Atom;Eclipse;IntelliJ;NetBeans;PyCharm;Qt Creator;Visual Studio;Visual Studio Code       1
# Eclipse;Notepad++;PyCharm;Qt Creator;Visual Studio;Visual Studio Code                                   1
# IntelliJ;IPython/Jupyter;PyCharm;RStudio;Spyder;Sublime Text;Vim                                        1
# Android Studio;GoLand;IntelliJ;Nano;PyCharm;Visual Studio Code;Webstorm                                 1
# Name: NEWCollabToolsWantToWorkWith, Length: 9188, dtype: int64

# %%
df['OpSysProfessional use'].value_counts()
# Out:
# Windows                                                                                    16645
# macOS                                                                                      12541
# Linux-based                                                                                10934
# Linux-based;Windows                                                                         5637
# Linux-based;macOS                                                                           4906
# Windows;Windows Subsystem for Linux (WSL)                                                   3800
# Linux-based;Windows;Windows Subsystem for Linux (WSL)                                       3003
# macOS;Windows                                                                               2327
# Linux-based;macOS;Windows                                                                   1551
# Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)                                  897
# Linux-based;Windows Subsystem for Linux (WSL)                                                712
# Windows Subsystem for Linux (WSL)                                                            586
# macOS;Windows;Windows Subsystem for Linux (WSL)                                              557
# macOS;Windows Subsystem for Linux (WSL)                                                      219
# Linux-based;macOS;Windows Subsystem for Linux (WSL)                                          206
# BSD;Linux-based                                                                              113
# BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)                              102
# BSD;Linux-based;macOS                                                                         92
# BSD                                                                                           85
# BSD;Linux-based;Windows                                                                       67
# BSD;Linux-based;macOS;Windows                                                                 55
# Linux-based;Other (please specify):                                                           52
# BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL)                                     51
# Other (please specify):                                                                       46
# Windows;Other (please specify):                                                               42
# Linux-based;Windows;Other (please specify):                                                   35
# BSD;macOS                                                                                     35
# BSD;Windows                                                                                   33
# BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):       18
# Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):                 17
# BSD;Windows;Windows Subsystem for Linux (WSL)                                                 15
# BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL)                                       15
# BSD;Linux-based;Windows Subsystem for Linux (WSL)                                             13
# Linux-based;macOS;Windows;Other (please specify):                                             11
# BSD;Windows Subsystem for Linux (WSL)                                                         10
# Windows;Windows Subsystem for Linux (WSL);Other (please specify):                              8
# BSD;Linux-based;Other (please specify):                                                        8
# Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):            7
# Linux-based;macOS;Other (please specify):                                                      7
# macOS;Other (please specify):                                                                  7
# macOS;Windows;Other (please specify):                                                          6
# BSD;macOS;Windows                                                                              6
# BSD;macOS;Windows;Windows Subsystem for Linux (WSL)                                            5
# Linux-based;Windows Subsystem for Linux (WSL);Other (please specify):                          3
# BSD;Linux-based;Windows;Other (please specify):                                                3
# BSD;Linux-based;macOS;Windows;Other (please specify):                                          3
# BSD;Other (please specify):                                                                    2
# Windows Subsystem for Linux (WSL);Other (please specify):                                      2
# BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):              2
# Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):                    1
# BSD;macOS;Windows Subsystem for Linux (WSL)                                                    1
# macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):                        1
# BSD;Linux-based;macOS;Other (please specify):                                                  1
# BSD;Windows;Other (please specify):                                                            1
# BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):                1
# Name: OpSysProfessional use, dtype: int64

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                                              1250
# Python                                                                                       962
# HTML/CSS;JavaScript                                                                          914
# HTML/CSS;JavaScript;PHP;SQL                                                                  745
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                                        570
#                                                                                             ...
# C#;Java;JavaScript;PHP;PowerShell;SQL;TypeScript                                               1
# C++;HTML/CSS;JavaScript;Python;Solidity;SQL                                                    1
# Dart;Haskell;HTML/CSS;Java;R;SQL;TypeScript                                                    1
# Bash/Shell;C;C#;Go;HTML/CSS;Java;JavaScript;Lua;Perl;PHP;Python;Ruby;Rust;SQL;TypeScript       1
# C#;JavaScript;Lua;PowerShell;SQL;TypeScript                                                    1
# Name: LanguageHaveWorkedWith, Length: 25068, dtype: int64

# %%
df['WebframeHaveWorkedWith'].value_counts()
# Out:
# React.js                                                                 1959
# Node.js                                                                  1507
# jQuery                                                                   1445
# Node.js;React.js                                                         1303
# Flask                                                                    1258
#                                                                          ...
# ASP.NET;Deno;Django;Express;Flask;jQuery;Node.js;React.js                   1
# ASP.NET;Drupal;Express;FastAPI;jQuery;Laravel;Node.js;React.js;Vue.js       1
# ASP.NET Core ;Blazor;Django;Express;Node.js;React.js                        1
# Django;Drupal;Flask;jQuery;Laravel;Node.js;React.js;Ruby on Rails           1
# Angular.js;Express;jQuery;Next.js;Node.js;Play Framework;React.js           1
# Name: WebframeHaveWorkedWith, Length: 8259, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming       18
# Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming           15
# Or, in your own words:;Non-binary, genderqueer, or gender non-conforming                 14
# Or, in your own words:;Woman                                                             13
# Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming              9
# Man;Or, in your own words:;Woman                                                          2
# Name: Gender, dtype: int64

# %%
# To sort indexes alphabetically use (.sort_index)

df.sort_index()
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %% [markdown]
# ## Filtering  - using conditionals to fiolter Rows and columns

# %%
poo
# Out:
#    index             Email           name  weekly intake favourite car
# 0      0   bri01@gmail.com  Brian Michael              5        Bently
# 1      1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2      2  pang02@gmail.com    Candy Pange              9      Mercedes

# %%
# Filtering the data by the country in which respondents are located

dus =(df['Country'] == 'South Africa')
df.loc[dus]
# Out:
#        ResponseId                                         MainBranch  \
# 100           101                        I code primarily as a hobby
# 342           343                     I am a developer by profession
# 624           625                     I am a developer by profession
# 1034         1035                     I am a developer by profession
# 1073         1074                     I am a developer by profession
# ...           ...                                                ...
# 71940       71941                     I am a developer by profession
# 71952       71953                     I am a developer by profession
# 72001       72002  I am not primarily a developer, but I write co...
# 72255       72256                     I am a developer by profession
# 72706       72707  I am not primarily a developer, but I write co...
#
#                                               Employment  \
# 100                                   Student, full-time
# 342                                  Employed, full-time
# 624    Employed, full-time;Independent contractor, fr...
# 1034   Employed, full-time;Independent contractor, fr...
# 1073                                 Employed, full-time
# ...                                                  ...
# 71940                                Employed, full-time
# 71952  Student, full-time;Not employed, but looking f...
# 72001                                Employed, full-time
# 72255                                Employed, full-time
# 72706                                Employed, full-time
#
#                                  RemoteWork  \
# 100                                     NaN
# 342                            Fully remote
# 624                            Fully remote
# 1034                           Fully remote
# 1073                           Fully remote
# ...                                     ...
# 71940  Hybrid (some remote, some in-person)
# 71952                          Fully remote
# 72001  Hybrid (some remote, some in-person)
# 72255  Hybrid (some remote, some in-person)
# 72706                          Fully remote
#
#                                        CodingActivities  \
# 100                                                 NaN
# 342                                               Hobby
# 624            Hobby;Contribute to open-source projects
# 1034                     Hobby;Bootstrapping a business
# 1073           Hobby;Contribute to open-source projects
# ...                                                 ...
# 71940                                             Hobby
# 71952  Bootstrapping a business;Freelance/contract work
# 72001                      I don’t code outside of work
# 72255                     Hobby;Freelance/contract work
# 72706                     Hobby;School or academic work
#
#                                                EdLevel  \
# 100                          Primary/elementary school
# 342       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 624       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1034      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1073   Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 71940     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 71952     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72001       Other doctoral degree (Ph.D., Ed.D., etc.)
# 72255     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72706     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 100    Other online resources (e.g., videos, blogs, f...
# 342    Other online resources (e.g., videos, blogs, f...
# 624    Books / Physical media;Other online resources ...
# 1034   Books / Physical media;Other online resources ...
# 1073   Books / Physical media;Friend or family member...
# ...                                                  ...
# 71940  Books / Physical media;Other online resources ...
# 71952  Books / Physical media;Other online resources ...
# 72001  Books / Physical media;Friend or family member...
# 72255  Other online resources (e.g., videos, blogs, f...
# 72706            School (i.e., University, College, etc)
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 100    Blogs;Written Tutorials;Stack Overflow;Video-b...                  NaN
# 342    Technical documentation;Programming Games;Writ...                  NaN
# 624    Technical documentation;Blogs;Written Tutorial...                  NaN
# 1034   Technical documentation;Blogs;Written Tutorial...                  NaN
# 1073   Technical documentation;Written Tutorials;Stac...                  NaN
# ...                                                  ...                  ...
# 71940       Technical documentation;Blogs;Stack Overflow                  NaN
# 71952  Technical documentation;Blogs;Written Tutorial...                Other
# 72001  Technical documentation;Blogs;Stack Overflow;O...                  NaN
# 72255  Technical documentation;Blogs;Programming Game...                  NaN
# 72706                                                NaN                  NaN
#
#       YearsCode YearsCodePro  \
# 100          11          NaN
# 342          30           21
# 624          20           15
# 1034          7            4
# 1073         26            8
# ...         ...          ...
# 71940        25           16
# 71952         7          NaN
# 72001        37           15
# 72255        14           10
# 72706         8            2
#
#                                                  DevType  \
# 100                                                  NaN
# 342                                Developer, full-stack
# 624    Developer, full-stack;Developer, back-end;Bloc...
# 1034   Developer, full-stack;Developer, mobile;Databa...
# 1073   Engineer, data;Developer, full-stack;Engineeri...
# ...                                                  ...
# 71940              Developer, mobile;Engineering manager
# 71952  Developer, front-end;Developer, full-stack;Dev...
# 72001  Data scientist or machine learning specialist;...
# 72255                                Developer, back-end
# 72706      Data scientist or machine learning specialist
#
#                         OrgSize                 PurchaseInfluence  \
# 100                         NaN                               NaN
# 342    5,000 to 9,999 employees     I have little or no influence
# 624        100 to 499 employees     I have little or no influence
# 1034       100 to 499 employees             I have some influence
# 1073         20 to 99 employees  I have a great deal of influence
# ...                         ...                               ...
# 71940      100 to 499 employees  I have a great deal of influence
# 71952                       NaN                               NaN
# 72001  5,000 to 9,999 employees             I have some influence
# 72255          2 to 9 employees     I have little or no influence
# 72706      100 to 499 employees     I have little or no influence
#
#                                               BuyNewTool       Country  \
# 100                                                  NaN  South Africa
# 342    Start a free trial;Visit developer communities...  South Africa
# 624    Start a free trial;Visit developer communities...  South Africa
# 1034   Visit developer communities like Stack Overflo...  South Africa
# 1073   Start a free trial;Ask developers I know/work ...  South Africa
# ...                                                  ...           ...
# 71940  Start a free trial;Visit developer communities...  South Africa
# 71952                                 Start a free trial  South Africa
# 72001  Start a free trial;Visit developer communities...  South Africa
# 72255  Start a free trial;Visit developer communities...  South Africa
# 72706  Start a free trial;Visit developer communities...  South Africa
#
#                         Currency  CompTotal CompFreq  \
# 100                          NaN        NaN      NaN
# 342      ZAR\tSouth African rand   900000.0   Yearly
# 624    USD\tUnited States dollar   115000.0   Yearly
# 1034     ZAR\tSouth African rand   624000.0   Yearly
# 1073     ZAR\tSouth African rand  2600000.0   Yearly
# ...                          ...        ...      ...
# 71940    ZAR\tSouth African rand  1040000.0   Yearly
# 71952                        NaN        NaN      NaN
# 72001    ZAR\tSouth African rand   900000.0   Yearly
# 72255    ZAR\tSouth African rand    88000.0  Monthly
# 72706    ZAR\tSouth African rand    31000.0  Monthly
#
#                                  LanguageHaveWorkedWith  \
# 100                                      APL;C++;Python
# 342         Bash/Shell;HTML/CSS;JavaScript;PHP;Rust;SQL
# 624             C++;HTML/CSS;JavaScript;Rust;TypeScript
# 1034                  Dart;HTML/CSS;Java;JavaScript;SQL
# 1073    Bash/Shell;Clojure;HTML/CSS;Java;JavaScript;SQL
# ...                                                 ...
# 71940  Bash/Shell;C#;Dart;Java;Objective-C;Python;Swift
# 71952                          C#;JavaScript;TypeScript
# 72001                                               SQL
# 72255                                 Clojure;Go;Python
# 72706                                             R;SQL
#
#                                   LanguageWantToWorkWith  \
# 100    APL;Assembly;Bash/Shell;C;C++;Haskell;LISP;Per...
# 342          Bash/Shell;HTML/CSS;JavaScript;PHP;Rust;SQL
# 624                               Elixir;Rust;TypeScript
# 1034        Dart;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 1073                Clojure;HTML/CSS;Java;JavaScript;SQL
# ...                                                  ...
# 71940            Bash/Shell;Dart;Kotlin;Swift;TypeScript
# 71952                                     C++;Rust;Swift
# 72001                            Bash/Shell;Python;R;SQL
# 72255                                       Clojure;Rust
# 72706                                       Python;R;SQL
#
#                                   DatabaseHaveWorkedWith  \
# 100                                                  NaN
# 342                                       MariaDB;Oracle
# 624                              PostgreSQL;Redis;SQLite
# 1034                                  MongoDB;PostgreSQL
# 1073                    Cloud Firestore;MySQL;PostgreSQL
# ...                                                  ...
# 71940                  Firebase Realtime Database;SQLite
# 71952  CouchDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 72001                                                NaN
# 72255                                           DynamoDB
# 72706                        Microsoft SQL Server;SQLite
#
#                              DatabaseWantToWorkWith  \
# 100                                             NaN
# 342                                         MariaDB
# 624                               PostgreSQL;SQLite
# 1034          PostgreSQL;Firebase Realtime Database
# 1073               Cloud Firestore;MySQL;PostgreSQL
# ...                                             ...
# 71940  PostgreSQL;Firebase Realtime Database;SQLite
# 71952                                           NaN
# 72001                                           NaN
# 72255                                         Redis
# 72706                   Microsoft SQL Server;SQLite
#
#           PlatformHaveWorkedWith  \
# 100                          NaN
# 342              Microsoft Azure
# 624                          NaN
# 1034                         AWS
# 1073                Google Cloud
# ...                          ...
# 71940  AWS;Firebase;Google Cloud
# 71952                 AWS;Heroku
# 72001                        NaN
# 72255                        AWS
# 72706                        NaN
#
#                              PlatformWantToWorkWith  \
# 100                                             NaN
# 342                                 Microsoft Azure
# 624                                             NaN
# 1034                                   AWS;Firebase
# 1073                                   Google Cloud
# ...                                             ...
# 71940                                           NaN
# 71952  DigitalOcean;Firebase;Linode;Microsoft Azure
# 72001                                           NaN
# 72255                                           NaN
# 72706                                           NaN
#
#                         WebframeHaveWorkedWith  \
# 100                                        NaN
# 342                      Node.js;Svelte;Vue.js
# 624                                   React.js
# 1034           Next.js;Node.js;React.js;Vue.js
# 1073   Express;Gatsby;Next.js;Node.js;React.js
# ...                                        ...
# 71940                                      NaN
# 71952         Express;Next.js;Node.js;React.js
# 72001                                      NaN
# 72255                                      NaN
# 72706                                      NaN
#
#                  WebframeWantToWorkWith     MiscTechHaveWorkedWith  \
# 100                                 NaN                        NaN
# 342               Node.js;Svelte;Vue.js                        NaN
# 624                             Phoenix                        NaN
# 1034           Next.js;Node.js;React.js                    Flutter
# 1073   Express;Next.js;Node.js;React.js                        NaN
# ...                                 ...                        ...
# 71940                               NaN                    Flutter
# 71952                               NaN      Electron;React Native
# 72001                               NaN                        NaN
# 72255                               NaN  Apache Kafka;NumPy;Pandas
# 72706                               NaN                  Tidyverse
#
#                                   MiscTechWantToWorkWith  \
# 100                                                  NaN
# 342                                                  NaN
# 624                                                  NaN
# 1034                Electron;Flutter;React Native;Spring
# 1073                                                 NaN
# ...                                                  ...
# 71940                                            Flutter
# 71952                                 Flutter;TensorFlow
# 72001                                                NaN
# 72255                                       Apache Kafka
# 72706  Keras;NumPy;Pandas;Scikit-learn;Tidyverse;Tens...
#
#               ToolsTechHaveWorkedWith        ToolsTechWantToWorkWith  \
# 100                               NaN                            NaN
# 342                               npm                            npm
# 624                            Docker                         Docker
# 1034                              npm                     Kubernetes
# 1073   Docker;Homebrew;Kubernetes;npm     Docker;Homebrew;Kubernetes
# ...                               ...                            ...
# 71940                          Docker              Docker;Kubernetes
# 71952               Homebrew;npm;Yarn  Docker;Unity 3D;Unreal Engine
# 72001                             NaN                            NaN
# 72255                 Docker;Homebrew              Docker;Kubernetes
# 72706                             NaN                            NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 100                                      Atom;Neovim;Vim
# 342                IntelliJ;Notepad++;Visual Studio Code
# 624                  Emacs;Neovim;Vim;Visual Studio Code
# 1034          Android Studio;IntelliJ;Visual Studio Code
# 1073               Emacs;Sublime Text;Visual Studio Code
# ...                                                  ...
# 71940        Android Studio;Vim;Visual Studio Code;Xcode
# 71952  Atom;CLion;Emacs;IntelliJ;Neovim;Vim;Visual St...
# 72001                                      Emacs;RStudio
# 72255                                              Emacs
# 72706                         RStudio;Visual Studio Code
#
#                 NEWCollabToolsWantToWorkWith  \
# 100                                   Neovim
# 342    IntelliJ;Notepad++;Visual Studio Code
# 624      Emacs;Neovim;Vim;Visual Studio Code
# 1034             IntelliJ;Visual Studio Code
# 1073   Emacs;Sublime Text;Visual Studio Code
# ...                                      ...
# 71940  Android Studio;Vim;Visual Studio Code
# 71952                   Android Studio;Xcode
# 72001  Emacs;IPython/Jupyter;PyCharm;RStudio
# 72255                                  Emacs
# 72706                IPython/Jupyter;RStudio
#
#                    OpSysProfessional use          OpSysPersonal use  \
# 100                          Linux-based                Linux-based
# 342    Windows Subsystem for Linux (WSL)                    Windows
# 624                    Linux-based;macOS  Linux-based;macOS;Windows
# 1034                       macOS;Windows              macOS;Windows
# 1073                   Linux-based;macOS                      macOS
# ...                                  ...                        ...
# 71940                        Linux-based                Linux-based
# 71952                              macOS                      macOS
# 72001                            Windows              macOS;Windows
# 72255                              macOS                Linux-based
# 72706                            Windows                    Windows
#
#       VersionControlSystem                                      VCInteraction  \
# 100                    Git                                       Command-line
# 342                    Git                           Code editor;Command-line
# 624                    Git                                       Command-line
# 1034                   Git                           Code editor;Command-line
# 1073                   Git                           Code editor;Command-line
# ...                    ...                                                ...
# 71940                  Git  Code editor;Command-line;Version control hosti...
# 71952                  Git                           Code editor;Command-line
# 72001                  Git  Code editor;Dedicated version control GUI appl...
# 72255                  Git                           Code editor;Command-line
# 72706      I don't use one                                                NaN
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 100                      NaN                        NaN
# 342                      NaN                        NaN
# 624                      NaN                        NaN
# 1034                     NaN                        NaN
# 1073                     NaN                        NaN
# ...                      ...                        ...
# 71940                    NaN                        NaN
# 71952                    NaN                        NaN
# 72001                    NaN                        NaN
# 72255                    NaN                        NaN
# 72706                    NaN                        NaN
#
#          OfficeStackAsyncHaveWorkedWith   OfficeStackAsyncWantToWorkWith  \
# 100                                 NaN                              NaN
# 342                                 NaN                              NaN
# 624                               Asana                              NaN
# 1034               Jira Work Management             Jira Work Management
# 1073                      Notion;Trello                           Notion
# ...                                 ...                              ...
# 71940   Stack Overflow for Teams;Trello  Stack Overflow for Teams;Trello
# 71952  ClickUp;monday.com;Notion;Trello                              NaN
# 72001                               NaN                              NaN
# 72255                          Airtable                         Airtable
# 72706                 Microsoft Planner                              NaN
#
#       OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 100                            Zoom                           NaN
# 342                 Microsoft Teams               Microsoft Teams
# 624      Mattermost;Rocketchat;Zoom                           NaN
# 1034          Microsoft Teams;Slack                         Slack
# 1073     Microsoft Teams;Slack;Zoom                         Slack
# ...                             ...                           ...
# 71940    Microsoft Teams;Slack;Zoom                         Slack
# 71952                           NaN                           NaN
# 72001          Microsoft Teams;Zoom                          Zoom
# 72255        Google Chat;Slack;Zoom                           NaN
# 72706               Microsoft Teams               Microsoft Teams
#
#              Blockchain                                         NEWSOSites  \
# 100           Favorable                      Stack Overflow;Stack Exchange
# 342    Very unfavorable                      Stack Overflow;Stack Exchange
# 624      Very favorable                      Stack Overflow;Stack Exchange
# 1034        Unfavorable                                     Stack Overflow
# 1073          Favorable                                     Stack Overflow
# ...                 ...                                                ...
# 71940       Unfavorable  Stack Overflow for Teams (private knowledge sh...
# 71952       Indifferent                      Stack Overflow;Stack Exchange
# 72001            Unsure                      Stack Overflow;Stack Exchange
# 72255  Very unfavorable                      Stack Overflow;Stack Exchange
# 72706       Indifferent                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq                SOAccount  \
# 100    Less than once per month or monthly                      Yes
# 342                   A few times per week                      Yes
# 624                   A few times per week  Not sure/can't remember
# 1034                  A few times per week                      Yes
# 1073       A few times per month or weekly  Not sure/can't remember
# ...                                    ...                      ...
# 71940                 A few times per week                      Yes
# 71952      A few times per month or weekly                      Yes
# 72001                 A few times per week                      Yes
# 72255                Daily or almost daily                      Yes
# 72706                 A few times per week                       No
#
#                                               SOPartFreq          SOComm  \
# 100                  Less than once per month or monthly   Yes, somewhat
# 342    I have never participated in Q&A on Stack Over...  No, not really
# 624                                                  NaN  No, not really
# 1034                 Less than once per month or monthly         Neutral
# 1073                                                 NaN         Neutral
# ...                                                  ...             ...
# 71940                Less than once per month or monthly   Yes, somewhat
# 71952  I have never participated in Q&A on Stack Over...         Neutral
# 72001                    A few times per month or weekly   Yes, somewhat
# 72255  I have never participated in Q&A on Stack Over...         Neutral
# 72706                                                NaN  No, not at all
#
#                       Age Gender Trans                         Sexuality  \
# 100    Under 18 years old    Man    No           Straight / Heterosexual
# 342       35-44 years old    Man    No           Straight / Heterosexual
# 624       35-44 years old    Man    No           Straight / Heterosexual
# 1034      25-34 years old    Man    No           Straight / Heterosexual
# 1073      35-44 years old    Man    No           Straight / Heterosexual
# ...                   ...    ...   ...                               ...
# 71940     35-44 years old    Man    No           Straight / Heterosexual
# 71952     25-34 years old    Man    No  Bisexual;Straight / Heterosexual
# 72001     45-54 years old    Man    No                    Gay or Lesbian
# 72255     25-34 years old    Man    No           Straight / Heterosexual
# 72706     25-34 years old    Man    No           Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 100            White;European  None of the above
# 342            White;European  None of the above
# 624             White;African  None of the above
# 1034                    White  None of the above
# 1073           White;European  None of the above
# ...                       ...                ...
# 71940  White;European;African  None of the above
# 71952           African;Black  None of the above
# 72001                   White  None of the above
# 72255          White;Biracial  None of the above
# 72706                   White  None of the above
#
#                                             MentalHealth TBranch  \
# 100    I have a concentration and/or memory disorder ...     NaN
# 342    I have a concentration and/or memory disorder ...     Yes
# 624    I have a mood or emotional disorder (e.g., dep...      No
# 1034                                   None of the above      No
# 1073                                   None of the above     Yes
# ...                                                  ...     ...
# 71940                                  None of the above     Yes
# 71952                         I have an anxiety disorder     NaN
# 72001  I have a mood or emotional disorder (e.g., dep...     Yes
# 72255  I have a concentration and/or memory disorder ...     Yes
# 72706                                  None of the above     Yes
#
#                         ICorPM  WorkExp     Knowledge_1  \
# 100                        NaN      NaN             NaN
# 342    Independent contributor     21.0           Agree
# 624                        NaN      NaN             NaN
# 1034                       NaN      NaN             NaN
# 1073            People manager     20.0  Strongly agree
# ...                        ...      ...             ...
# 71940  Independent contributor     16.0  Strongly agree
# 71952                      NaN      NaN             NaN
# 72001           People manager     12.0           Agree
# 72255  Independent contributor     12.0           Agree
# 72706  Independent contributor      1.0        Disagree
#
#                       Knowledge_2                 Knowledge_3  \
# 100                           NaN                         NaN
# 342                         Agree  Neither agree nor disagree
# 624                           NaN                         NaN
# 1034                          NaN                         NaN
# 1073            Strongly disagree              Strongly agree
# ...                           ...                         ...
# 71940              Strongly agree  Neither agree nor disagree
# 71952                         NaN                         NaN
# 72001                       Agree  Neither agree nor disagree
# 72255                       Agree  Neither agree nor disagree
# 72706  Neither agree nor disagree           Strongly disagree
#
#                       Knowledge_4     Knowledge_5                 Knowledge_6  \
# 100                           NaN             NaN                         NaN
# 342                      Disagree        Disagree                       Agree
# 624                           NaN             NaN                         NaN
# 1034                          NaN             NaN                         NaN
# 1073               Strongly agree  Strongly agree  Neither agree nor disagree
# ...                           ...             ...                         ...
# 71940                    Disagree        Disagree  Neither agree nor disagree
# 71952                         NaN             NaN                         NaN
# 72001  Neither agree nor disagree           Agree  Neither agree nor disagree
# 72255                    Disagree           Agree                       Agree
# 72706                    Disagree        Disagree                       Agree
#
#                       Knowledge_7       Frequency_1        Frequency_2  \
# 100                           NaN               NaN                NaN
# 342                         Agree  1-2 times a week   3-5 times a week
# 624                           NaN               NaN                NaN
# 1034                          NaN               NaN                NaN
# 1073            Strongly disagree  3-5 times a week  6-10 times a week
# ...                           ...               ...                ...
# 71940  Neither agree nor disagree  1-2 times a week   3-5 times a week
# 71952                         NaN               NaN                NaN
# 72001  Neither agree nor disagree  3-5 times a week   3-5 times a week
# 72255                       Agree  3-5 times a week  6-10 times a week
# 72706                       Agree  1-2 times a week              Never
#
#             Frequency_3               TimeSearching         TimeAnswering  \
# 100                 NaN                         NaN                   NaN
# 342    1-2 times a week         30-60 minutes a day   30-60 minutes a day
# 624                 NaN                         NaN                   NaN
# 1034                NaN                         NaN                   NaN
# 1073   1-2 times a week  Less than 15 minutes a day   30-60 minutes a day
# ...                 ...                         ...                   ...
# 71940             Never  Less than 15 minutes a day   15-30 minutes a day
# 71952               NaN                         NaN                   NaN
# 72001  3-5 times a week         30-60 minutes a day   30-60 minutes a day
# 72255  1-2 times a week        60-120 minutes a day  60-120 minutes a day
# 72706  1-2 times a week         15-30 minutes a day   15-30 minutes a day
#
#           Onboarding                                   ProfessionalTech  \
# 100              NaN                                                NaN
# 342        Very long                      DevOps function;Microservices
# 624              NaN                                                NaN
# 1034             NaN                                                NaN
# 1073   Somewhat long  DevOps function;Microservices;Developer portal...
# ...              ...                                                ...
# 71940     Just right  Microservices;Developer portal or other centra...
# 71952            NaN                                                NaN
# 72001     Just right                                      None of these
# 72255      Very long  DevOps function;Microservices;Continuous integ...
# 72706  Somewhat long                                      None of these
#
#       TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 100           NaN         NaN         NaN  Appropriate in length
# 342            No          No         Yes              Too short
# 624           NaN         NaN         NaN               Too long
# 1034          NaN         NaN         NaN  Appropriate in length
# 1073          Yes          No         Yes  Appropriate in length
# ...           ...         ...         ...                    ...
# 71940         Yes          No         Yes  Appropriate in length
# 71952         NaN         NaN         NaN  Appropriate in length
# 72001         Yes          No         Yes  Appropriate in length
# 72255         Yes          No         Yes  Appropriate in length
# 72706         Yes         Yes         Yes  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 100                          Easy                  NaN
# 342                          Easy              56897.0
# 624    Neither easy nor difficult             115000.0
# 1034                         Easy              39449.0
# 1073                         Easy             164370.0
# ...                           ...                  ...
# 71940                        Easy              65748.0
# 71952                        Easy                  NaN
# 72001                        Easy              56897.0
# 72255                   Difficult              66756.0
# 72706  Neither easy nor difficult              23520.0
#
# [493 rows x 79 columns]

# %%
# If you want to filter to a particular column

dus =(df['Country'] == 'Uganda')
df.loc[dus,'Employment']
# Out:
# 5371                                    Student, full-time
# 5719     Independent contractor, freelancer, or self-em...
# 9376                                   Employed, full-time
# 9584     Independent contractor, freelancer, or self-em...
# 13079                   Not employed, but looking for work
# 13474                                   Student, full-time
# 13919                                  Employed, full-time
# 16457                                  Employed, full-time
# 17165                                  Employed, full-time
# 18403                   Not employed, but looking for work
# 19396                                  Employed, full-time
# 20135                                   Student, part-time
# 20136    Employed, full-time;Independent contractor, fr...
# 22376    Independent contractor, freelancer, or self-em...
# 23973                                  Employed, full-time
# 25807    Independent contractor, freelancer, or self-em...
# 27322    Independent contractor, freelancer, or self-em...
# 33121                                  Employed, full-time
# 33211               Student, part-time;Employed, part-time
# 33259    Student, full-time;Not employed, but looking f...
# 33887                                  Employed, full-time
# 34128                                  Employed, full-time
# 34336                                  Employed, full-time
# 35409                                  I prefer not to say
# 35668    Not employed, but looking for work;Independent...
# 36498    Independent contractor, freelancer, or self-em...
# 36756               Not employed, and not looking for work
# 36939                                   Student, full-time
# 37428    Not employed, but looking for work;Independent...
# 42117                                   Student, full-time
# 42120                                  Employed, full-time
# 42361                                   Student, part-time
# 42494                                  Employed, full-time
# 42587                                   Student, part-time
# 42608    Employed, full-time;Independent contractor, fr...
# 42880    Independent contractor, freelancer, or self-em...
# 44890                   Not employed, but looking for work
# 44986    Independent contractor, freelancer, or self-em...
# 46325                   Not employed, but looking for work
# 48311    Independent contractor, freelancer, or self-em...
# 48788    Independent contractor, freelancer, or self-em...
# 49005                                  I prefer not to say
# 50527    Independent contractor, freelancer, or self-em...
# 52252    Student, full-time;Independent contractor, fre...
# 55031                                  Employed, full-time
# 56045                                  Employed, full-time
# 56560    Student, part-time;Not employed, but looking f...
# 57297               Employed, full-time;Student, part-time
# 58415                                  Employed, full-time
# 60072                                  Employed, full-time
# 60271                                   Student, part-time
# 60700    Employed, full-time;Independent contractor, fr...
# 60812                   Not employed, but looking for work
# 61647               Not employed, and not looking for work
# 61677                                   Student, full-time
# 63363                                  Employed, full-time
# 64057    Student, part-time;Not employed, but looking f...
# 67250               Student, part-time;Employed, part-time
# 67479    Independent contractor, freelancer, or self-em...
# 70042    Independent contractor, freelancer, or self-em...
# 71019    Not employed, but looking for work;Independent...
# 72851                                   Student, full-time
# 73040    Independent contractor, freelancer, or self-em...
# Name: Employment, dtype: object

# %%
# filtering using ( & and |)

dus =(df['Country'] == 'Uganda') & (df['RemoteWork'] == 'Fully remote')
df.loc[dus,'LanguageHaveWorkedWith']
# Out:
# 5719          HTML/CSS;Java;JavaScript;Rust;SQL;TypeScript
# 20136       HTML/CSS;Java;JavaScript;Kotlin;SAS;TypeScript
# 27322                   HTML/CSS;JavaScript;PHP;Python;SQL
# 33121    Bash/Shell;HTML/CSS;JavaScript;PHP;Python;SQL;...
# 33887                  HTML/CSS;JavaScript;Ruby;TypeScript
# 42608       HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;SQL
# 50527                       HTML/CSS;JavaScript;TypeScript
# 60072                     JavaScript;Python;SQL;TypeScript
# 67479            APL;C;C#;HTML/CSS;Java;JavaScript;PHP;SQL
# 71019                         Bash/Shell;C;C++;Python;Rust
# Name: LanguageHaveWorkedWith, dtype: object

# %%
# filtering those with high salaries

high_salary = (df['CompTotal'] > 70000)
df.loc[high_salary, ['Country', 'Currency','LanguageHaveWorkedWith','CompFreq','CompTotal']]
# Out:
#                         Country                   Currency  \
# 11     United States of America  USD\tUnited States dollar
# 14     United States of America  USD\tUnited States dollar
# 17                      Austria          EUR European Euro
# 22                       Canada       CAD\tCanadian dollar
# 25                      Germany          EUR European Euro
# ...                         ...                        ...
# 73246        Russian Federation         RUB\tRussian ruble
# 73253                 Australia     AUD\tAustralian dollar
# 73254  United States of America  USD\tUnited States dollar
# 73258                     India          INR\tIndian rupee
# 73264  United States of America  USD\tUnited States dollar
#
#                                   LanguageHaveWorkedWith CompFreq  CompTotal
# 11     C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL   Yearly   194400.0
# 14           HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala   Yearly   110000.0
# 17                                            Python;SQL   Yearly   190000.0
# 22                                     C#;SQL;TypeScript   Yearly   125000.0
# 25                  Dart;Go;Java;Kotlin;Swift;TypeScript   Yearly    85000.0
# ...                                                  ...      ...        ...
# 73246                                Java;JavaScript;SQL  Monthly   150000.0
# 73253                                                 Go   Yearly   121000.0
# 73254                                                  R   Yearly   115000.0
# 73258                                        Go;Java;SQL   Yearly  3200000.0
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL   Yearly   107000.0
#
# [20183 rows x 5 columns]

# %%
# learn about the string method in pandas

# %% [markdown]
# ### Updating rows and columns -- Modifying data within Dataframes

# %% [markdown]
# ### updating the columns

# %% [markdown]
# poo

# %%
# changing columns names(.columns)

poo.columns
# Out:
# Index(['IDENTITY', 'EMAIL_ADDRESS', 'FULL_NAME', 'WEEKLY_INTAKE',
#        'FAVOURITE_CAR'],
#       dtype='object')

# %%
# This only used when you want to change all the column names
poo.columns = ['identity', 'Email_Address', 'Full_name', 'Weekly_intake', 'Favourite_car']
poo
# Out:
#    identity                                      Email_Address      Full_name  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    Weekly_intake Favourite_car
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius

# %%
# To change the column names all to uppercase

poo.columns = [x.upper() for x in poo.columns]
poo
# Out:
#    IDENTITY                                      EMAIL_ADDRESS      FULL_NAME  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    WEEKLY_INTAKE FAVOURITE_CAR
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius

# %%
# To change spaces to underscores
poo.columns = poo.columns.str.replace(' ', '_') # this won't work for us because we got no spaces on our column tittles
poo
# Out:
#    IDENTITY                                      EMAIL_ADDRESS      FULL_NAME  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    WEEKLY_INTAKE FAVOURITE_CAR
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius

# %%
# To change the uppercase to lowercase

poo.columns = [x.lower() for x in poo.columns]
poo
# Out:
#    identity     email_address      full_name  weekly_intake favourite_car
# 0         0   bri01@gmail.com  Brian Michael              5        Bently
# 1         1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2         2  pang02@gmail.com    Candy Pange              9      Mercedes

# %%
# to just change specific values of the columns we will use (.rename) and pass in a dictionary

poo.rename(columns={'email_address': 'email', 'full_name': 'name'}, inplace = True)
poo
# Out:
#    identity             email           name  weekly_intake favourite_car
# 0         0   bri01@gmail.com  Brian Michael              5        Bently
# 1         1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2         2  pang02@gmail.com    Candy Pange              9      Mercedes

# %% [markdown]
# ### updating rows

# %%
# to update the rows 
#This is used to change things within the rows mainly specific things

poo.loc[2, ['name', 'favourite_car']] = ['Tracy Blundo', 'Mobius']
poo
# Out:
#    identity                                              email           name  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    weekly_intake favourite_car
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius

# %%
# To change a single value

poo.loc[2, 'email'] = 'tracyblu@gmail.com'
poo
# Out:
#    identity                                              email           name  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    weekly_intake favourite_car
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius

# %%
# How to change multiple rows

poo
# Out:
#    IDENTITY                                      EMAIL_ADDRESS      FULL_NAME  \
# 0         0  <bound method StringMethods.lower of <pandas.c...  Brian Michael
# 1         1  <bound method StringMethods.lower of <pandas.c...     Owen Kelly
# 2         2                                 tracyblu@gmail.com   Tracy Blundo
#
#    WEEKLY_INTAKE FAVOURITE_CAR
# 0              5        Bently
# 1              6       Buggati
# 2              9        Mobius
