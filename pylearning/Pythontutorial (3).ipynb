# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # first notebook

# %% [markdown]
# #variables in python

# %%
x = 22

print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = 'am good'

# %%
type(y)
# Out:
# str

# %%
x,y,z = 'vanilla', 'mint', 'hello'

print(x)
print(y)
print(z)
# Out:
# vanilla
# mint
# hello

# %% [markdown]
# # list

# %%
ice_cream = ['chocolate','Vanilla', 'Rocky road']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# chocolate
# Vanilla
# Rocky road

# %%
# the best way to write a varioable
# 1 by using underscore infront or between the words

ice_cream = 'Vanilla'
_icecream = 'Vanilla'
_ice_cream = 'Vanilla'


#the wrong ways to write variables
# 1 beginning variables with numbers

_icecream = 'vanilla'

# %% [markdown]
# # python data types

# %%
#numeric data types
#1 integers = this are whole numbers both positive and negative

type(-12+44)
# Out:
# int

# %%
#2 float = this are numerics that have decimal places 

type(10.5)
type(12+12.6)
# Out:
# float

# %%
#3 complex = this are numerical data with letters in them that are like imaginary numbers
#  J is the only letter that is used in complex (if you use anyother letter you will get an error)

type(12+5j)
# Out:
# complex

# %%
# Boolean 
# this are only used to produce either a true or false results

type(True)
type(False)

#example use case

type(1 > 5)
# Out:
# bool

# %%
1 > 5
# Out:
# False

# %%
# strings
# when assigning strings to a variable you should use Quatation marks

y = 'hae, eveyone'
type(y)
# Out:
# str

# %%
#when using strings there are use of single quatation and double quatation which are used to do the same task

x = 'life is good'
x = "life is good"

# %%
#triple quatations are used when you want to write a large amount of text like a poem or paragraph

multiline = """
The ice cream vanquished
my longing for sweets,
upon this diet i look away,
it no longer exists on this day
"""

# %%
print(multiline)
# Out:
# The ice cream vanquished
# my longing for sweets,
# upon this diet i look away,
# it no longer exists on this day

# %%
type(multiline)
# Out:
# str

# %%
a= 'hello world'
print(a[:5])
# Out:
# hello

# %% [markdown]
# # list

# %%
#list
#stores multuiple values list are stored in brackets[]
# list are positioned just as strings and a position 0 we have 1

[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['BMW','Mercedes','Bently','Ferrari','Maybach']
# Out:
# ['BMW', 'Mercedes', 'Bently', 'Ferrari', 'Maybach']

# %%
#to add a value to a list you use (.append) this adds to the furthest part

cars = ['BMW','Mercedes','Bently','Ferrari','Maybach']
cars.append('Buggati')
cars
# Out:
# ['BMW', 'Mercedes', 'Bently', 'Ferrari', 'Maybach', 'Buggati']

# %%
# to delete elements in a list you use (.pop)- this is used to remove a value by its index
#also the (remove) function can be used and in that you provide the value to be removed from the list

#(.pop)
numbers = [1,2,3,4,5,6,7,88,9]
numbers.pop(0)
# Out:
# 1

# %%
print(numbers)
# Out:
# [2, 3, 4, 5, 6, 7, 88, 9]

# %%
#(.remove)

bill = [99,87,65,44,33,23,54]
bill.remove(44)
print(bill)
# Out:
# [99, 87, 65, 33, 23, 54]

# %%
#changing things in a list
cars[0]= 'Tesla'
cars
# Out:
# ['Tesla', 'Mercedes', 'Bently', 'Ferrari', 'Maybach', 'Buggati']

# %%
#nested list = this is a list within a list
nest_list = ['Vanilla',3,['Scoops','spoon'], True, 'Good']
nest_list[2]
# Out:
# ['Scoops', 'spoon']

# %% [markdown]
# # tuple

# %%
#tuples -can not be modified or changed after it has been created
#tuples are created using open parenthesis
#tuples are used when the data in them are not expected to change

good_day = (1,2,3,4,5,6)
type(good_day)
# Out:
# tuple

# %%
for bum in good_day:
    print(bum)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# # set

# %%
#sets
#values within a set cannot be accessed using index because its unordered

daily_stoic={1,2,3,4}
type(daily_stoic)
# Out:
# set

# %%
#sets do not hold duplicate values
#used when one wants to avoid duplicates


daily_pint = {1,2,3}

# %%
type(daily_pint)
# Out:
# set

# %%
print(daily_pint)
# Out:
# {1, 2, 3}

# %%
good_day = {1,2,3,5,7,8,77,2,3,7,4,5,6}  #you can see that during the print sets do not print duplicate values
print(good_day)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 77}

# %%
#sets can be used to compare values between different sets

daily_log = {1,2,31,2,3,4,1,2,5,6,3,2}
wife_daily_log = {1,3,5,7,3,24,5,7,3,2,0}

# %%
#when you want to find unique values from both daily_log and wife_daily_log

print(daily_log | wife_daily_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 24, 31}

# %%
#when you want to find value that are present in both daily_log and wife_daily_log

print(daily_log & wife_daily_log)
# Out:
# {1, 2, 3, 5}

# %%
#when you want to know the values that are not present in both daily_log and wife_daily_log

print(daily_log - wife_daily_log)
# Out:
# {4, 6, 31}

# %% [markdown]
# # dictionaries

# %%
#dictionaries
#has a key/value pair

dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
dict_cream.values()
# Out:
# dict_values(['Brian Michael', 5, ['Bently', 'Buggati', 'Mercedes']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite car'])

# %%
#dictionaries are called by the key

dict_cream['name']
# Out:
# 'Brian Michael'

# %%
#you can also update the values within a dictionary

dict_cream['name'] = 'Bimax Motors'

print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'weekly intake': 5, 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
#you can also update the whole dictionary the one we did before was on updating a single value

dict_cream.update({'name': 'Bimax Motors', 'production cost': 'five million', 'favourite car': ['Genim F12', 'Coldera01', 'Feyup']})

print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'weekly intake': 5, 'favourite car': ['Genim F12', 'Coldera01', 'Feyup'], 'production cost': 'five million'}

# %%
# to delete a value from the dictionary use del before the variable

del dict_cream['weekly intake']
print(dict_cream)
# Out:
# {'name': 'Bimax Motors', 'favourite car': ['Genim F12', 'Coldera01', 'Feyup'], 'production cost': 'five million'}

# %% [markdown]
# # comparison,logical and membership operators in python

# %%
#this contains mathematical operators

# equal to (==)

10 == 10
# Out:
# True

# %%
#not equal to (!=)

10 != 40
# Out:
# True

# %%
'Vanilla' == 'Vanilla'
# Out:
# True

# %%
x = 'Brian'
y = 'Michael'

x != y
# Out:
# True

# %%
# less than (<)

10 < 40
# Out:
# True

# %% [markdown]
# # logical operators

# %%
#logical operators often compined with logical operators

#And -----returns True if both statements are true
#Or ------Returns True if one of the statements is true
#Not -----Reverse the result, returns False if the statement is true

# %%
(10 > 50) and (50 < 40)
# Out:
# False

# %%
(70 > 30) and (10 < 30)
# Out:
# True

# %%
(10 > 60) or (0.5 <20)
# Out:
# True

# %%
not(50 > 10)
# Out:
# False

# %% [markdown]
# # membership operators

# %%
#used to check if a value or string is within another value or sequence


#In -------Returns True if a sequence with the specified value is present in the object
#Not in -----Returns True if a sequence with the specified value is not present in the object

# %%
brian_michael = 'i love cars soo much my guy'
'guy' in brian_michael #its like we are looking for the word guy in 'i love cars soo much my guy'
# Out:
# True

# %%
'guy' in 'i love cars soo much my guy'
# Out:
# True

# %%
_muranga = [1,2,3,34,4,4,5]

67 not in _muranga
# Out:
# True

# %% [markdown]
# # If  -  Elif  -  Else  statements

# %%
x = 25000000
if x == 25000000:
    print('am rich!')
# Out:
# am rich!

# %%
x = 25000000
if x > 25000000:
    print('am rich!')
else:
    print('work harder bro!')
# Out:
# work harder bro!

# %%
x = 25000000
if x > 25000000:
    print('am rich!')
elif x < 50000000:
    print('good job to me!')
else:
    print('work harder bro!')
# Out:
# good job to me!

# %%
#onother way to write if else statement

print('it worked!') if 10 > 30 else print('it did not work ....')
# Out:
# it did not work ....

# %%
#nested if statement

# %% [markdown]
# # for loops

# %%
#used to do something repeatedly until untill a condition is met

# %%
# Syntax  =  For var_name in sequence:                          for the var_name choose something meaningful
                #statement(s)

puke = ['jenny','Ram', 'Rahul', 'Pagal']


for names in puke:
    print(names)
# Out:
# jenny
# Ram
# Rahul
# Pagal

# %%
# for loops for dictonaries

dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}

# %%
for bull in dict_cream.values():    #to print values
    print(bull)
# Out:
# Brian Michael
# 5
# ['Bently', 'Buggati', 'Mercedes']

# %%
for pig in dict_cream.keys():      #to print keys
    print(pig)
# Out:
# name
# weekly intake
# favourite car

# %%
for keys,value in dict_cream.items():   # to print out both keys and values
    print(keys,'->',value)
# Out:
# name -> Brian Michael
# weekly intake -> 5
# favourite car -> ['Bently', 'Buggati', 'Mercedes']

# %%
#nested for loop

# %%
flavors = ['Vanilla', 'Chocolate', 'Cookie Dough']
toppings = ['Hot Fudge', 'Oreos', 'Marshmallo']

# %%
for one in flavors:
    for two in toppings:
        print(one, 'topped with', two)
# Out:
# Vanilla topped with Hot Fudge
# Vanilla topped with Oreos
# Vanilla topped with Marshmallo
# Chocolate topped with Hot Fudge
# Chocolate topped with Oreos
# Chocolate topped with Marshmallo
# Cookie Dough topped with Hot Fudge
# Cookie Dough topped with Oreos
# Cookie Dough topped with Marshmallo

# %% [markdown]
# # while loops

# %%
num = 0

while num < 5:
    print(num)
    num = num + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# breaking while loop  --- you use break to break out of a loop even if the statement is true


num = 0

while num < 7:
    print(num)
    if num == 4:
        break
    num = num + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#else statement in a while loop

num = 0
while num < 5:
    print(num)
    if num == 7:
        break
    num = num+1
else:
    print('no longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# no longer < 5

# %%
# this will lead to a infinate loop

num = 0
while num < 5:
    print(num)
    if num == 3:
        continue
    num = num+1
else:
    print('no longer < 5')

# %%
# 3 won't be printed out

num = 0
while num < 5:
    num = num+1
    if num == 3:
        continue
    print(num)
else:
    print('no longer < 5')

# %% [markdown]
# # functions

# %%
#they are only run when called
#example

def first_function():
    print('i finaly did it!')

# %%
#calling the function above
first_function()

# %%
#aguments in functions

def num_cool(number):
    print(number**2)

# %%
#calling the function

num_cool(6)   # 6 is the agument passed to the function

# %%
#passing more than one argument

def num_pass(number,power):
    print(number**power)

# %%
num_pass(5,2)

# %%
#abatury arguments   used when you are not sure about the number of arguments you want to pass

def num_arg(*number):
    print(number[0]*number[1])

# %%
num_arg(6,5,7,8,9)

# %%
#another example of how you can write the code above

tu_ple = (6,5,7,8,9)

def num_apt(*number):
    print(number[0]*number[1])

# %%
num_apt(*tu_ple)

# %%
#keyword Arguments   =  you define the values of the arguments

def num_one(power,number):
    print(number**power)

# %%
num_one(number = 3, power = 5)

# %%
#arbitary keyword argument
#in the arbitary argument we have one star here we are going to have two of them

def bri_an(**number):
    print('My number is: ' + number['brim'])

# %%
bri_an(brim = '356')

# %%
# when dealing with more than one

def muk_on(**arg):
    print('My number is: ' + arg['brim'] + ' My other number is: ' + arg['trim'])

# %%
muk_on(brim = '356', trim = '987')

# %% [markdown]
# # converting data types

# %%
#converting integer and strings

# %%
num_int = 9
type(num_int)

# %%
num_str = '8'
type(num_str)

# %%
# when converting string to integer

str_con = int(num_str)

# %%
type(str_con)

# %%
#converting lists, sets and tuples

# %%
#converting list to tuple

list_type = [1,2,3,4,5,6]
type(list_type)

# %%
tuple(list_type)

# %%
type(tuple(list_type))

# %%
#converting a list into a set
#when converting a list into a set only the unique data will be selected because set eliminates duplicates

list_type = [1,2,3,4,3,4,2,3,9,78,5,4,5,2,1,0,4,6]
set(list_type)

# %%
type(set(list_type))

# %%
#converting dictionaries
dict_cream = {'name': 'Brian Michael', 'weekly intake': 5, 'favourite car':['Bently','Buggati','Mercedes']}
type(dict_cream)

# %%
dict_cream.items()

# %%
dict_cream.values()

# %%
dict_cream.keys()

# %%
#converting keys to a list
list(dict_cream.keys())

# %%
type(list(dict_cream.keys()))

# %%
#converting long strings into a list

puma = 'i love getting things done the right way'
list(puma)

# %%
type(list(puma))

# %% [markdown]
# # BMI calculator (body mass index)

# %% [markdown]
# #BMI Calculator reference
# https://mercer-health.com/services/weight-management-center/bmi-calculator#:~:text=Body%20Mass%20Index%2C%20or%20BMI,inches%20x%20height%20in%20inches

# %%
# BMI = (weight in kilogram) / (height in meters x height in meters)

#Under 18.5	Underweight	Minimal
#18.5 - 24.9	Normal Weight	Minimal
#25 - 29.9	Overweight	Increased
#30 - 34.9	Obese	High
#35 - 39.9	Severely Obese	Very High
#40 and over	Morbidly Obese	Extremely High

Name = input('Enter your Name: ')
weight = float(input('Enter your weight in kilograms: '))
height = float(input('Enter your height in meters: '))
BMI = (weight) / (height**2)
print(BMI)


if BMI < 18.5:
    print(Name + ', You are underweight')
elif BMI <= 24.9:
    print(Name + ', You have a normal weight')
elif BMI <= 29.9:
    print(Name + ', You are overweight')
elif BMI <= 34.9:
    print(Name + ', You are Obese')
elif BMI <= 39.9:
    print(Name + ', You are Severly Obese')
else:
    print(Name + ', You are Morbidly Obese')

# %% [markdown]
# # Automatic file sorter in File explorer

# %%
# the OS module       (that is what i should learn before doing this project)

# %% [markdown]
# # Key data structrures for data science

# %% [markdown]
# # string functions
#
# # 1.lower and Upper

# %%
#used to change strings to lower case or upper case

scum = 'Everything you see around you'
scum.upper()

# %%
Town = 'WHERE THERE ARE MANY OPPOTUNITIES TO MAKE MONEY'
Town.lower()

# %% [markdown]
# # 2. Strip

# %%
#used to get rid of white space and even new lines in a string

sing = '  everything is cool\n'
print(sing)

# %%
sing.strip()

# %%
#also used to get rid of other values within a string

make = '*****2345*****'
print(make)

# %%
make.strip('*')

# %% [markdown]
# # 3. split

# %%
#used to return a list of words in a long string

lop = 'let us all play with the new guy'
lop.split(' ')

# %% [markdown]
# # 4.string formatting

# %%
#uses the format function   ---- used to add some words to a string

statement = 'we love {} {}'
statement.format('data','stealing')
print(statement.format('data','stealing'))

# %% [markdown]
# # Numpy

# %% [markdown]
# ## numpy array

# %%
#numpy can be used to store a bunch of data in multidimensional array (1,2,3)
#numpy is used because it tends to be faster than using list

# %% [markdown]
# ## application of Numpy
#
# Mathematics(MATLAB Replacement),
# Plotting (Matplotlib),
# It is Backend of (Pandas, Connect 4, Digital Photography),
# Machine Learning

# %%
import numpy as np

# %% [markdown]
# ### Basics

# %%
#how to initialise an array

a = np.array([1,2,3])          # this is a one dimensional array
print(a)

# %%
b = np.array([[9.0,8.2,7.5,1.0],[5.3,8.0,9.0,1.2]])     # this is a two dimensional array of data type floats
print(b)

# %%
# how to get the dimension of your array
a.ndim

# %%
b.ndim

# %%
# to get the shape 
a.shape

# %%
b.shape     #(2,4) = says two rows and four columns

# %%
# to get type
b.dtype

# %%
# to get size
b.itemsize

# %% [markdown]
# ## Accessing/ changing specific elements, rows, columns e.t.c

# %%
a = np.array([[8,6,5,3,8,9,1],[7,5,3,1,9,5,3]])
print(a)

# %%
a.shape

# %%
# geting a specific element  [row,column] (first row and column are 0)
# lets get 7

a[1,0]

# %%
# to get an entire row
a[0, :]

# %%
# to get a specific column
a[:, 4]

# %%
a[0, 1:6]

# %%
# changing elements (lets change 7 to 13)
a[1,0]=13
print(a)

# %% [markdown]
# * 3D example

# %%
b = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(b)

# %%
b.size

# %%
b.ndim

# %%
# getting specuific element

b[0,0,1]

# %% [markdown]
# ## Initializing Different types of Arrays

# %%
# All zeros(0s) matrix  (return a new array of a given shape and type, filled with zeros)

np.zeros((2,3))

# %%
np.zeros((4,4,2))

# %%
# All ones(1s) matrix (returns a new array filled with 1s)

np.ones((2,3,4))

# %%
# Any other number matrix   (you specify the shape and also the values)

np.full((3,2,2), 22)     #(22 is the value to be filled that i have specified)

# %%
# Any other number (np.full_like)  (enables us to take a shape that has already been build)
a = np.array([[8,6,5,3,8,9,1],[7,5,3,1,9,5,3]])
a

# %%
np.full_like(a, 3)

# %%
#Random decimal numbers(random.rand)

np.random.rand(3,2)

# %%
#Random integer values(np.random.randint)
# 2 --- is the position argument

np.random.randint(9,size=(4,3))

# %%
#The identity matrix (its always a square so it requires one agument)

np.identity(4)

# %%
# Repeat a array (i have used in in a two dimensional array)

arr = np.array([[5,4,3,2]])
r1 = np.repeat(arr,3, axis=0)
print(r1)

# %%
arg = np.array([[5,6,7,8],[9,7,8,5]])
print(arg)

# %%
output = np.ones((5,5))
print(output)

z = np.zeros((3,3))
z[1,1]=9
print(z)
output[1:4,1:4] = z
print(output)

# %% [markdown]
# ### when copying contents of another variable

# %%
# when you want to copy the contents of another variable you need to use the (.copy())
#the example below

a = np.array([1,2,3,4])
b = a
b[0] =1000
b
a

# %%
# when copying to use it diferrently

a = np.array([5,4,6,8])
b = a.copy()
b[0]= 100
b
a

# %% [markdown]
# ## Mathematics using numpy

# %%
a = np.array([1,2,3,4])
a

# %%
#addition
# this adds it to all the values within the array

a+2

# %%
#subtraction(also subtracts everything from the array)

a - 4

# %%
#multiplication
a * 4

# %%
#division
a / 2

# %%
b = np.array([3,4,5,8])
a + b

# %%
np.sin(a)

# %%
np.cos(a)

# %% [markdown]
# #### Numpy mathematical Documentation
# ####  For a lot more (https://docs.scipy.org/doc/numpy/reference/routines.math.html)

# %%
a = np .array([7,4,7,9,7,5])
a

# %%
a * 10

# %%
a

# %%
a += 10
a

# %%
a

# %%
a = np.arange(9)
a

# %%
a <= 3

# %%
a > 6

# %%
a.mean()

# %% [markdown]
# ### Linear Algebra

# %%
# Linear Algebra is the one of the most important part in machine learning

a = np.ones((2,3))
print(a)

b = np.full((3,2), 2)
print(b)

np.matmul(a,b)

# %%
### DO MORE ABOUT LINEAR ALGEBRA AND NUMPY THAT WILL ALSO BE USED IN MACHINE LEARNING

# %% [markdown]
# ### Statistics

# %%
## Mean, mediun, Max, min

doo = np.array([[5,4,6,7],[8,7,9,6]])
doo

# %%
np.min(doo)

# %%
np.sum(doo)

# %% [markdown]
# ## Reorganizing Arrays

# %%
# This is used to mainly change the shapes of arrays(Use the .reshape)

hell = np.array([[5,6,8,9,2],[7,9,4,6,2]])
print(hell)

hello = hell.reshape((5,2))
print(hello)

# %%
# Vertically stacking vectors

v1 = np.array([1,2,3,4])
v2 = np.array([5,6,7,8])

np.vstack([v1,v2])
np.vstack([v1,v2,v2,v1])

# %%
# horizontal stack

h1 = np.ones((2,4))
h2 = np.zeros((2,2))

np.hstack((h1,h2))

# %% [markdown]
# ## Miscellaneous
# ### Load Data from file

# %%
np.genfromcsv('Excel project')

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Importing Data into Jupyter notebook

# %%
# To import data you have to give the route that the data is supossed to follow use the (pd.read_csv)(csv is a file name)

df = pd.read_csv('desktop/pandas/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
# to get to know the number of column and rows in your data (use the .shape attribute)

df.shape
# Out:
# (73268, 79)

# %% [markdown]
# ## Data types in pandas in our dataset
# #### Object means string
# #### Int64 is integer that stored in a 64 bit
# #### and float

# %%
#To get more information about the data you are using use (.info())
#This gives you the columns and the data types that you are using

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %%
# To view all the columns in our dataset (.set_option('display.max_columns',_number of columns_))

df = pd.read_csv('desktop/pandas/survey_results_public.csv')
pd.set_option('display.max_columns', 79)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
# i want to put a schema file that we have that have matching questions to the dataset that we have
# so we will load in the schema file

schema_df = pd.read_csv('desktop/pandas/survey_results_schema.csv')
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# ..        ...   ...      ...
# 74        NaN    MC     MAVR
# 75        NaN    MC     MAVR
# 76        NaN    MC     MAVR
# 77        NaN    MC     MAVR
# 78        NaN    MC     MAVR
#
# [79 rows x 6 columns]

# %%
# to view all rows of your dataset(pd.set_option('display.max_rows'_number of rows_))

pd.set_option('display.max_rows', 79)
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
# when you want to just see a certain amount of data(.head()) this for viewing the first 10 items

schema_df.head(10)
# Out:
#       qid             qname  \
# 0   QID16                S0
# 1   QID12          MetaInfo
# 2    QID1                S1
# 3    QID2        MainBranch
# 4  QID296        Employment
# 5  QID308        RemoteWork
# 6  QID297  CodingActivities
# 7  QID190                S2
# 8   QID25           EdLevel
# 9  QID276         LearnCode
#
#                                             question force_resp  type selector
# 0  <div><span style="font-size:19px;"><strong>Hel...      False    DB       TB
# 1                                  Browser Meta Info      False  Meta  Browser
# 2  <span style="font-size:22px; font-family: aria...      False    DB       TB
# 3  Which of the following options best describes ...       True    MC     SAVR
# 4  Which of the following best describes your cur...      False    MC     MAVR
# 5  Which best describes your current work situation?      False    MC     SAVR
# 6  Which of the following best describes the code...      False    MC     MAVR
# 7  <span style="font-size:22px; font-family: aria...      False    DB       TB
# 8  Which of the following best describes the high...      False    MC     SAVR
# 9  How did you learn to code? Select all that apply.      False    MC     MAVR

# %%
#viewing the last 10(.tail())
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# 73260             Employed, full-time;Student, part-time
# 73261                                Employed, full-time
# 73262             Student, full-time;Employed, part-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73258  Hybrid (some remote, some in-person)
# 73259  Hybrid (some remote, some in-person)
# 73260  Hybrid (some remote, some in-person)
# 73261  Hybrid (some remote, some in-person)
# 73262  Hybrid (some remote, some in-person)
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73258                                              Hobby
# 73259                            Other (please specify):
# 73260                            School or academic work
# 73261                                              Hobby
# 73262                            School or academic work
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73259    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73260       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73262  Secondary school (e.g. American high school, G...
# 73263       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73258  Other online resources (e.g., videos, blogs, f...
# 73259  Books / Physical media;Other online resources ...
# 73260            School (i.e., University, College, etc)
# 73261  Books / Physical media;Other online resources ...
# 73262  Other online resources (e.g., videos, blogs, f...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73258  Stack Overflow;Video-based Online Courses;Onli...
# 73259  Technical documentation;Blogs;Written Tutorial...
# 73260                                                NaN
# 73261  Technical documentation;Blogs;Programming Game...
# 73262  Technical documentation;Written Tutorials;Stac...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 73258                    Coursera;Udemy         5  ...  15-30 minutes a day
# 73259                               NaN         6  ...  15-30 minutes a day
# 73260                               NaN         8  ...  15-30 minutes a day
# 73261      Udemy;Codecademy;Pluralsight         9  ...  15-30 minutes a day
# 73262                               NaN         4  ...                  NaN
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering      Onboarding  \
# 73258         15-30 minutes a day      Just right
# 73259  Less than 15 minutes a day  Somewhat short
# 73260         30-60 minutes a day       Very long
# 73261         15-30 minutes a day   Somewhat long
# 73262                         NaN             NaN
# 73263  Less than 15 minutes a day      Just right
# 73264        60-120 minutes a day       Very long
# 73265        60-120 minutes a day      Just right
# 73266                         NaN             NaN
# 73267                         NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 73258  DevOps function;Microservices;Developer portal...         Yes
# 73259  DevOps function;Continuous integration (CI) an...         Yes
# 73260  DevOps function;Developer portal or other cent...          No
# 73261  Innersource initiative;DevOps function;Microse...         Yes
# 73262                                                NaN         NaN
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 73258         Yes         Yes               Too long
# 73259         Yes         Yes  Appropriate in length
# 73260          No         Yes  Appropriate in length
# 73261         Yes         Yes  Appropriate in length
# 73262         NaN         NaN  Appropriate in length
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 73258  Neither easy nor difficult                 NaN
# 73259  Neither easy nor difficult                 NaN
# 73260                        Easy                 NaN
# 73261                        Easy                 NaN
# 73262  Neither easy nor difficult                 NaN
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [10 rows x 79 columns]

# %% [markdown]
# # dataframe and series data type

# %% [markdown]
# ### dataframes

# %%
# dataframe is madeup of multiple rows and also multiple columns ()
# Dataframes are like storing data in python Dictionaries 

#example of data stored in a python dictionary

dict_cream = {'name': ['Brian Michael','Owen Kelly', 'Candy Pange'], 'weekly intake': [5,6,9], 'favourite car':['Bently','Buggati','Mercedes']}
print(dict_cream)
# Out:
# {'name': ['Brian Michael', 'Owen Kelly', 'Candy Pange'], 'weekly intake': [5, 6, 9], 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
# Example of the same data stored using dataframes in pandas

cp = pd.DataFrame(dict_cream)
cp
# Out:
#             name  weekly intake favourite car
# 0  Brian Michael              5        Bently
# 1     Owen Kelly              6       Buggati
# 2    Candy Pange              9      Mercedes

# %%
cp['name']
# Out:
# 0    Brian Michael
# 1       Owen Kelly
# 2      Candy Pange
# Name: name, dtype: object

# %% [markdown]
# ## Series

# %%
# This is a list of Data . Its rows of data
# Dataframe is rows and columns while a series is just rows

# %%
# Data in one row is called is series
cp.name
# Out:
# 0    Brian Michael
# 1       Owen Kelly
# 2      Candy Pange
# Name: name, dtype: object

# %%
#accessing multiple columns using dataframe

cp[['name', 'weekly intake']]
# Out:
#             name  weekly intake
# 0  Brian Michael              5
# 1     Owen Kelly              6
# 2    Candy Pange              9

# %%
# Accessing rows use (loc) and (iloc) iloc means index location
# when using (iloc) you search by integer location while in (loc) you search by label

cp.iloc[[0,1]]
# Out:
#             name  weekly intake favourite car
# 0  Brian Michael              5        Bently
# 1     Owen Kelly              6       Buggati

# %%
# to select just a specific column in defferent row

cp.iloc[[0,2], 2]
# Out:
# 0      Bently
# 2    Mercedes
# Name: favourite car, dtype: object

# %%
cp.loc[0]
# Out:
# name             Brian Michael
# weekly intake                5
# favourite car           Bently
# Name: 0, dtype: object

# %%
cp.loc[[0,1,2], 'favourite car']
# Out:
# 0      Bently
# 1     Buggati
# 2    Mercedes
# Name: favourite car, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
df.shape
# Out:
# (73268, 79)

# %%
su=df['RemoteWork']
su.loc[0:50]
# Out:
# 0                                      NaN
# 1                             Fully remote
# 2     Hybrid (some remote, some in-person)
# 3                             Fully remote
# 4     Hybrid (some remote, some in-person)
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8     Hybrid (some remote, some in-person)
# 9                             Fully remote
# 10    Hybrid (some remote, some in-person)
# 11                            Fully remote
# 12    Hybrid (some remote, some in-person)
# 13                            Fully remote
# 14                            Fully remote
# 15                            Fully remote
# 16    Hybrid (some remote, some in-person)
# 17                            Fully remote
# 18    Hybrid (some remote, some in-person)
# 19                                     NaN
# 20    Hybrid (some remote, some in-person)
# 21    Hybrid (some remote, some in-person)
# 22                            Fully remote
# 23    Hybrid (some remote, some in-person)
# 24                            Fully remote
# 25    Hybrid (some remote, some in-person)
# 26    Hybrid (some remote, some in-person)
# 27                                     NaN
# 28    Hybrid (some remote, some in-person)
# 29                            Fully remote
# 30                                     NaN
# 31                            Fully remote
# 32                          Full in-person
# 33                          Full in-person
# 34                            Fully remote
# 35                                     NaN
# 36                            Fully remote
# 37                            Fully remote
# 38                                     NaN
# 39    Hybrid (some remote, some in-person)
# 40    Hybrid (some remote, some in-person)
# 41    Hybrid (some remote, some in-person)
# 42                                     NaN
# 43                          Full in-person
# 44                                     NaN
# 45    Hybrid (some remote, some in-person)
# 46                                     NaN
# 47                            Fully remote
# 48    Hybrid (some remote, some in-person)
# 49                            Fully remote
# 50                          Full in-person
# Name: RemoteWork, dtype: object

# %%
# Counts values in a column(.value_counts())

df['RemoteWork'].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64

# %%
df.loc[0 : 1000, 'CompTotal' : 'LanguageHaveWorkedWith']
# Out:
#       CompTotal CompFreq                             LanguageHaveWorkedWith
# 0           NaN      NaN                                                NaN
# 1           NaN      NaN                              JavaScript;TypeScript
# 2       32000.0   Yearly                  C#;C++;HTML/CSS;JavaScript;Python
# 3       60000.0  Monthly                       C#;JavaScript;SQL;TypeScript
# 4           NaN      NaN        C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...         ...      ...                                                ...
# 996         NaN      NaN  Bash/Shell;C;Elixir;JavaScript;Rust;SQL;TypeSc...
# 997    181000.0   Yearly     Bash/Shell;C#;JavaScript;PowerShell;Python;SQL
# 998    145000.0   Yearly                                           Java;PHP
# 999         NaN      NaN                                     C#;Dart;Python
# 1000  1200000.0  Monthly  C;C#;C++;HTML/CSS;JavaScript;PowerShell;Rust;T...
#
# [1001 rows x 3 columns]

# %% [markdown]
# ## Indexes - How to set, Reset and use indexes

# %%
# Indexes are the numbering that are automatically given to data at the far left side
# we will first use a small amount of dataframe as an example

dict_cream = {'name': ['Brian Michael','Owen Kelly', 'Candy Pange'], 'weekly intake': [5,6,9],'Email':['bri01@gmail.com','owen66@gmail.com','pang02@gmail.com'] ,'favourite car':['Bently','Buggati','Mercedes']}
print(dict_cream)
# Out:
# {'name': ['Brian Michael', 'Owen Kelly', 'Candy Pange'], 'weekly intake': [5, 6, 9], 'Email': ['bri01@gmail.com', 'owen66@gmail.com', 'pang02@gmail.com'], 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
poo = pd.DataFrame(dict_cream)
poo
# Out:
#             name  weekly intake             Email favourite car
# 0  Brian Michael              5   bri01@gmail.com        Bently
# 1     Owen Kelly              6  owen66@gmail.com       Buggati
# 2    Candy Pange              9  pang02@gmail.com      Mercedes

# %%
# Indexes is what identifies each and every data within our data
# So lets set Email as our indexes because its unique on each and every person
#use(.set_index)


poo.set_index('Email')
# Out:
#                            name  weekly intake favourite car
# Email
# bri01@gmail.com   Brian Michael              5        Bently
# owen66@gmail.com     Owen Kelly              6       Buggati
# pang02@gmail.com    Candy Pange              9      Mercedes

# %%
poo
# Out:
#             name  weekly intake             Email favourite car
# 0  Brian Michael              5   bri01@gmail.com        Bently
# 1     Owen Kelly              6  owen66@gmail.com       Buggati
# 2    Candy Pange              9  pang02@gmail.com      Mercedes

# %%
# To make the indexing permarnent use (.set_index('name of column', inplace=True))

poo.set_index('Email', inplace=True)
poo
# Out:
#                            name  weekly intake favourite car
# Email
# bri01@gmail.com   Brian Michael              5        Bently
# owen66@gmail.com     Owen Kelly              6       Buggati
# pang02@gmail.com    Candy Pange              9      Mercedes

# %%
poo.index
# Out:
# Index(['bri01@gmail.com', 'owen66@gmail.com', 'pang02@gmail.com'], dtype='object', name='Email')

# %%
# use can use the email indexes to obtain data about a specific person

poo.loc['owen66@gmail.com']
# Out:
# name             Owen Kelly
# weekly intake             6
# favourite car       Buggati
# Name: owen66@gmail.com, dtype: object

# %%
# How to reset the indexes (.reset_index(inplace=True))

poo.reset_index(inplace=True)
poo
# Out:
#               Email           name  weekly intake favourite car
# 0   bri01@gmail.com  Brian Michael              5        Bently
# 1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2  pang02@gmail.com    Candy Pange              9      Mercedes

# %%
df = pd.read_csv('desktop/pandas/survey_results_public.csv')
schema_df = pd.read_csv('desktop/pandas/survey_results_schema.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
pd.set_option('display.max_column', 79)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
df.loc[0 : 70, 'Country' : 'LanguageHaveWorkedWith']
# Out:
#                                               Country  \
# 0                                                 NaN
# 1                                              Canada
# 2   United Kingdom of Great Britain and Northern I...
# 3                                              Israel
# 4                            United States of America
# 5                                             Germany
# 6                                               India
# 7                                               India
# 8                                         Netherlands
# 9                                             Croatia
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
# 12                           United States of America
# 13                                          Australia
# 14                           United States of America
# 15                                 Russian Federation
# 16                                     Czech Republic
# 17                                            Austria
# 18                                            Austria
# 19                                             Serbia
# 20                                            Austria
# 21                                              Italy
# 22                                             Canada
# 23                                        Netherlands
# 24                                             Israel
# 25                                            Germany
# 26                           United States of America
# 27                                             Israel
# 28                           United States of America
# 29                                            Ireland
# 30                                                NaN
# 31                           United States of America
# 32                                             Canada
# 33                                             Israel
# 34                                             Poland
# 35                                             Israel
# 36                                             Canada
# 37                                             Israel
# 38                                           Slovenia
# 39                                     Czech Republic
# 40                           United States of America
# 41                                             Israel
# 42                                               Iraq
# 43                                             Sweden
# 44                                            Austria
# 45                                         Madagascar
# 46                                             Norway
# 47                           United States of America
# 48                                            Germany
# 49                                            Germany
# 50                                     Czech Republic
# 51                                             Poland
# 52                                     Czech Republic
# 53                           United States of America
# 54                                             Norway
# 55                           United States of America
# 56                                             Taiwan
# 57                                        Netherlands
# 58                                 Hong Kong (S.A.R.)
# 59                                            Germany
# 60                                             Canada
# 61                                             Mexico
# 62                                             France
# 63                           United States of America
# 64                                             France
# 65                                              India
# 66                                             Brazil
# 67                                          Australia
# 68                                          Lithuania
# 69                                            Uruguay
# 70                                             Serbia
#
#                      Currency  CompTotal CompFreq  \
# 0                         NaN        NaN      NaN
# 1        CAD\tCanadian dollar        NaN      NaN
# 2         GBP\tPound sterling    32000.0   Yearly
# 3     ILS\tIsraeli new shekel    60000.0  Monthly
# 4   USD\tUnited States dollar        NaN      NaN
# 5                         NaN        NaN      NaN
# 6                         NaN        NaN      NaN
# 7                         NaN        NaN      NaN
# 8           EUR European Euro    46000.0   Yearly
# 9          HRK\tCroatian kuna        NaN      NaN
# 10        GBP\tPound sterling    48000.0   Yearly
# 11  USD\tUnited States dollar   194400.0   Yearly
# 12  USD\tUnited States dollar    65000.0   Yearly
# 13     AUD\tAustralian dollar        NaN      NaN
# 14  USD\tUnited States dollar   110000.0   Yearly
# 15         RUB\tRussian ruble        NaN   Weekly
# 16          CZK\tCzech koruna    37000.0  Monthly
# 17          EUR European Euro   190000.0   Yearly
# 18          EUR European Euro     4000.0  Monthly
# 19                        NaN        NaN      NaN
# 20                        NaN        NaN      NaN
# 21          EUR European Euro    32000.0   Yearly
# 22       CAD\tCanadian dollar   125000.0   Yearly
# 23          EUR European Euro        NaN      NaN
# 24    ILS\tIsraeli new shekel        NaN      NaN
# 25          EUR European Euro    85000.0   Yearly
# 26  USD\tUnited States dollar   106960.0   Yearly
# 27                        NaN        NaN      NaN
# 28  USD\tUnited States dollar   130000.0   Yearly
# 29          EUR European Euro   130000.0  Monthly
# 30                        NaN        NaN      NaN
# 31  USD\tUnited States dollar   102000.0   Yearly
# 32                        NaN        NaN      NaN
# 33                        NaN        NaN      NaN
# 34          PLN\tPolish zloty    30000.0  Monthly
# 35                        NaN        NaN      NaN
# 36       CAD\tCanadian dollar        NaN      NaN
# 37    ILS\tIsraeli new shekel        NaN      NaN
# 38                        NaN        NaN      NaN
# 39          CZK\tCzech koruna        NaN  Monthly
# 40  USD\tUnited States dollar   130000.0   Yearly
# 41    ILS\tIsraeli new shekel    19000.0  Monthly
# 42                        NaN        NaN      NaN
# 43                        NaN        NaN      NaN
# 44                        NaN        NaN      NaN
# 45          EUR European Euro      400.0  Monthly
# 46                        NaN        NaN      NaN
# 47  USD\tUnited States dollar   135000.0   Yearly
# 48          EUR European Euro   100000.0   Yearly
# 49          EUR European Euro     4000.0  Monthly
# 50                        NaN        NaN      NaN
# 51          PLN\tPolish zloty    14000.0  Monthly
# 52                        NaN        NaN      NaN
# 53  USD\tUnited States dollar   170000.0   Yearly
# 54       NOK\tNorwegian krone  1000000.0   Yearly
# 55  USD\tUnited States dollar   141000.0   Yearly
# 56     TWD\tNew Taiwan dollar  1632000.0   Yearly
# 57          EUR European Euro     3650.0  Monthly
# 58      HKD\tHong Kong dollar        NaN  Monthly
# 59          EUR European Euro    60000.0   Yearly
# 60       CAD\tCanadian dollar    85000.0   Yearly
# 61                        NaN        NaN      NaN
# 62          EUR European Euro    70000.0   Yearly
# 63  USD\tUnited States dollar   150000.0   Yearly
# 64                        NaN        NaN      NaN
# 65          INR\tIndian rupee        NaN  Monthly
# 66        BRL\tBrazilian real    10000.0  Monthly
# 67                        NaN        NaN      NaN
# 68                        NaN        NaN      NaN
# 69        UYU\tUruguayan peso   130000.0  Monthly
# 70         RSD\tSerbian dinar        NaN      NaN
#
#                                LanguageHaveWorkedWith
# 0                                                 NaN
# 1                               JavaScript;TypeScript
# 2                   C#;C++;HTML/CSS;JavaScript;Python
# 3                        C#;JavaScript;SQL;TypeScript
# 4         C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                             C++;Lua
# 6       C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 7                  C;C++;HTML/CSS;Java;JavaScript;SQL
# 8                                                 NaN
# 9                                   Delphi;Java;Swift
# 10   Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# 11  C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 12               C;HTML/CSS;Rust;SQL;Swift;TypeScript
# 13  Elixir;Erlang;HTML/CSS;JavaScript;Ruby;SQL;Typ...
# 14        HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 15      Bash/Shell;HTML/CSS;JavaScript;SQL;TypeScript
# 16                               C#;Java;PHP;Python;R
# 17                                         Python;SQL
# 18                                  C#;PowerShell;SQL
# 19                C++;HTML/CSS;Java;JavaScript;Python
# 20  Bash/Shell;C#;HTML/CSS;Java;JavaScript;PowerSh...
# 21                              Python;SQL;TypeScript
# 22                                  C#;SQL;TypeScript
# 23                                                VBA
# 24                   C#;C++;JavaScript;PHP;TypeScript
# 25               Dart;Go;Java;Kotlin;Swift;TypeScript
# 26     Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;SQL
# 27             C#;HTML/CSS;JavaScript;Rust;TypeScript
# 28                                              C;C++
# 29                       C#;JavaScript;PowerShell;SQL
# 30                                                NaN
# 31                         C#;HTML/CSS;JavaScript;SQL
# 32                                         C++;Python
# 33                                      C++;Go;Python
# 34          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 35                                      MATLAB;Python
# 36  C#;C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL
# 37                HTML/CSS;JavaScript;PHP;Python;Ruby
# 38                     HTML/CSS;JavaScript;Python;SQL
# 39  Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Per...
# 40      C#;C++;HTML/CSS;JavaScript;SQL;TypeScript;VBA
# 41                     Bash/Shell;HTML/CSS;Python;SQL
# 42                C#;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 43                                                NaN
# 44  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# 45                              JavaScript;TypeScript
# 46                   Bash/Shell;C;C++;Java;Lua;Python
# 47                 Java;JavaScript;PHP;SQL;TypeScript
# 48                                  Haskell;Java;Rust
# 49              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 50                            Bash/Shell;Julia;Python
# 51  Bash/Shell;HTML/CSS;Java;JavaScript;Python;Rus...
# 52                          Bash/Shell;Go;Java;Python
# 53              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 54  Bash/Shell;C#;HTML/CSS;Java;JavaScript;LISP;Po...
# 55  C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 56                                                C++
# 57   Bash/Shell;C#;HTML/CSS;PowerShell;SQL;TypeScript
# 58                   Dart;HTML/CSS;Java;Kotlin;Python
# 59  Assembly;Bash/Shell;C;HTML/CSS;JavaScript;PHP;...
# 60  Bash/Shell;C#;C++;HTML/CSS;Java;JavaScript;Kot...
# 61                         Bash/Shell;HTML/CSS;Python
# 62                                 Groovy;Java;Kotlin
# 63  Bash/Shell;C;Go;HTML/CSS;Java;JavaScript;Pytho...
# 64                C;C#;HTML/CSS;Java;JavaScript;PHP;R
# 65                                                 C#
# 66              C;C++;Delphi;HTML/CSS;Java;JavaScript
# 67                     C#;HTML/CSS;JavaScript;PHP;SQL
# 68  C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;...
# 69  Bash/Shell;HTML/CSS;Java;JavaScript;SQL;TypeSc...
# 70                                    Java;Kotlin;PHP

# %%
# how to set a column as the index when you are loading in the data (, index_col = 'name of the column')

df = pd.read_csv('desktop/pandas/survey_results_public.csv', index_col = 'CompFreq')
df.head(50)
# Out:
#           ResponseId                                         MainBranch  \
# CompFreq
# NaN                1                                      None of these
# NaN                2                     I am a developer by profession
# Yearly             3  I am not primarily a developer, but I write co...
# Monthly            4                     I am a developer by profession
# NaN                5                     I am a developer by profession
# NaN                6  I am not primarily a developer, but I write co...
# NaN                7                        I code primarily as a hobby
# NaN                8                     I am a developer by profession
# Yearly             9                     I am a developer by profession
# NaN               10                     I am a developer by profession
# Yearly            11                     I am a developer by profession
# Yearly            12  I am not primarily a developer, but I write co...
# Yearly            13                     I am a developer by profession
# NaN               14                     I am a developer by profession
# Yearly            15                     I am a developer by profession
# Weekly            16                     I am a developer by profession
# Monthly           17                     I am a developer by profession
# Yearly            18                     I am a developer by profession
# Monthly           19                     I am a developer by profession
# NaN               20                              I am learning to code
# NaN               21                     I am a developer by profession
# Yearly            22                     I am a developer by profession
# Yearly            23                     I am a developer by profession
# NaN               24  I am not primarily a developer, but I write co...
# NaN               25                     I am a developer by profession
# Yearly            26                     I am a developer by profession
# Yearly            27                     I am a developer by profession
# NaN               28                     I am a developer by profession
# Yearly            29                     I am a developer by profession
# Monthly           30                     I am a developer by profession
# NaN               31                                      None of these
# Yearly            32                     I am a developer by profession
# NaN               33                        I code primarily as a hobby
# NaN               34  I am not primarily a developer, but I write co...
# Monthly           35                     I am a developer by profession
# NaN               36  I am not primarily a developer, but I write co...
# NaN               37                     I am a developer by profession
# NaN               38                     I am a developer by profession
# NaN               39                        I code primarily as a hobby
# Monthly           40                     I am a developer by profession
# Yearly            41                     I am a developer by profession
# Monthly           42                     I am a developer by profession
# NaN               43                     I am a developer by profession
# NaN               44                        I code primarily as a hobby
# NaN               45                     I am a developer by profession
# Monthly           46                     I am a developer by profession
# NaN               47                        I code primarily as a hobby
# Yearly            48                     I am a developer by profession
# Yearly            49                     I am a developer by profession
# Monthly           50                     I am a developer by profession
#
#                                                  Employment  \
# CompFreq
# NaN                                                     NaN
# NaN                                     Employed, full-time
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
# NaN                                     Employed, full-time
# NaN                                      Student, full-time
# NaN                                      Student, part-time
# NaN                      Not employed, but looking for work
# Yearly                                  Employed, full-time
# NaN       Independent contractor, freelancer, or self-em...
# Yearly                                  Employed, full-time
# Yearly    Employed, full-time;Independent contractor, fr...
# Yearly                                  Employed, full-time
# NaN                                     Employed, part-time
# Yearly    Employed, full-time;Independent contractor, fr...
# Weekly    Independent contractor, freelancer, or self-em...
# Monthly                                 Employed, full-time
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
# NaN                                      Student, full-time
# NaN                  Student, part-time;Employed, part-time
# Yearly                                  Employed, full-time
# Yearly                                  Employed, full-time
# NaN                                     Employed, full-time
# NaN       Independent contractor, freelancer, or self-em...
# Yearly                                  Employed, full-time
# Yearly                                  Employed, full-time
# NaN                  Not employed, and not looking for work
# Yearly                                  Employed, full-time
# Monthly   Employed, full-time;Independent contractor, fr...
# NaN                                                     NaN
# Yearly                                  Employed, full-time
# NaN                  Student, full-time;Employed, part-time
# NaN                  Student, part-time;Employed, part-time
# Monthly   Independent contractor, freelancer, or self-em...
# NaN                                      Student, full-time
# NaN                                     Employed, full-time
# NaN       Independent contractor, freelancer, or self-em...
# NaN                                      Student, full-time
# Monthly                                 Employed, full-time
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
# NaN                      Not employed, but looking for work
# NaN                  Employed, full-time;Student, part-time
# NaN                                      Student, full-time
# Monthly                                 Employed, full-time
# NaN                                      Student, full-time
# Yearly                                  Employed, full-time
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
#
#                                     RemoteWork  \
# CompFreq
# NaN                                        NaN
# NaN                               Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Monthly                           Fully remote
# NaN       Hybrid (some remote, some in-person)
# NaN                                        NaN
# NaN                                        NaN
# NaN                                        NaN
# Yearly    Hybrid (some remote, some in-person)
# NaN                               Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Yearly                            Fully remote
# Yearly    Hybrid (some remote, some in-person)
# NaN                               Fully remote
# Yearly                            Fully remote
# Weekly                            Fully remote
# Monthly   Hybrid (some remote, some in-person)
# Yearly                            Fully remote
# Monthly   Hybrid (some remote, some in-person)
# NaN                                        NaN
# NaN       Hybrid (some remote, some in-person)
# Yearly    Hybrid (some remote, some in-person)
# Yearly                            Fully remote
# NaN       Hybrid (some remote, some in-person)
# NaN                               Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Yearly    Hybrid (some remote, some in-person)
# NaN                                        NaN
# Yearly    Hybrid (some remote, some in-person)
# Monthly                           Fully remote
# NaN                                        NaN
# Yearly                            Fully remote
# NaN                             Full in-person
# NaN                             Full in-person
# Monthly                           Fully remote
# NaN                                        NaN
# NaN                               Fully remote
# NaN                               Fully remote
# NaN                                        NaN
# Monthly   Hybrid (some remote, some in-person)
# Yearly    Hybrid (some remote, some in-person)
# Monthly   Hybrid (some remote, some in-person)
# NaN                                        NaN
# NaN                             Full in-person
# NaN                                        NaN
# Monthly   Hybrid (some remote, some in-person)
# NaN                                        NaN
# Yearly                            Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Monthly                           Fully remote
#
#                                            CodingActivities  \
# CompFreq
# NaN                                                     NaN
# NaN                Hobby;Contribute to open-source projects
# Yearly                                                Hobby
# Monthly                        I don’t code outside of work
# NaN                                                   Hobby
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                         I don’t code outside of work
# NaN       Hobby;Contribute to open-source projects;Boots...
# Yearly                         I don’t code outside of work
# Yearly    Hobby;Contribute to open-source projects;Freel...
# Yearly                                                Hobby
# NaN                                                   Hobby
# Yearly                        Hobby;Freelance/contract work
# Weekly             Hobby;Contribute to open-source projects
# Monthly                                               Hobby
# Yearly                                                Hobby
# Monthly                                               Hobby
# NaN                                                     NaN
# NaN                                                   Hobby
# Yearly                         I don’t code outside of work
# Yearly             Hobby;Contribute to open-source projects
# NaN                            I don’t code outside of work
# NaN                            I don’t code outside of work
# Yearly                                                Hobby
# Yearly                         I don’t code outside of work
# NaN                                                     NaN
# Yearly             Hobby;Contribute to open-source projects
# Monthly                      Hobby;Bootstrapping a business
# NaN                                                     NaN
# Yearly                         I don’t code outside of work
# NaN                Hobby;Contribute to open-source projects
# NaN                                                   Hobby
# Monthly   Hobby;Contribute to open-source projects;Boots...
# NaN                                                     NaN
# NaN                            I don’t code outside of work
# NaN                            I don’t code outside of work
# NaN                                                     NaN
# Monthly                                               Hobby
# Yearly                        Hobby;Freelance/contract work
# Monthly                        I don’t code outside of work
# NaN                                                     NaN
# NaN                                                   Hobby
# NaN                                                     NaN
# Monthly                             Other (please specify):
# NaN                                                     NaN
# Yearly                                                Hobby
# Yearly             Hobby;Contribute to open-source projects
# Monthly                                               Hobby
#
#                                                     EdLevel  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN       Secondary school (e.g. American high school, G...
# NaN       Some college/university study without earning ...
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN       Some college/university study without earning ...
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Weekly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Monthly        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly   Secondary school (e.g. American high school, G...
# NaN       Some college/university study without earning ...
# NaN       Some college/university study without earning ...
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Yearly                                       Something else
# NaN         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN       Some college/university study without earning ...
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN                                          Something else
# Yearly      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN                                                     NaN
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN                               Primary/elementary school
# NaN       Some college/university study without earning ...
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN              Other doctoral degree (Ph.D., Ed.D., etc.)
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN       Secondary school (e.g. American high school, G...
# NaN       Secondary school (e.g. American high school, G...
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Yearly                  Associate degree (A.A., A.S., etc.)
# Monthly   Secondary school (e.g. American high school, G...
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN       Some college/university study without earning ...
# NaN       Secondary school (e.g. American high school, G...
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN       Secondary school (e.g. American high school, G...
# Yearly         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly    Some college/university study without earning ...
# Monthly   Secondary school (e.g. American high school, G...
#
#                                                   LearnCode  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Books / Physical media;Friend or family member...
# Monthly   Books / Physical media;School (i.e., Universit...
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN       Books / Physical media;School (i.e., Universit...
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN                         Online Courses or Certification
# Yearly                  On the job training;Coding Bootcamp
# NaN       Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Friend or family member...
# Yearly    Other online resources (e.g., videos, blogs, f...
# Yearly              School (i.e., University, College, etc)
# NaN       Books / Physical media;School (i.e., Universit...
# Yearly    Other online resources (e.g., videos, blogs, f...
# Weekly                               Books / Physical media
# Monthly   Books / Physical media;Other online resources ...
# Yearly    Other online resources (e.g., videos, blogs, f...
# Monthly   Books / Physical media;School (i.e., Universit...
# NaN        Books / Physical media;Coding Bootcamp;Colleague
# NaN       Books / Physical media;Other online resources ...
# Yearly                              Other (please specify):
# Yearly                               Books / Physical media
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN                                                     NaN
# Yearly    Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Other online resources ...
# NaN       Other online resources (e.g., videos, blogs, f...
# Yearly    Books / Physical media;School (i.e., Universit...
# Monthly   Books / Physical media;Other online resources ...
# NaN                                                     NaN
# Yearly    Books / Physical media;Other online resources ...
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN       Friend or family member;Other online resources...
# Monthly   Other online resources (e.g., videos, blogs, f...
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN       Books / Physical media;Other online resources ...
# NaN       Books / Physical media;Friend or family member...
# NaN       Friend or family member;Other online resources...
# Monthly   Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Other online resources ...
# Monthly   Other online resources (e.g., videos, blogs, f...
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN       Books / Physical media;Other online resources ...
# NaN                 School (i.e., University, College, etc)
# Monthly   Other online resources (e.g., videos, blogs, f...
# NaN       Other online resources (e.g., videos, blogs, f...
# Yearly    Friend or family member;Other online resources...
# Yearly    Books / Physical media;Other online resources ...
# Monthly   Other online resources (e.g., videos, blogs, f...
#
#                                             LearnCodeOnline  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Technical documentation;Blogs;Programming Game...
# Monthly                                                 NaN
# NaN       Technical documentation;Blogs;Stack Overflow;O...
# NaN                                                     NaN
# NaN               Stack Overflow;Video-based Online Courses
# NaN                                                     NaN
# Yearly                                                  NaN
# NaN       Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly                                                  NaN
# NaN                                                     NaN
# Yearly    Written Tutorials;Stack Overflow;Video-based O...
# Weekly                                                  NaN
# Monthly   Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Written Tutorials;Stac...
# Monthly                                                 NaN
# NaN                                                     NaN
# NaN       Technical documentation;Blogs;Stack Overflow;V...
# Yearly                                                  NaN
# Yearly                                                  NaN
# NaN       Blogs;Written Tutorials;Stack Overflow;Written...
# NaN                                                     NaN
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Stack Overflow;Online ...
# NaN       Technical documentation;Written Tutorials;Stac...
# Yearly                                                  NaN
# Monthly        Technical documentation;Blogs;Stack Overflow
# NaN                                                     NaN
# Yearly    Technical documentation;Blogs;Stack Overflow;O...
# NaN       Technical documentation;Online challenges (e.g...
# NaN       Technical documentation;Blogs;Written Tutorial...
# Monthly                       Technical documentation;Blogs
# NaN       Technical documentation;Blogs;Stack Overflow;O...
# NaN       Technical documentation;Blogs;Written Tutorial...
# NaN       Technical documentation;Blogs;Written Tutorial...
# NaN       Blogs;Written Tutorials;Stack Overflow;Video-b...
# Monthly   Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Monthly   Technical documentation;Blogs;Written Tutorial...
# NaN       Technical documentation;Blogs;Stack Overflow;V...
# NaN       Technical documentation;Written Tutorials;Stac...
# NaN                                                     NaN
# Monthly   Technical documentation;Video-based Online Cou...
# NaN             Technical documentation;Blogs;How-to videos
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Monthly        Technical documentation;Blogs;Stack Overflow
#
#                            LearnCodeCoursesCert YearsCode YearsCodePro  \
# CompFreq
# NaN                                         NaN       NaN          NaN
# NaN                                         NaN       NaN          NaN
# Yearly                                      NaN        14            5
# Monthly                                     NaN        20           17
# NaN                                         NaN         8            3
# NaN                                         NaN        15          NaN
# NaN                                         NaN         3          NaN
# NaN                              Coursera;Udemy         1          NaN
# Yearly                                      NaN         6            6
# NaN                                         NaN        37           30
# Yearly                                      NaN         5            2
# Yearly                                      NaN        12           10
# Yearly                                      NaN        12            5
# NaN                                         NaN        22           15
# Yearly                                      NaN        11            5
# Weekly                                      NaN         4            4
# Monthly                        Udemy;Codecademy         7            4
# Yearly                     Coursera;Pluralsight        13           10
# Monthly                                     NaN        36           22
# NaN                                         NaN         2          NaN
# NaN                                         NaN         1          NaN
# Yearly                                      NaN         5            4
# Yearly                                      NaN        25           20
# NaN                                         NaN        10            6
# NaN                                         NaN        40           40
# Yearly    Coursera;Udemy;Codecademy;edX;Udacity        16            9
# Yearly                                      NaN        10            5
# NaN                                         NaN         4          NaN
# Yearly                                      NaN        20           14
# Monthly                                     NaN        27           22
# NaN                                         NaN       NaN          NaN
# Yearly                                      NaN        24           21
# NaN                                         NaN         3          NaN
# NaN                                         NaN         8          NaN
# Monthly          Coursera;Udemy;Pluralsight;edX         6            5
# NaN                                         NaN        16          NaN
# NaN                                       Udemy        12            7
# NaN                                         NaN        19           14
# NaN                                       Other         2          NaN
# Monthly                        Udemy;Codecademy        24           18
# Yearly                                      NaN        20           15
# Monthly                  Coursera;Udemy;Udacity         3            3
# NaN                           Udemy;Pluralsight         4          NaN
# NaN                                         NaN        15          NaN
# NaN                                         NaN         6          NaN
# Monthly                                   Udemy         4            3
# NaN                                         NaN         7          NaN
# Yearly                                      NaN         6            5
# Yearly                                      NaN        40           25
# Monthly                                     NaN         7            4
#
#                                                     DevType  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Data scientist or machine learning specialist;...
# Monthly                               Developer, full-stack
# NaN       Developer, front-end;Developer, full-stack;Dev...
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                           Developer, full-stack;Student
# Yearly                                  Developer, back-end
# NaN       Developer, desktop or enterprise applications;...
# Yearly            Developer, full-stack;Developer, back-end
# Yearly                                  Engineering manager
# Yearly                                Developer, full-stack
# NaN       Developer, front-end;Developer, full-stack;Dev...
# Yearly    Developer, full-stack;Academic researcher;DevO...
# Weekly                                Developer, full-stack
# Monthly                               Developer, full-stack
# Yearly                                       Engineer, data
# Monthly   Developer, back-end;Developer, desktop or ente...
# NaN                                                     NaN
# NaN                                                 Student
# Yearly                                Developer, full-stack
# Yearly                                  Developer, back-end
# NaN                                 Other (please specify):
# NaN                                   Developer, full-stack
# Yearly                Developer, back-end;Developer, mobile
# Yearly            Developer, full-stack;Developer, back-end
# NaN                                                     NaN
# Yearly    Developer, desktop or enterprise applications;...
# Monthly                               Developer, full-stack
# NaN                                                     NaN
# Yearly                                Developer, full-stack
# NaN                                                 Student
# NaN                             Student;Academic researcher
# Monthly                                 Developer, back-end
# NaN                                                     NaN
# NaN                     Developer, back-end;Project manager
# NaN       Developer, front-end;Developer, full-stack;Dev...
# NaN                                                     NaN
# Monthly   Developer, back-end;Database administrator;Dev...
# Yearly    Developer, front-end;Engineer, data;Developer,...
# Monthly   Data scientist or machine learning specialist;...
# NaN       Developer, front-end;Developer, full-stack;Dev...
# NaN                                                     NaN
# NaN                                                     NaN
# Monthly                                Developer, front-end
# NaN                                                     NaN
# Yearly            Developer, full-stack;Developer, back-end
# Yearly    Developer, back-end;Developer, desktop or ente...
# Monthly   Developer, front-end;Developer, full-stack;Dev...
#
#                                                     OrgSize  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                   20 to 99 employees
# Monthly                                100 to 499 employees
# NaN                                      20 to 99 employees
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                         I don’t know
# NaN       Just me - I am a freelancer, sole proprietor, ...
# Yearly                                 100 to 499 employees
# Yearly                                   20 to 99 employees
# Yearly                                     2 to 9 employees
# NaN                                      20 to 99 employees
# Yearly                             5,000 to 9,999 employees
# Weekly    Just me - I am a freelancer, sole proprietor, ...
# Monthly                                    2 to 9 employees
# Yearly                             1,000 to 4,999 employees
# Monthly                                100 to 499 employees
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                   20 to 99 employees
# Yearly                                 100 to 499 employees
# NaN                                      20 to 99 employees
# NaN       Just me - I am a freelancer, sole proprietor, ...
# Yearly                                   20 to 99 employees
# Yearly                                   20 to 99 employees
# NaN                                                     NaN
# Yearly                             10,000 or more employees
# Monthly   Just me - I am a freelancer, sole proprietor, ...
# NaN                                                     NaN
# Yearly                             10,000 or more employees
# NaN                                                     NaN
# NaN                                                     NaN
# Monthly                                100 to 499 employees
# NaN                                                     NaN
# NaN                                      20 to 99 employees
# NaN       Just me - I am a freelancer, sole proprietor, ...
# NaN                                                     NaN
# Monthly                                    2 to 9 employees
# Yearly                                 100 to 499 employees
# Monthly                                  20 to 99 employees
# NaN                                                     NaN
# NaN                                                     NaN
# NaN                                                     NaN
# Monthly                                500 to 999 employees
# NaN                                                     NaN
# Yearly                             1,000 to 4,999 employees
# Yearly                                   20 to 99 employees
# Monthly                                100 to 499 employees
#
#                          PurchaseInfluence  \
# CompFreq
# NaN                                    NaN
# NaN                                    NaN
# Yearly               I have some influence
# Monthly              I have some influence
# NaN                  I have some influence
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# Yearly       I have little or no influence
# NaN       I have a great deal of influence
# Yearly       I have little or no influence
# Yearly               I have some influence
# Yearly    I have a great deal of influence
# NaN                  I have some influence
# Yearly       I have little or no influence
# Weekly    I have a great deal of influence
# Monthly              I have some influence
# Yearly               I have some influence
# Monthly      I have little or no influence
# NaN                                    NaN
# NaN                                    NaN
# Yearly               I have some influence
# Yearly               I have some influence
# NaN       I have a great deal of influence
# NaN       I have a great deal of influence
# Yearly               I have some influence
# Yearly       I have little or no influence
# NaN                                    NaN
# Yearly       I have little or no influence
# Monthly   I have a great deal of influence
# NaN                                    NaN
# Yearly               I have some influence
# NaN                                    NaN
# NaN                                    NaN
# Monthly              I have some influence
# NaN                                    NaN
# NaN                  I have some influence
# NaN       I have a great deal of influence
# NaN                                    NaN
# Monthly              I have some influence
# Yearly    I have a great deal of influence
# Monthly      I have little or no influence
# NaN                                    NaN
# NaN                                    NaN
# NaN                                    NaN
# Monthly      I have little or no influence
# NaN                                    NaN
# Yearly       I have little or no influence
# Yearly               I have some influence
# Monthly              I have some influence
#
#                                                  BuyNewTool  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                                  NaN
# Monthly                             Other (please specify):
# NaN       Start a free trial;Visit developer communities...
# NaN                                 Other (please specify):
# NaN       Start a free trial;Visit developer communities...
# NaN                                      Start a free trial
# Yearly                                                  NaN
# NaN       Start a free trial;Ask developers I know/work ...
# Yearly    Start a free trial;Visit developer communities...
# Yearly    Start a free trial;Ask developers I know/work ...
# Yearly      Visit developer communities like Stack Overflow
# NaN       Start a free trial;Ask developers I know/work ...
# Yearly    Start a free trial;Visit developer communities...
# Weekly                                   Start a free trial
# Monthly   Start a free trial;Research companies that hav...
# Yearly    Start a free trial;Ask developers I know/work ...
# Monthly   Start a free trial;Visit developer communities...
# NaN       Visit developer communities like Stack Overflo...
# NaN       Start a free trial;Visit developer communities...
# Yearly                                   Start a free trial
# Yearly    Start a free trial;Ask developers I know/work ...
# NaN       Other (please specify):;Start a free trial;Res...
# NaN                                      Start a free trial
# Yearly                      Ask developers I know/work with
# Yearly                                   Start a free trial
# NaN       Start a free trial;Visit developer communities...
# Yearly    Other (please specify):;Ask developers I know/...
# Monthly   Start a free trial;Visit developer communities...
# NaN                                                     NaN
# Yearly                              Other (please specify):
# NaN       Start a free trial;Visit developer communities...
# NaN       Visit developer communities like Stack Overflo...
# Monthly   Start a free trial;Ask developers I know/work ...
# NaN       Start a free trial;Visit developer communities...
# NaN       Start a free trial;Visit developer communities...
# NaN       Start a free trial;Ask developers I know/work ...
# NaN       Visit developer communities like Stack Overflo...
# Monthly   Start a free trial;Visit developer communities...
# Yearly    Start a free trial;Visit developer communities...
# Monthly   Visit developer communities like Stack Overflo...
# NaN       Start a free trial;Visit developer communities...
# NaN       Other (please specify):;Visit developer commun...
# NaN       Start a free trial;Visit developer communities...
# Monthly                                  Start a free trial
# NaN                                 Other (please specify):
# Yearly    Start a free trial;Visit developer communities...
# Yearly    Start a free trial;Visit developer communities...
# Monthly     Visit developer communities like Stack Overflow
#
#                                                     Country  \
# CompFreq
# NaN                                                     NaN
# NaN                                                  Canada
# Yearly    United Kingdom of Great Britain and Northern I...
# Monthly                                              Israel
# NaN                                United States of America
# NaN                                                 Germany
# NaN                                                   India
# NaN                                                   India
# Yearly                                          Netherlands
# NaN                                                 Croatia
# Yearly    United Kingdom of Great Britain and Northern I...
# Yearly                             United States of America
# Yearly                             United States of America
# NaN                                               Australia
# Yearly                             United States of America
# Weekly                                   Russian Federation
# Monthly                                      Czech Republic
# Yearly                                              Austria
# Monthly                                             Austria
# NaN                                                  Serbia
# NaN                                                 Austria
# Yearly                                                Italy
# Yearly                                               Canada
# NaN                                             Netherlands
# NaN                                                  Israel
# Yearly                                              Germany
# Yearly                             United States of America
# NaN                                                  Israel
# Yearly                             United States of America
# Monthly                                             Ireland
# NaN                                                     NaN
# Yearly                             United States of America
# NaN                                                  Canada
# NaN                                                  Israel
# Monthly                                              Poland
# NaN                                                  Israel
# NaN                                                  Canada
# NaN                                                  Israel
# NaN                                                Slovenia
# Monthly                                      Czech Republic
# Yearly                             United States of America
# Monthly                                              Israel
# NaN                                                    Iraq
# NaN                                                  Sweden
# NaN                                                 Austria
# Monthly                                          Madagascar
# NaN                                                  Norway
# Yearly                             United States of America
# Yearly                                              Germany
# Monthly                                             Germany
#
#                            Currency  CompTotal  \
# CompFreq
# NaN                             NaN        NaN
# NaN            CAD\tCanadian dollar        NaN
# Yearly          GBP\tPound sterling    32000.0
# Monthly     ILS\tIsraeli new shekel    60000.0
# NaN       USD\tUnited States dollar        NaN
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# Yearly            EUR European Euro    46000.0
# NaN              HRK\tCroatian kuna        NaN
# Yearly          GBP\tPound sterling    48000.0
# Yearly    USD\tUnited States dollar   194400.0
# Yearly    USD\tUnited States dollar    65000.0
# NaN          AUD\tAustralian dollar        NaN
# Yearly    USD\tUnited States dollar   110000.0
# Weekly           RUB\tRussian ruble        NaN
# Monthly           CZK\tCzech koruna    37000.0
# Yearly            EUR European Euro   190000.0
# Monthly           EUR European Euro     4000.0
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# Yearly            EUR European Euro    32000.0
# Yearly         CAD\tCanadian dollar   125000.0
# NaN               EUR European Euro        NaN
# NaN         ILS\tIsraeli new shekel        NaN
# Yearly            EUR European Euro    85000.0
# Yearly    USD\tUnited States dollar   106960.0
# NaN                             NaN        NaN
# Yearly    USD\tUnited States dollar   130000.0
# Monthly           EUR European Euro   130000.0
# NaN                             NaN        NaN
# Yearly    USD\tUnited States dollar   102000.0
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# Monthly           PLN\tPolish zloty    30000.0
# NaN                             NaN        NaN
# NaN            CAD\tCanadian dollar        NaN
# NaN         ILS\tIsraeli new shekel        NaN
# NaN                             NaN        NaN
# Monthly           CZK\tCzech koruna        NaN
# Yearly    USD\tUnited States dollar   130000.0
# Monthly     ILS\tIsraeli new shekel    19000.0
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# NaN                             NaN        NaN
# Monthly           EUR European Euro      400.0
# NaN                             NaN        NaN
# Yearly    USD\tUnited States dollar   135000.0
# Yearly            EUR European Euro   100000.0
# Monthly           EUR European Euro     4000.0
#
#                                      LanguageHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                   JavaScript;TypeScript
# Yearly                    C#;C++;HTML/CSS;JavaScript;Python
# Monthly                        C#;JavaScript;SQL;TypeScript
# NaN             C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# NaN                                                 C++;Lua
# NaN           C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# NaN                      C;C++;HTML/CSS;Java;JavaScript;SQL
# Yearly                                                  NaN
# NaN                                       Delphi;Java;Swift
# Yearly     Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# Yearly    C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# Yearly                 C;HTML/CSS;Rust;SQL;Swift;TypeScript
# NaN       Elixir;Erlang;HTML/CSS;JavaScript;Ruby;SQL;Typ...
# Yearly          HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# Weekly        Bash/Shell;HTML/CSS;JavaScript;SQL;TypeScript
# Monthly                                C#;Java;PHP;Python;R
# Yearly                                           Python;SQL
# Monthly                                   C#;PowerShell;SQL
# NaN                     C++;HTML/CSS;Java;JavaScript;Python
# NaN       Bash/Shell;C#;HTML/CSS;Java;JavaScript;PowerSh...
# Yearly                                Python;SQL;TypeScript
# Yearly                                    C#;SQL;TypeScript
# NaN                                                     VBA
# NaN                        C#;C++;JavaScript;PHP;TypeScript
# Yearly                 Dart;Go;Java;Kotlin;Swift;TypeScript
# Yearly       Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;SQL
# NaN                  C#;HTML/CSS;JavaScript;Rust;TypeScript
# Yearly                                                C;C++
# Monthly                        C#;JavaScript;PowerShell;SQL
# NaN                                                     NaN
# Yearly                           C#;HTML/CSS;JavaScript;SQL
# NaN                                              C++;Python
# NaN                                           C++;Go;Python
# Monthly           HTML/CSS;JavaScript;Python;SQL;TypeScript
# NaN                                           MATLAB;Python
# NaN       C#;C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL
# NaN                     HTML/CSS;JavaScript;PHP;Python;Ruby
# NaN                          HTML/CSS;JavaScript;Python;SQL
# Monthly   Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Per...
# Yearly        C#;C++;HTML/CSS;JavaScript;SQL;TypeScript;VBA
# Monthly                      Bash/Shell;HTML/CSS;Python;SQL
# NaN                     C#;HTML/CSS;JavaScript;PHP;Ruby;SQL
# NaN                                                     NaN
# NaN       Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# Monthly                               JavaScript;TypeScript
# NaN                        Bash/Shell;C;C++;Java;Lua;Python
# Yearly                   Java;JavaScript;PHP;SQL;TypeScript
# ...
# NaN                    NaN                NaN               NaN
# Yearly    1-2 times a week   1-2 times a week  1-2 times a week
# Monthly   1-2 times a week   1-2 times a week  1-2 times a week
# NaN                    NaN                NaN               NaN
# Yearly    1-2 times a week   1-2 times a week  1-2 times a week
# NaN                    NaN                NaN               NaN
# NaN                    NaN                NaN               NaN
# Monthly              Never   1-2 times a week  1-2 times a week
# NaN                    NaN                NaN               NaN
# NaN       1-2 times a week   1-2 times a week  1-2 times a week
# NaN                    NaN                NaN               NaN
# NaN                    NaN                NaN               NaN
# Monthly                NaN                NaN               NaN
# Yearly                 NaN                NaN               NaN
# Monthly   1-2 times a week   10+ times a week             Never
# NaN                    NaN                NaN               NaN
# NaN                    NaN                NaN               NaN
# NaN                    NaN                NaN               NaN
# Monthly   1-2 times a week   1-2 times a week             Never
# NaN                    NaN                NaN               NaN
# Yearly    1-2 times a week  6-10 times a week  1-2 times a week
# Yearly    1-2 times a week   3-5 times a week             Never
# Monthly              Never   1-2 times a week  1-2 times a week
#
#                        TimeSearching               TimeAnswering  \
# CompFreq
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Yearly                           NaN                         NaN
# Monthly                          NaN                         NaN
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Yearly           15-30 minutes a day      Over 120 minutes a day
# NaN                              NaN                         NaN
# Yearly                           NaN                         NaN
# Yearly           30-60 minutes a day        60-120 minutes a day
# Yearly           30-60 minutes a day  Less than 15 minutes a day
# NaN             60-120 minutes a day         30-60 minutes a day
# Yearly           30-60 minutes a day         30-60 minutes a day
# Weekly                           NaN                         NaN
# Monthly                          NaN                         NaN
# Yearly                           NaN                         NaN
# Monthly                          NaN                         NaN
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Yearly           30-60 minutes a day        60-120 minutes a day
# Yearly           30-60 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Yearly           30-60 minutes a day        60-120 minutes a day
# Yearly                           NaN                         NaN
# NaN                              NaN                         NaN
# Yearly           30-60 minutes a day         15-30 minutes a day
# Monthly          15-30 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# Yearly           30-60 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Monthly          30-60 minutes a day         30-60 minutes a day
# NaN                              NaN                         NaN
# NaN              30-60 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Monthly                          NaN                         NaN
# Yearly                           NaN                         NaN
# Monthly          30-60 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Monthly   Less than 15 minutes a day         15-30 minutes a day
# NaN                              NaN                         NaN
# Yearly           30-60 minutes a day         30-60 minutes a day
# Yearly           15-30 minutes a day  Less than 15 minutes a day
# Monthly          30-60 minutes a day         15-30 minutes a day
#
#               Onboarding                                   ProfessionalTech  \
# CompFreq
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Yearly               NaN                                                NaN
# Monthly              NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Yearly     Somewhat long  Innersource initiative;DevOps function;Microse...
# NaN                  NaN                                                NaN
# Yearly               NaN                                                NaN
# Yearly        Just right  Innersource initiative;DevOps function;Microse...
# Yearly    Somewhat short                      DevOps function;Microservices
# NaN           Very short  Continuous integration (CI) and (more often) c...
# Yearly     Somewhat long  DevOps function;Continuous integration (CI) an...
# Weekly               NaN                                                NaN
# Monthly              NaN                                                NaN
# Yearly               NaN                                                NaN
# Monthly              NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Yearly     Somewhat long                                      None of these
# Yearly     Somewhat long  DevOps function;Microservices;Continuous integ...
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Yearly    Somewhat short  DevOps function;Microservices;Continuous integ...
# Yearly               NaN                                                NaN
# NaN                  NaN                                                NaN
# Yearly     Somewhat long  Developer portal or other central places to fi...
# Monthly    Somewhat long  DevOps function;Continuous integration (CI) an...
# NaN                  NaN                                                NaN
# Yearly         Very long                                    DevOps function
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Monthly    Somewhat long  DevOps function;Developer portal or other cent...
# NaN                  NaN                                                NaN
# NaN       Somewhat short  Continuous integration (CI) and (more often) c...
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Monthly              NaN                                                NaN
# Yearly               NaN                                                NaN
# Monthly   Somewhat short                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# Monthly        Very long                                      Microservices
# NaN                  NaN                                                NaN
# Yearly     Somewhat long  DevOps function;Microservices;Developer portal...
# Yearly        Just right  Continuous integration (CI) and (more often) c...
# Monthly    Somewhat long  Continuous integration (CI) and (more often) c...
#
#          TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# CompFreq
# NaN              NaN         NaN         NaN                    NaN
# NaN              NaN         NaN         NaN               Too long
# Yearly           NaN         NaN         NaN  Appropriate in length
# Monthly          NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN               Too long
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Yearly           Yes         Yes         Yes  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Yearly           NaN         NaN         NaN  Appropriate in length
# Yearly           Yes         Yes          No              Too short
# Yearly           Yes          No         Yes  Appropriate in length
# NaN               No          No          No              Too short
# Yearly            No         Yes         Yes  Appropriate in length
# Weekly           NaN         NaN         NaN                    NaN
# Monthly          NaN         NaN         NaN  Appropriate in length
# Yearly           NaN         NaN         NaN  Appropriate in length
# Monthly          NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Yearly           Yes          No          No  Appropriate in length
# Yearly            No          No          No               Too long
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN              Too short
# Yearly           Yes          No         Yes  Appropriate in length
# Yearly           NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Yearly           Yes         Yes          No  Appropriate in length
# Monthly          Yes         Yes         Yes               Too long
# NaN              NaN         NaN         NaN                    NaN
# Yearly            No         Yes         Yes  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Monthly          Yes         Yes         Yes               Too long
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              Yes         Yes         Yes  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Monthly          NaN         NaN         NaN  Appropriate in length
# Yearly           NaN         NaN         NaN  Appropriate in length
# Monthly          NaN         Yes         Yes  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# Monthly           No         Yes         Yes               Too long
# NaN              NaN         NaN         NaN              Too short
# Yearly           Yes         Yes         Yes  Appropriate in length
# Yearly           Yes          No         Yes  Appropriate in length
# Monthly           No          No         Yes  Appropriate in length
#
#                           SurveyEase  ConvertedCompYearly
# CompFreq
# NaN                              NaN                  NaN
# NaN                        Difficult                  NaN
# Yearly    Neither easy nor difficult              40205.0
# Monthly                         Easy             215232.0
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# Yearly                          Easy              49056.0
# NaN                             Easy                  NaN
# Yearly                          Easy              60307.0
# Yearly                          Easy             194400.0
# Yearly                          Easy              65000.0
# NaN                             Easy                  NaN
# Yearly                          Easy             110000.0
# Weekly    Neither easy nor difficult                  NaN
# Monthly   Neither easy nor difficult              19224.0
# Yearly                          Easy             202623.0
# Monthly                         Easy              51192.0
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# Yearly                          Easy              34126.0
# Yearly    Neither easy nor difficult              97605.0
# NaN       Neither easy nor difficult                  NaN
# NaN                             Easy                  NaN
# Yearly    Neither easy nor difficult              90647.0
# Yearly                          Easy             106960.0
# NaN                             Easy                  NaN
# Yearly                          Easy             130000.0
# Monthly                         Easy            1663644.0
# NaN                              NaN                  NaN
# Yearly                          Easy             102000.0
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# Monthly                         Easy              83256.0
# NaN       Neither easy nor difficult                  NaN
# NaN                             Easy                  NaN
# NaN       Neither easy nor difficult                  NaN
# NaN                             Easy                  NaN
# Monthly   Neither easy nor difficult                  NaN
# Yearly                          Easy             130000.0
# Monthly   Neither easy nor difficult              68160.0
# NaN                             Easy                  NaN
# NaN       Neither easy nor difficult                  NaN
# NaN                             Easy                  NaN
# Monthly                         Easy               5124.0
# NaN       Neither easy nor difficult                  NaN
# Yearly                          Easy             135000.0
# Yearly                          Easy             106644.0
# Monthly                         Easy              51192.0

# %%
df['NEWCollabToolsWantToWorkWith'].value_counts()
# Out:
# Visual Studio Code                                                                                   8815
# Visual Studio;Visual Studio Code                                                                     2907
# Vim;Visual Studio Code                                                                               1794
# Notepad++;Visual Studio;Visual Studio Code                                                           1519
# IntelliJ;Visual Studio Code                                                                          1360
#                                                                                                      ...
# CLion;IPython/Jupyter;PyCharm;Visual Studio;Webstorm                                                    1
# Android Studio;Atom;Eclipse;IntelliJ;NetBeans;PyCharm;Qt Creator;Visual Studio;Visual Studio Code       1
# Eclipse;Notepad++;PyCharm;Qt Creator;Visual Studio;Visual Studio Code                                   1
# IntelliJ;IPython/Jupyter;PyCharm;RStudio;Spyder;Sublime Text;Vim                                        1
# Android Studio;GoLand;IntelliJ;Nano;PyCharm;Visual Studio Code;Webstorm                                 1
# Name: NEWCollabToolsWantToWorkWith, Length: 9188, dtype: int64

# %%
df['OpSysProfessional use'].value_counts()
# Out:
# Windows                                                                                    16645
# macOS                                                                                      12541
# Linux-based                                                                                10934
# Linux-based;Windows                                                                         5637
# Linux-based;macOS                                                                           4906
# Windows;Windows Subsystem for Linux (WSL)                                                   3800
# Linux-based;Windows;Windows Subsystem for Linux (WSL)                                       3003
# macOS;Windows                                                                               2327
# Linux-based;macOS;Windows                                                                   1551
# Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)                                  897
# Linux-based;Windows Subsystem for Linux (WSL)                                                712
# Windows Subsystem for Linux (WSL)                                                            586
# macOS;Windows;Windows Subsystem for Linux (WSL)                                              557
# macOS;Windows Subsystem for Linux (WSL)                                                      219
# Linux-based;macOS;Windows Subsystem for Linux (WSL)                                          206
# BSD;Linux-based                                                                              113
# BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)                              102
# BSD;Linux-based;macOS                                                                         92
# BSD                                                                                           85
# BSD;Linux-based;Windows                                                                       67
# BSD;Linux-based;macOS;Windows                                                                 55
# Linux-based;Other (please specify):                                                           52
# BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL)                                     51
# Other (please specify):                                                                       46
# Windows;Other (please specify):                                                               42
# Linux-based;Windows;Other (please specify):                                                   35
# BSD;macOS                                                                                     35
# BSD;Windows                                                                                   33
# BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):       18
# Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):                 17
# BSD;Windows;Windows Subsystem for Linux (WSL)                                                 15
# BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL)                                       15
# BSD;Linux-based;Windows Subsystem for Linux (WSL)                                             13
# Linux-based;macOS;Windows;Other (please specify):                                             11
# BSD;Windows Subsystem for Linux (WSL)                                                         10
# Windows;Windows Subsystem for Linux (WSL);Other (please specify):                              8
# BSD;Linux-based;Other (please specify):                                                        8
# Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):            7
# Linux-based;macOS;Other (please specify):                                                      7
# macOS;Other (please specify):                                                                  7
# macOS;Windows;Other (please specify):                                                          6
# BSD;macOS;Windows                                                                              6
# BSD;macOS;Windows;Windows Subsystem for Linux (WSL)                                            5
# Linux-based;Windows Subsystem for Linux (WSL);Other (please specify):                          3
# BSD;Linux-based;Windows;Other (please specify):                                                3
# BSD;Linux-based;macOS;Windows;Other (please specify):                                          3
# BSD;Other (please specify):                                                                    2
# Windows Subsystem for Linux (WSL);Other (please specify):                                      2
# BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):              2
# Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):                    1
# BSD;macOS;Windows Subsystem for Linux (WSL)                                                    1
# macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):                        1
# BSD;Linux-based;macOS;Other (please specify):                                                  1
# BSD;Windows;Other (please specify):                                                            1
# BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):                1
# Name: OpSysProfessional use, dtype: int64

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                                              1250
# Python                                                                                       962
# HTML/CSS;JavaScript                                                                          914
# HTML/CSS;JavaScript;PHP;SQL                                                                  745
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                                        570
#                                                                                             ...
# C#;Java;JavaScript;PHP;PowerShell;SQL;TypeScript                                               1
# C++;HTML/CSS;JavaScript;Python;Solidity;SQL                                                    1
# Dart;Haskell;HTML/CSS;Java;R;SQL;TypeScript                                                    1
# Bash/Shell;C;C#;Go;HTML/CSS;Java;JavaScript;Lua;Perl;PHP;Python;Ruby;Rust;SQL;TypeScript       1
# C#;JavaScript;Lua;PowerShell;SQL;TypeScript                                                    1
# Name: LanguageHaveWorkedWith, Length: 25068, dtype: int64

# %%
df['WebframeHaveWorkedWith'].value_counts()
# Out:
# React.js                                                                 1959
# Node.js                                                                  1507
# jQuery                                                                   1445
# Node.js;React.js                                                         1303
# Flask                                                                    1258
#                                                                          ...
# ASP.NET;Deno;Django;Express;Flask;jQuery;Node.js;React.js                   1
# ASP.NET;Drupal;Express;FastAPI;jQuery;Laravel;Node.js;React.js;Vue.js       1
# ASP.NET Core ;Blazor;Django;Express;Node.js;React.js                        1
# Django;Drupal;Flask;jQuery;Laravel;Node.js;React.js;Ruby on Rails           1
# Angular.js;Express;jQuery;Next.js;Node.js;Play Framework;React.js           1
# Name: WebframeHaveWorkedWith, Length: 8259, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming       18
# Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming           15
# Or, in your own words:;Non-binary, genderqueer, or gender non-conforming                 14
# Or, in your own words:;Woman                                                             13
# Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming              9
# Man;Or, in your own words:;Woman                                                          2
# Name: Gender, dtype: int64

# %%
# To sort indexes alphabetically use (.sort_index)

df.sort_index()
# Out:
#           ResponseId                                         MainBranch  \
# CompFreq
# Monthly        36763                     I am a developer by profession
# Monthly        23520                     I am a developer by profession
# Monthly        59193                     I am a developer by profession
# Monthly        59194                     I am a developer by profession
# Monthly        23509                     I am a developer by profession
# ...              ...                                                ...
# NaN            73258                              I am learning to code
# NaN            73261                     I am a developer by profession
# NaN            73263                              I am learning to code
# NaN            73266  I am not primarily a developer, but I write co...
# NaN            73268  I used to be a developer by profession, but no...
#
#                                                  Employment  \
# CompFreq
# Monthly                                 Employed, full-time
# Monthly                                 Employed, full-time
# Monthly   Employed, full-time;Independent contractor, fr...
# Monthly                                 Employed, full-time
# Monthly                                 Employed, full-time
# ...                                                     ...
# NaN                                      Student, full-time
# NaN                  Employed, full-time;Student, part-time
# NaN                  Student, full-time;Employed, part-time
# NaN                                     Employed, full-time
# NaN       Independent contractor, freelancer, or self-em...
#
#                                     RemoteWork  \
# CompFreq
# Monthly   Hybrid (some remote, some in-person)
# Monthly                         Full in-person
# Monthly                           Fully remote
# Monthly                           Fully remote
# Monthly                         Full in-person
# ...                                        ...
# NaN                                        NaN
# NaN       Hybrid (some remote, some in-person)
# NaN       Hybrid (some remote, some in-person)
# NaN       Hybrid (some remote, some in-person)
# NaN                               Fully remote
#
#                                            CodingActivities  \
# CompFreq
# Monthly                                               Hobby
# Monthly            Hobby;Contribute to open-source projects
# Monthly   Hobby;Contribute to open-source projects;Boots...
# Monthly                                               Hobby
# Monthly                        I don’t code outside of work
# ...                                                     ...
# NaN                                                     NaN
# NaN                                 School or academic work
# NaN                                 School or academic work
# NaN                           Hobby;School or academic work
# NaN       Hobby;Contribute to open-source projects;Boots...
#
#                                                     EdLevel  \
# CompFreq
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Monthly     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                     ...
# NaN       Secondary school (e.g. American high school, G...
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN       Secondary school (e.g. American high school, G...
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                   LearnCode  \
# CompFreq
# Monthly   Books / Physical media;Friend or family member...
# Monthly   Other online resources (e.g., videos, blogs, f...
# Monthly      Books / Physical media;Friend or family member
# Monthly             School (i.e., University, College, etc)
# Monthly   Books / Physical media;Other online resources ...
# ...                                                     ...
# NaN       Books / Physical media;Other online resources ...
# NaN                 School (i.e., University, College, etc)
# NaN       Other online resources (e.g., videos, blogs, f...
# NaN       Books / Physical media;Other online resources ...
# NaN       Books / Physical media;Friend or family member...
#
#                                             LearnCodeOnline  \
# CompFreq
# Monthly        Technical documentation;Blogs;Stack Overflow
# Monthly                       Technical documentation;Blogs
# Monthly                                                 NaN
# Monthly                                                 NaN
# Monthly   Technical documentation;Stack Overflow;Online ...
# ...                                                     ...
# NaN       Technical documentation;Blogs;Written Tutorial...
# NaN                                                     NaN
# NaN       Technical documentation;Written Tutorials;Stac...
# NaN       Technical documentation;Programming Games;Stac...
# NaN       Technical documentation;Blogs;Programming Game...
#
#                       LearnCodeCoursesCert YearsCode YearsCodePro  \
# CompFreq
# Monthly                                NaN        24           15
# Monthly                                NaN        14            6
# Monthly                                NaN        15           11
# Monthly                                NaN        15            8
# Monthly                              Udemy        25           21
# ...                                    ...       ...          ...
# NaN                                    NaN         7          NaN
# NaN                                    NaN         8          NaN
# NaN                                    NaN         4          NaN
# NaN       Udemy;Codecademy;Pluralsight;edX        42           33
# NaN                      Udemy;Pluralsight        16            5
#
#                                                     DevType  \
# CompFreq
# Monthly   Developer, back-end;Developer, mobile;Other (p...
# Monthly   Developer, front-end;Developer, full-stack;Dev...
# Monthly   Developer, front-end;Developer, full-stack;Dev...
# Monthly                                 Developer, back-end
# Monthly   Developer, full-stack;Developer, back-end;Deve...
# ...                                                     ...
# NaN                                                     NaN
# NaN                             Developer, back-end;Student
# NaN                            Developer, front-end;Student
# NaN       Developer, full-stack;Developer, desktop or en...
# NaN       Developer, front-end;Engineer, data;Engineer, ...
#
#                        OrgSize                 PurchaseInfluence  \
# CompFreq
# Monthly   100 to 499 employees             I have some influence
# Monthly   500 to 999 employees     I have little or no influence
# Monthly   100 to 499 employees             I have some influence
# Monthly   100 to 499 employees             I have some influence
# Monthly       2 to 9 employees             I have some influence
# ...                        ...                               ...
# NaN                        NaN                               NaN
# NaN                        NaN                               NaN
# NaN                        NaN                               NaN
# NaN         20 to 99 employees  I have a great deal of influence
# NaN                        NaN                               NaN
#
#                                                  BuyNewTool  \
# CompFreq
# Monthly   Start a free trial;Visit developer communities...
# Monthly   Research companies that have advertised on sit...
# Monthly                                                 NaN
# Monthly   Start a free trial;Visit developer communities...
# Monthly   Start a free trial;Visit developer communities...
# ...                                                     ...
# NaN       Visit developer communities like Stack Overflo...
# NaN       Visit developer communities like Stack Overflo...
# NaN                                                     NaN
# NaN       Start a free trial;Ask developers I know/work ...
# NaN       Start a free trial;Visit developer communities...
#
#                            Country                   Currency  CompTotal  \
# CompFreq
# Monthly                     France          EUR European Euro        NaN
# Monthly                  Indonesia     IDR\tIndonesian rupiah  8000000.0
# Monthly                Netherlands          EUR European Euro     9600.0
# Monthly                     Brazil        BRL\tBrazilian real        NaN
# Monthly                     Brazil        BRL\tBrazilian real        NaN
# ...                            ...                        ...        ...
# NaN                          India                        NaN        NaN
# NaN                        Belgium                        NaN        NaN
# NaN                        Germany                        NaN        NaN
# NaN       United States of America  USD\tUnited States dollar        NaN
# NaN                         Canada                        NaN        NaN
#
#                                      LanguageHaveWorkedWith  \
# CompFreq
# Monthly              C;C++;HTML/CSS;JavaScript;Python;Swift
# Monthly   Bash/Shell;HTML/CSS;Java;JavaScript;Perl;PHP;P...
# Monthly                       Go;Java;JavaScript;TypeScript
# Monthly                                  Go;Java;JavaScript
# Monthly                          C#;Delphi;HTML/CSS;PHP;SQL
# ...                                                     ...
# NaN                                            C;Python;SQL
# NaN                                                      C#
# NaN                          Assembly;C;C++;Java;TypeScript
# NaN                      HTML/CSS;JavaScript;PHP;Python;SQL
# NaN             C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                           LanguageWantToWorkWith  \
# CompFreq
# Monthly   C;C++;HTML/CSS;JavaScript;Python;Swift
# Monthly                   Objective-C;Rust;Swift
# Monthly       Go;Java;JavaScript;Rust;TypeScript
# Monthly                       Go;Java;JavaScript
# Monthly               C#;Delphi;HTML/CSS;PHP;SQL
# ...                                          ...
# NaN                                        C;C++
# NaN                                           C#
# NaN                                     C++;Java
# NaN        C#;HTML/CSS;JavaScript;PHP;Python;SQL
# NaN                   PowerShell;Rust;TypeScript
#
#                                      DatabaseHaveWorkedWith  \
# CompFreq
# Monthly                                                 NaN
# Monthly                        IBM DB2;MariaDB;MySQL;SQLite
# Monthly                    Elasticsearch;MariaDB;PostgreSQL
# Monthly                 DynamoDB;MongoDB;MySQL;Redis;SQLite
# Monthly   MySQL;PostgreSQL;Firebase Realtime Database;SQ...
# ...                                                     ...
# NaN                                                   MySQL
# NaN                                    Microsoft SQL Server
# NaN                                                     NaN
# NaN       MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# NaN                        Microsoft SQL Server;Neo4j;Redis
#
#                                      DatabaseWantToWorkWith  \
# CompFreq
# Monthly                                                 NaN
# Monthly                                          PostgreSQL
# Monthly                  Cloud Firestore;MariaDB;PostgreSQL
# Monthly                 DynamoDB;MongoDB;MySQL;Redis;SQLite
# Monthly   MySQL;PostgreSQL;Firebase Realtime Database;SQ...
# ...                                                     ...
# NaN                                                     NaN
# NaN                                    Microsoft SQL Server
# NaN                                                     NaN
# NaN       MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# NaN                                             Neo4j;Redis
#
#                           PlatformHaveWorkedWith  \
# CompFreq
# Monthly                                      NaN
# Monthly                   Managed Hosting;VMware
# Monthly                         AWS;Google Cloud
# Monthly                                      AWS
# Monthly                                 Firebase
# ...                                          ...
# NaN                                          NaN
# NaN                              Microsoft Azure
# NaN                                          NaN
# NaN       Managed Hosting;Microsoft Azure;VMware
# NaN                              Microsoft Azure
#
#                                      PlatformWantToWorkWith  \
# CompFreq
# Monthly                                                 NaN
# Monthly                                                 NaN
# Monthly                           AWS;Firebase;Google Cloud
# Monthly   AWS;Google Cloud;IBM Cloud or Watson;Microsoft...
# Monthly                                            Firebase
# ...                                                     ...
# NaN                                                     NaN
# NaN                                         Microsoft Azure
# NaN                                                     NaN
# NaN       Firebase;Linode;Managed Hosting;Microsoft Azur...
# NaN              AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                                 WebframeHaveWorkedWith  \
# CompFreq
# Monthly                                            NaN
# Monthly          Laravel;Node.js;Svelte;Symfony;Vue.js
# Monthly                                Angular;Node.js
# Monthly            Angular;Angular.js;Node.js;React.js
# Monthly                   ASP.NET Core ;Blazor;Laravel
# ...                                                ...
# NaN                                                NaN
# NaN                              ASP.NET;ASP.NET Core
# NaN                                            Node.js
# NaN                                   ASP.NET;React.js
# NaN       ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                      WebframeWantToWorkWith  \
# CompFreq
# Monthly                                                 NaN
# Monthly                                                 NaN
# Monthly                                    Node.js;React.js
# Monthly                             Node.js;React.js;Vue.js
# Monthly                        ASP.NET Core ;Blazor;Laravel
# ...                                                     ...
# NaN                                                     NaN
# NaN                                    ASP.NET Core ;Blazor
# NaN                                                     NaN
# NaN       ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# NaN                            ASP.NET Core ;Node.js;Svelte
#
#              MiscTechHaveWorkedWith  \
# CompFreq
# Monthly                         NaN
# Monthly                         NaN
# Monthly              Flutter;Spring
# Monthly                      Spring
# Monthly                         NaN
# ...                             ...
# NaN                            .NET
# NaN                            .NET
# NaN                             NaN
# NaN        .NET;Pandas;React Native
# NaN       Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# CompFreq
# Monthly                                              NaN
# Monthly                                              NaN
# Monthly                              React Native;Spring
# Monthly                                           Spring
# Monthly                                              NaN
# ...                                                  ...
# NaN                                                  NaN
# NaN                                                 .NET
# NaN                                                  NaN
# NaN       .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# NaN                                                  NaN
#
#                          ToolsTechHaveWorkedWith  \
# CompFreq
# Monthly                                      NaN
# Monthly                               Docker;npm
# Monthly                 Docker;Homebrew;npm;Yarn
# Monthly                               Docker;npm
# Monthly                                      npm
# ...                                          ...
# NaN                                          NaN
# NaN                                       Docker
# NaN                                          npm
# NaN                                          npm
# NaN       Docker;Kubernetes;npm;Pulumi;Terraform
#
#                          ToolsTechWantToWorkWith  \
# CompFreq
# Monthly                                      NaN
# Monthly                        Docker;Kubernetes
# Monthly                 Docker;Homebrew;npm;Yarn
# Monthly                Docker;npm;Terraform;Yarn
# Monthly                                      npm
# ...                                          ...
# NaN                                          NaN
# NaN                            Docker;Kubernetes
# NaN                                          NaN
# NaN                            npm;Unreal Engine
# NaN       Docker;Kubernetes;npm;Pulumi;Terraform
#
#                                NEWCollabToolsHaveWorkedWith  \
# CompFreq
# Monthly                                       Eclipse;Xcode
# Monthly                 Sublime Text;Vim;Visual Studio Code
# Monthly                      CLion;GoLand;IntelliJ;Webstorm
# Monthly       Eclipse;IntelliJ;Notepad++;Visual Studio Code
# Monthly   Notepad++;PyCharm;Visual Studio;Visual Studio ...
# ...                                                     ...
# NaN                        Visual Studio;Visual Studio Code
# NaN                        Visual Studio;Visual Studio Code
# NaN                              Eclipse;Visual Studio Code
# NaN                 Spyder;Visual Studio;Visual Studio Code
# NaN                        Visual Studio;Visual Studio Code
#
#                                NEWCollabToolsWantToWorkWith  \
# CompFreq
# Monthly                                       Eclipse;Xcode
# Monthly                                                 NaN
# Monthly                      CLion;GoLand;IntelliJ;Webstorm
# Monthly        GoLand;IntelliJ;Notepad++;Visual Studio Code
# Monthly   Notepad++;PyCharm;Visual Studio;Visual Studio ...
# ...                                                     ...
# NaN                                      Visual Studio Code
# NaN                        Visual Studio;Visual Studio Code
# NaN                       Android Studio;Visual Studio Code
# NaN                 Spyder;Visual Studio;Visual Studio Code
# NaN                               Neovim;Visual Studio Code
#
#          OpSysProfessional use                          OpSysPersonal use  \
# CompFreq
# Monthly    Linux-based;Windows                                      macOS
# Monthly            Linux-based  Windows;Windows Subsystem for Linux (WSL)
# Monthly      Linux-based;macOS                                      macOS
# Monthly            Linux-based                                Linux-based
# Monthly    Linux-based;Windows                        Linux-based;Windows
# ...                        ...                                        ...
# NaN                        NaN                                    Windows
# NaN                    Windows                                    Windows
# NaN                        NaN                        Linux-based;Windows
# NaN                    Windows                                    Windows
# NaN        Linux-based;Windows                        Linux-based;Windows
#
#          VersionControlSystem  \
# CompFreq
# Monthly         Git;Mercurial
# Monthly                   Git
# Monthly                   Git
# Monthly                   Git
# Monthly                   Git
# ...                       ...
# NaN                       Git
# NaN                       Git
# NaN                       Git
# NaN                       Git
# NaN                       Git
#
#                                               VCInteraction  \
# CompFreq
# Monthly   Code editor;Command-line;Version control hosti...
# Monthly   Command-line;Version control hosting service w...
# Monthly                                        Command-line
# Monthly                                        Command-line
# Monthly           Dedicated version control GUI application
# ...                                                     ...
# NaN                                            Command-line
# NaN       Code editor;Command-line;Version control hosti...
# NaN                                            Command-line
# NaN       Code editor;Command-line;Version control hosti...
# NaN       Code editor;Command-line;Version control hosti...
#
#           VCHostingPersonal use  VCHostingProfessional use  \
# CompFreq
# Monthly                     NaN                        NaN
# Monthly                     NaN                        NaN
# Monthly                     NaN                        NaN
# Monthly                     NaN                        NaN
# Monthly                     NaN                        NaN
# ...                         ...                        ...
# NaN                         NaN                        NaN
# NaN                         NaN                        NaN
# NaN                         NaN                        NaN
# NaN                         NaN                        NaN
# NaN                         NaN                        NaN
#
#                         OfficeStackAsyncHaveWorkedWith  \
# CompFreq
# Monthly                           Jira Work Management
# Monthly                                         Notion
# Monthly                    Jira Work Management;Notion
# Monthly                                            NaN
# Monthly                                            NaN
# ...                                                ...
# NaN                                                NaN
# NaN                                             Notion
# NaN                                             Notion
# NaN                                    Microsoft Lists
# NaN       Confluence;Jira Work Management;Trello;Wrike
#
#          OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# CompFreq
# Monthly            Jira Work Management    Mattermost;Microsoft Teams
# Monthly                             NaN                           NaN
# Monthly                          Notion        Google Chat;Slack;Zoom
# Monthly                             NaN    Microsoft Teams;Slack;Zoom
# Monthly                             NaN                   Google Chat
# ...                                 ...                           ...
# NaN                                 NaN          Microsoft Teams;Zoom
# NaN                             ClickUp          Microsoft Teams;Zoom
# NaN                              Notion                    Slack;Zoom
# NaN                     Microsoft Lists          Microsoft Teams;Zoom
# NaN                                 NaN    Microsoft Teams;Slack;Zoom
#
#          OfficeStackSyncWantToWorkWith        Blockchain  \
# CompFreq
# Monthly                            NaN  Very unfavorable
# Monthly                            NaN            Unsure
# Monthly         Google Chat;Slack;Zoom    Very favorable
# Monthly     Microsoft Teams;Slack;Zoom            Unsure
# Monthly                    Google Chat       Indifferent
# ...                                ...               ...
# NaN                                NaN  Very unfavorable
# NaN                    Microsoft Teams       Unfavorable
# NaN                                NaN            Unsure
# NaN               Microsoft Teams;Zoom  Very unfavorable
# NaN                         Slack;Zoom         Favorable
#
#                                                  NEWSOSites  \
# CompFreq
# Monthly                       Stack Overflow;Stack Exchange
# Monthly                       Stack Overflow;Stack Exchange
# Monthly                       Stack Overflow;Stack Exchange
# Monthly                       Stack Overflow;Stack Exchange
# Monthly                                      Stack Overflow
# ...                                                     ...
# NaN                           Stack Overflow;Stack Exchange
# NaN                                          Stack Overflow
# NaN                                          Stack Overflow
# NaN                           Stack Overflow;Stack Exchange
# NaN       Collectives on Stack Overflow;Stack Overflow;S...
#
#                                   SOVisitFreq                SOAccount  \
# CompFreq
# Monthly                 Daily or almost daily                      Yes
# Monthly                  A few times per week  Not sure/can't remember
# Monthly                Multiple times per day                      Yes
# Monthly                 Daily or almost daily                      Yes
# Monthly       A few times per month or weekly                       No
# ...                                       ...                      ...
# NaN       Less than once per month or monthly                      Yes
# NaN                     Daily or almost daily                      Yes
# NaN                      A few times per week                      Yes
# NaN                    Multiple times per day                      Yes
# NaN                     Daily or almost daily                      Yes
#
#                                                  SOPartFreq           SOComm  \
# CompFreq
# Monthly                 Less than once per month or monthly    Yes, somewhat
# Monthly                                                 NaN          Neutral
# Monthly                                A few times per week          Neutral
# Monthly   I have never participated in Q&A on Stack Over...    Yes, somewhat
# Monthly                                                 NaN  Yes, definitely
# ...                                                     ...              ...
# NaN                     Less than once per month or monthly   No, not at all
# NaN                     Less than once per month or monthly    Yes, somewhat
# NaN                     Less than once per month or monthly   No, not really
# NaN                     Less than once per month or monthly    Yes, somewhat
# NaN                     Less than once per month or monthly    Yes, somewhat
#
#                          Age Gender Trans                Sexuality  \
# CompFreq
# Monthly      35-44 years old    Man    No        Prefer not to say
# Monthly      25-34 years old    Man    No  Straight / Heterosexual
# Monthly      35-44 years old    Man    No  Straight / Heterosexual
# Monthly      25-34 years old    Man    No  Straight / Heterosexual
# Monthly      45-54 years old    Man    No  Straight / Heterosexual
# ...                      ...    ...   ...                      ...
# NaN       Under 18 years old    Man    No  Straight / Heterosexual
# NaN          18-24 years old    Man    No  Straight / Heterosexual
# NaN          18-24 years old    Man    No  Straight / Heterosexual
# NaN          55-64 years old    Man    No  Straight / Heterosexual
# NaN          25-34 years old    Man    No  Straight / Heterosexual
#
#                        Ethnicity      Accessibility  \
# CompFreq
# Monthly        Prefer not to say  None of the above
# Monthly                    Asian                NaN
# Monthly                  African  None of the above
# Monthly                    White  None of the above
# Monthly     White;South American  None of the above
# ...                          ...                ...
# NaN                       Indian  None of the above
# NaN                     European  None of the above
# NaN                     European  None of the above
# NaN                  Multiracial  None of the above
# NaN       Or, in your own words:  None of the above
#
#                                                MentalHealth TBranch  \
# CompFreq
# Monthly                                   Prefer not to say     Yes
# Monthly                                   None of the above     Yes
# Monthly   I have a concentration and/or memory disorder ...     Yes
# Monthly                                   None of the above     Yes
# Monthly                                   None of the above      No
# ...                                                     ...     ...
# NaN                                       None of the above     NaN
# NaN       I have a concentration and/or memory disorder ...     Yes
# NaN       I have a mood or emotional disorder (e.g., dep...     NaN
# NaN                                       None of the above     Yes
# NaN                                       None of the above     NaN
#
#                            ICorPM  WorkExp                 Knowledge_1  \
# CompFreq
# Monthly   Independent contributor     15.0                       Agree
# Monthly   Independent contributor     10.0                       Agree
# Monthly   Independent contributor     11.0                       Agree
# Monthly   Independent contributor      8.0  Neither agree nor disagree
# Monthly                       NaN      NaN                         NaN
# ...                           ...      ...                         ...
# NaN                           NaN      NaN                         NaN
# NaN       Independent contributor      3.0  Neither agree nor disagree
# NaN                           NaN      NaN                         NaN
# NaN       Independent contributor     42.0                    Disagree
# NaN                           NaN      NaN                         NaN
#
#                          Knowledge_2 Knowledge_3 Knowledge_4  \
# CompFreq
# Monthly   Neither agree nor disagree       Agree       Agree
# Monthly                        Agree    Disagree    Disagree
# Monthly                     Disagree       Agree    Disagree
# Monthly   Neither agree nor disagree       Agree       Agree
# Monthly                          NaN         NaN         NaN
# ...                              ...         ...         ...
# NaN                              NaN         NaN         NaN
# NaN                            Agree       Agree       Agree
# NaN                              NaN         NaN         NaN
# NaN       Neither agree nor disagree    Disagree       Agree
# NaN                              NaN         NaN         NaN
#
#                          Knowledge_5                 Knowledge_6  \
# CompFreq
# Monthly               Strongly agree                    Disagree
# Monthly   Neither agree nor disagree  Neither agree nor disagree
# Monthly                        Agree                    Disagree
# Monthly                        Agree                       Agree
# Monthly                          NaN                         NaN
# ...                              ...                         ...
# NaN                              NaN                         NaN
# NaN       Neither agree nor disagree                       Agree
# NaN                              NaN                         NaN
# NaN                            Agree                       Agree
# NaN                              NaN                         NaN
#
#                          Knowledge_7       Frequency_1       Frequency_2  \
# CompFreq
# Monthly            Strongly disagree  1-2 times a week  1-2 times a week
# Monthly                        Agree  1-2 times a week  1-2 times a week
# Monthly   Neither agree nor disagree             Never  1-2 times a week
# Monthly                        Agree             Never  1-2 times a week
# Monthly                          NaN               NaN               NaN
# ...                              ...               ...               ...
# NaN                              NaN               NaN               NaN
# NaN                   Strongly agree             Never  1-2 times a week
# NaN                              NaN               NaN               NaN
# NaN       Neither agree nor disagree             Never             Never
# NaN                              NaN               NaN               NaN
#
#                Frequency_3        TimeSearching               TimeAnswering  \
# CompFreq
# Monthly   1-2 times a week  15-30 minutes a day  Less than 15 minutes a day
# Monthly   1-2 times a week  30-60 minutes a day      Over 120 minutes a day
# Monthly              Never  30-60 minutes a day         15-30 minutes a day
# Monthly              Never  30-60 minutes a day         30-60 minutes a day
# Monthly                NaN                  NaN                         NaN
# ...                    ...                  ...                         ...
# NaN                    NaN                  NaN                         NaN
# NaN       1-2 times a week  15-30 minutes a day         30-60 minutes a day
# NaN                    NaN                  NaN                         NaN
# NaN                  Never  30-60 minutes a day        60-120 minutes a day
# NaN                    NaN                  NaN                         NaN
#
#              Onboarding                                   ProfessionalTech  \
# CompFreq
# Monthly   Somewhat long                                      None of these
# Monthly             NaN                                      None of these
# Monthly      Just right  Continuous integration (CI) and (more often) c...
# Monthly   Somewhat long  DevOps function;Microservices;Developer portal...
# Monthly             NaN                                                NaN
# ...                 ...                                                ...
# NaN                 NaN                                                NaN
# NaN           Very long  DevOps function;Developer portal or other cent...
# NaN                 NaN                                                NaN
# NaN          Just right                                      None of these
# NaN                 NaN                                                NaN
#
#          TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# CompFreq
# Monthly           No         Yes         Yes  Appropriate in length
# Monthly           No          No          No  Appropriate in length
# Monthly           No          No         Yes               Too long
# Monthly          Yes         Yes         Yes               Too long
# Monthly          NaN         NaN         NaN  Appropriate in length
# ...              ...         ...         ...                    ...
# NaN              NaN         NaN         NaN              Too short
# NaN               No          No         Yes  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
# NaN               No          No          No  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
#
#                           SurveyEase  ConvertedCompYearly
# CompFreq
# Monthly   Neither easy nor difficult                  NaN
# Monthly   Neither easy nor difficult               6552.0
# Monthly   Neither easy nor difficult             122856.0
# Monthly   Neither easy nor difficult                  NaN
# Monthly                         Easy                  NaN
# ...                              ...                  ...
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
# NaN       Neither easy nor difficult                  NaN
# NaN                             Easy                  NaN
# NaN                             Easy                  NaN
#
# [73268 rows x 78 columns]

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %% [markdown]
# ## Filtering  - using conditionals to fiolter Rows and columns

# %%
poo
# Out:
#               Email           name  weekly intake favourite car
# 0   bri01@gmail.com  Brian Michael              5        Bently
# 1  owen66@gmail.com     Owen Kelly              6       Buggati
# 2  pang02@gmail.com    Candy Pange              9      Mercedes

# %%
# Filtering the data by the country in which respondents are located

dus =(df['Country'] == 'South Africa')
df.loc[dus]
# Out:
#           ResponseId                                         MainBranch  \
# CompFreq
# NaN              101                        I code primarily as a hobby
# Yearly           343                     I am a developer by profession
# Yearly           625                     I am a developer by profession
# Yearly          1035                     I am a developer by profession
# Yearly          1074                     I am a developer by profession
# ...              ...                                                ...
# Yearly         71941                     I am a developer by profession
# NaN            71953                     I am a developer by profession
# Yearly         72002  I am not primarily a developer, but I write co...
# Monthly        72256                     I am a developer by profession
# Monthly        72707  I am not primarily a developer, but I write co...
#
#                                                  Employment  \
# CompFreq
# NaN                                      Student, full-time
# Yearly                                  Employed, full-time
# Yearly    Employed, full-time;Independent contractor, fr...
# Yearly    Employed, full-time;Independent contractor, fr...
# Yearly                                  Employed, full-time
# ...                                                     ...
# Yearly                                  Employed, full-time
# NaN       Student, full-time;Not employed, but looking f...
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
# Monthly                                 Employed, full-time
#
#                                     RemoteWork  \
# CompFreq
# NaN                                        NaN
# Yearly                            Fully remote
# Yearly                            Fully remote
# Yearly                            Fully remote
# Yearly                            Fully remote
# ...                                        ...
# Yearly    Hybrid (some remote, some in-person)
# NaN                               Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Monthly   Hybrid (some remote, some in-person)
# Monthly                           Fully remote
#
#                                           CodingActivities  \
# CompFreq
# NaN                                                    NaN
# Yearly                                               Hobby
# Yearly            Hobby;Contribute to open-source projects
# Yearly                      Hobby;Bootstrapping a business
# Yearly            Hobby;Contribute to open-source projects
# ...                                                    ...
# Yearly                                               Hobby
# NaN       Bootstrapping a business;Freelance/contract work
# Yearly                        I don’t code outside of work
# Monthly                      Hobby;Freelance/contract work
# Monthly                      Hobby;School or academic work
#
#                                                   EdLevel  \
# CompFreq
# NaN                             Primary/elementary school
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                   ...
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly         Other doctoral degree (Ph.D., Ed.D., etc.)
# Monthly      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Monthly      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                   LearnCode  \
# CompFreq
# NaN       Other online resources (e.g., videos, blogs, f...
# Yearly    Other online resources (e.g., videos, blogs, f...
# Yearly    Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Friend or family member...
# ...                                                     ...
# Yearly    Books / Physical media;Other online resources ...
# NaN       Books / Physical media;Other online resources ...
# Yearly    Books / Physical media;Friend or family member...
# Monthly   Other online resources (e.g., videos, blogs, f...
# Monthly             School (i.e., University, College, etc)
#
#                                             LearnCodeOnline  \
# CompFreq
# NaN       Blogs;Written Tutorials;Stack Overflow;Video-b...
# Yearly    Technical documentation;Programming Games;Writ...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Written Tutorials;Stac...
# ...                                                     ...
# Yearly         Technical documentation;Blogs;Stack Overflow
# NaN       Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Stack Overflow;O...
# Monthly   Technical documentation;Blogs;Programming Game...
# Monthly                                                 NaN
#
#          LearnCodeCoursesCert YearsCode YearsCodePro  \
# CompFreq
# NaN                       NaN        11          NaN
# Yearly                    NaN        30           21
# Yearly                    NaN        20           15
# Yearly                    NaN         7            4
# Yearly                    NaN        26            8
# ...                       ...       ...          ...
# Yearly                    NaN        25           16
# NaN                     Other         7          NaN
# Yearly                    NaN        37           15
# Monthly                   NaN        14           10
# Monthly                   NaN         8            2
#
#                                                     DevType  \
# CompFreq
# NaN                                                     NaN
# Yearly                                Developer, full-stack
# Yearly    Developer, full-stack;Developer, back-end;Bloc...
# Yearly    Developer, full-stack;Developer, mobile;Databa...
# Yearly    Engineer, data;Developer, full-stack;Engineeri...
# ...                                                     ...
# Yearly                Developer, mobile;Engineering manager
# NaN       Developer, front-end;Developer, full-stack;Dev...
# Yearly    Data scientist or machine learning specialist;...
# Monthly                                 Developer, back-end
# Monthly       Data scientist or machine learning specialist
#
#                            OrgSize                 PurchaseInfluence  \
# CompFreq
# NaN                            NaN                               NaN
# Yearly    5,000 to 9,999 employees     I have little or no influence
# Yearly        100 to 499 employees     I have little or no influence
# Yearly        100 to 499 employees             I have some influence
# Yearly          20 to 99 employees  I have a great deal of influence
# ...                            ...                               ...
# Yearly        100 to 499 employees  I have a great deal of influence
# NaN                            NaN                               NaN
# Yearly    5,000 to 9,999 employees             I have some influence
# Monthly           2 to 9 employees     I have little or no influence
# Monthly       100 to 499 employees     I have little or no influence
#
#                                                  BuyNewTool       Country  \
# CompFreq
# NaN                                                     NaN  South Africa
# Yearly    Start a free trial;Visit developer communities...  South Africa
# Yearly    Start a free trial;Visit developer communities...  South Africa
# Yearly    Visit developer communities like Stack Overflo...  South Africa
# Yearly    Start a free trial;Ask developers I know/work ...  South Africa
# ...                                                     ...           ...
# Yearly    Start a free trial;Visit developer communities...  South Africa
# NaN                                      Start a free trial  South Africa
# Yearly    Start a free trial;Visit developer communities...  South Africa
# Monthly   Start a free trial;Visit developer communities...  South Africa
# Monthly   Start a free trial;Visit developer communities...  South Africa
#
#                            Currency  CompTotal  \
# CompFreq
# NaN                             NaN        NaN
# Yearly      ZAR\tSouth African rand   900000.0
# Yearly    USD\tUnited States dollar   115000.0
# Yearly      ZAR\tSouth African rand   624000.0
# Yearly      ZAR\tSouth African rand  2600000.0
# ...                             ...        ...
# Yearly      ZAR\tSouth African rand  1040000.0
# NaN                             NaN        NaN
# Yearly      ZAR\tSouth African rand   900000.0
# Monthly     ZAR\tSouth African rand    88000.0
# Monthly     ZAR\tSouth African rand    31000.0
#
#                                     LanguageHaveWorkedWith  \
# CompFreq
# NaN                                         APL;C++;Python
# Yearly         Bash/Shell;HTML/CSS;JavaScript;PHP;Rust;SQL
# Yearly             C++;HTML/CSS;JavaScript;Rust;TypeScript
# Yearly                   Dart;HTML/CSS;Java;JavaScript;SQL
# Yearly     Bash/Shell;Clojure;HTML/CSS;Java;JavaScript;SQL
# ...                                                    ...
# Yearly    Bash/Shell;C#;Dart;Java;Objective-C;Python;Swift
# NaN                               C#;JavaScript;TypeScript
# Yearly                                                 SQL
# Monthly                                  Clojure;Go;Python
# Monthly                                              R;SQL
#
#                                      LanguageWantToWorkWith  \
# CompFreq
# NaN       APL;Assembly;Bash/Shell;C;C++;Haskell;LISP;Per...
# Yearly          Bash/Shell;HTML/CSS;JavaScript;PHP;Rust;SQL
# Yearly                               Elixir;Rust;TypeScript
# Yearly         Dart;HTML/CSS;Java;JavaScript;SQL;TypeScript
# Yearly                 Clojure;HTML/CSS;Java;JavaScript;SQL
# ...                                                     ...
# Yearly              Bash/Shell;Dart;Kotlin;Swift;TypeScript
# NaN                                          C++;Rust;Swift
# Yearly                              Bash/Shell;Python;R;SQL
# Monthly                                        Clojure;Rust
# Monthly                                        Python;R;SQL
#
#                                      DatabaseHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# Yearly                                       MariaDB;Oracle
# Yearly                              PostgreSQL;Redis;SQLite
# Yearly                                   MongoDB;PostgreSQL
# Yearly                     Cloud Firestore;MySQL;PostgreSQL
# ...                                                     ...
# Yearly                    Firebase Realtime Database;SQLite
# NaN       CouchDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# Yearly                                                  NaN
# Monthly                                            DynamoDB
# Monthly                         Microsoft SQL Server;SQLite
#
#                                 DatabaseWantToWorkWith  \
# CompFreq
# NaN                                                NaN
# Yearly                                         MariaDB
# Yearly                               PostgreSQL;SQLite
# Yearly           PostgreSQL;Firebase Realtime Database
# Yearly                Cloud Firestore;MySQL;PostgreSQL
# ...                                                ...
# Yearly    PostgreSQL;Firebase Realtime Database;SQLite
# NaN                                                NaN
# Yearly                                             NaN
# Monthly                                          Redis
# Monthly                    Microsoft SQL Server;SQLite
#
#              PlatformHaveWorkedWith  \
# CompFreq
# NaN                             NaN
# Yearly              Microsoft Azure
# Yearly                          NaN
# Yearly                          AWS
# Yearly                 Google Cloud
# ...                             ...
# Yearly    AWS;Firebase;Google Cloud
# NaN                      AWS;Heroku
# Yearly                          NaN
# Monthly                         AWS
# Monthly                         NaN
#
#                                 PlatformWantToWorkWith  \
# CompFreq
# NaN                                                NaN
# Yearly                                 Microsoft Azure
# Yearly                                             NaN
# Yearly                                    AWS;Firebase
# Yearly                                    Google Cloud
# ...                                                ...
# Yearly                                             NaN
# NaN       DigitalOcean;Firebase;Linode;Microsoft Azure
# Yearly                                             NaN
# Monthly                                            NaN
# Monthly                                            NaN
#
#                            WebframeHaveWorkedWith  \
# CompFreq
# NaN                                           NaN
# Yearly                      Node.js;Svelte;Vue.js
# Yearly                                   React.js
# Yearly            Next.js;Node.js;React.js;Vue.js
# Yearly    Express;Gatsby;Next.js;Node.js;React.js
# ...                                           ...
# Yearly                                        NaN
# NaN              Express;Next.js;Node.js;React.js
# Yearly                                        NaN
# Monthly                                       NaN
# Monthly                                       NaN
#
#                     WebframeWantToWorkWith     MiscTechHaveWorkedWith  \
# CompFreq
# NaN                                    NaN                        NaN
# Yearly               Node.js;Svelte;Vue.js                        NaN
# Yearly                             Phoenix                        NaN
# Yearly            Next.js;Node.js;React.js                    Flutter
# Yearly    Express;Next.js;Node.js;React.js                        NaN
# ...                                    ...                        ...
# Yearly                                 NaN                    Flutter
# NaN                                    NaN      Electron;React Native
# Yearly                                 NaN                        NaN
# Monthly                                NaN  Apache Kafka;NumPy;Pandas
# Monthly                                NaN                  Tidyverse
#
#                                      MiscTechWantToWorkWith  \
# CompFreq
# NaN                                                     NaN
# Yearly                                                  NaN
# Yearly                                                  NaN
# Yearly                 Electron;Flutter;React Native;Spring
# Yearly                                                  NaN
# ...                                                     ...
# Yearly                                              Flutter
# NaN                                      Flutter;TensorFlow
# Yearly                                                  NaN
# Monthly                                        Apache Kafka
# Monthly   Keras;NumPy;Pandas;Scikit-learn;Tidyverse;Tens...
#
#                  ToolsTechHaveWorkedWith        ToolsTechWantToWorkWith  \
# CompFreq
# NaN                                  NaN                            NaN
# Yearly                               npm                            npm
# Yearly                            Docker                         Docker
# Yearly                               npm                     Kubernetes
# Yearly    Docker;Homebrew;Kubernetes;npm     Docker;Homebrew;Kubernetes
# ...                                  ...                            ...
# Yearly                            Docker              Docker;Kubernetes
# NaN                    Homebrew;npm;Yarn  Docker;Unity 3D;Unreal Engine
# Yearly                               NaN                            NaN
# Monthly                  Docker;Homebrew              Docker;Kubernetes
# Monthly                              NaN                            NaN
#
#                                NEWCollabToolsHaveWorkedWith  \
# CompFreq
# NaN                                         Atom;Neovim;Vim
# Yearly                IntelliJ;Notepad++;Visual Studio Code
# Yearly                  Emacs;Neovim;Vim;Visual Studio Code
# Yearly           Android Studio;IntelliJ;Visual Studio Code
# Yearly                Emacs;Sublime Text;Visual Studio Code
# ...                                                     ...
# Yearly          Android Studio;Vim;Visual Studio Code;Xcode
# NaN       Atom;CLion;Emacs;IntelliJ;Neovim;Vim;Visual St...
# Yearly                                        Emacs;RStudio
# Monthly                                               Emacs
# Monthly                          RStudio;Visual Studio Code
#
#                    NEWCollabToolsWantToWorkWith  \
# CompFreq
# NaN                                      Neovim
# Yearly    IntelliJ;Notepad++;Visual Studio Code
# Yearly      Emacs;Neovim;Vim;Visual Studio Code
# Yearly              IntelliJ;Visual Studio Code
# Yearly    Emacs;Sublime Text;Visual Studio Code
# ...                                         ...
# Yearly    Android Studio;Vim;Visual Studio Code
# NaN                        Android Studio;Xcode
# Yearly    Emacs;IPython/Jupyter;PyCharm;RStudio
# Monthly                                   Emacs
# Monthly                 IPython/Jupyter;RStudio
#
#                       OpSysProfessional use          OpSysPersonal use  \
# CompFreq
# NaN                             Linux-based                Linux-based
# Yearly    Windows Subsystem for Linux (WSL)                    Windows
# Yearly                    Linux-based;macOS  Linux-based;macOS;Windows
# Yearly                        macOS;Windows              macOS;Windows
# Yearly                    Linux-based;macOS                      macOS
# ...                                     ...                        ...
# Yearly                          Linux-based                Linux-based
# NaN                                   macOS                      macOS
# Yearly                              Windows              macOS;Windows
# Monthly                               macOS                Linux-based
# Monthly                             Windows                    Windows
#
#          VersionControlSystem  \
# CompFreq
# NaN                       Git
# Yearly                    Git
# Yearly                    Git
# Yearly                    Git
# Yearly                    Git
# ...                       ...
# Yearly                    Git
# NaN                       Git
# Yearly                    Git
# Monthly                   Git
# Monthly       I don't use one
#
#                                               VCInteraction  \
# CompFreq
# NaN                                            Command-line
# Yearly                             Code editor;Command-line
# Yearly                                         Command-line
# Yearly                             Code editor;Command-line
# Yearly                             Code editor;Command-line
# ...                                                     ...
# Yearly    Code editor;Command-line;Version control hosti...
# NaN                                Code editor;Command-line
# Yearly    Code editor;Dedicated version control GUI appl...
# Monthly                            Code editor;Command-line
# Monthly                                                 NaN
#
#           VCHostingPersonal use  VCHostingProfessional use  \
# CompFreq
# NaN                         NaN                        NaN
# Yearly                      NaN                        NaN
# Yearly                      NaN                        NaN
# Yearly                      NaN                        NaN
# Yearly                      NaN                        NaN
# ...                         ...                        ...
# Yearly                      NaN                        NaN
# NaN                         NaN                        NaN
# Yearly                      NaN                        NaN
# Monthly                     NaN                        NaN
# Monthly                     NaN                        NaN
#
#             OfficeStackAsyncHaveWorkedWith   OfficeStackAsyncWantToWorkWith  \
# CompFreq
# NaN                                    NaN                              NaN
# Yearly                                 NaN                              NaN
# Yearly                               Asana                              NaN
# Yearly                Jira Work Management             Jira Work Management
# Yearly                       Notion;Trello                           Notion
# ...                                    ...                              ...
# Yearly     Stack Overflow for Teams;Trello  Stack Overflow for Teams;Trello
# NaN       ClickUp;monday.com;Notion;Trello                              NaN
# Yearly                                 NaN                              NaN
# Monthly                           Airtable                         Airtable
# Monthly                  Microsoft Planner                              NaN
#
#          OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# CompFreq
# NaN                               Zoom                           NaN
# Yearly                 Microsoft Teams               Microsoft Teams
# Yearly      Mattermost;Rocketchat;Zoom                           NaN
# Yearly           Microsoft Teams;Slack                         Slack
# Yearly      Microsoft Teams;Slack;Zoom                         Slack
# ...                                ...                           ...
# Yearly      Microsoft Teams;Slack;Zoom                         Slack
# NaN                                NaN                           NaN
# Yearly            Microsoft Teams;Zoom                          Zoom
# Monthly         Google Chat;Slack;Zoom                           NaN
# Monthly                Microsoft Teams               Microsoft Teams
#
#                 Blockchain                                         NEWSOSites  \
# CompFreq
# NaN              Favorable                      Stack Overflow;Stack Exchange
# Yearly    Very unfavorable                      Stack Overflow;Stack Exchange
# Yearly      Very favorable                      Stack Overflow;Stack Exchange
# Yearly         Unfavorable                                     Stack Overflow
# Yearly           Favorable                                     Stack Overflow
# ...                    ...                                                ...
# Yearly         Unfavorable  Stack Overflow for Teams (private knowledge sh...
# NaN            Indifferent                      Stack Overflow;Stack Exchange
# Yearly              Unsure                      Stack Overflow;Stack Exchange
# Monthly   Very unfavorable                      Stack Overflow;Stack Exchange
# Monthly        Indifferent                      Stack Overflow;Stack Exchange
#
#                                   SOVisitFreq                SOAccount  \
# CompFreq
# NaN       Less than once per month or monthly                      Yes
# Yearly                   A few times per week                      Yes
# Yearly                   A few times per week  Not sure/can't remember
# Yearly                   A few times per week                      Yes
# Yearly        A few times per month or weekly  Not sure/can't remember
# ...                                       ...                      ...
# Yearly                   A few times per week                      Yes
# NaN           A few times per month or weekly                      Yes
# Yearly                   A few times per week                      Yes
# Monthly                 Daily or almost daily                      Yes
# Monthly                  A few times per week                       No
#
#                                                  SOPartFreq          SOComm  \
# CompFreq
# NaN                     Less than once per month or monthly   Yes, somewhat
# Yearly    I have never participated in Q&A on Stack Over...  No, not really
# Yearly                                                  NaN  No, not really
# Yearly                  Less than once per month or monthly         Neutral
# Yearly                                                  NaN         Neutral
# ...                                                     ...             ...
# Yearly                  Less than once per month or monthly   Yes, somewhat
# NaN       I have never participated in Q&A on Stack Over...         Neutral
# Yearly                      A few times per month or weekly   Yes, somewhat
# Monthly   I have never participated in Q&A on Stack Over...         Neutral
# Monthly                                                 NaN  No, not at all
#
#                          Age Gender Trans                         Sexuality  \
# CompFreq
# NaN       Under 18 years old    Man    No           Straight / Heterosexual
# Yearly       35-44 years old    Man    No           Straight / Heterosexual
# Yearly       35-44 years old    Man    No           Straight / Heterosexual
# Yearly       25-34 years old    Man    No           Straight / Heterosexual
# Yearly       35-44 years old    Man    No           Straight / Heterosexual
# ...                      ...    ...   ...                               ...
# Yearly       35-44 years old    Man    No           Straight / Heterosexual
# NaN          25-34 years old    Man    No  Bisexual;Straight / Heterosexual
# Yearly       45-54 years old    Man    No                    Gay or Lesbian
# Monthly      25-34 years old    Man    No           Straight / Heterosexual
# Monthly      25-34 years old    Man    No           Straight / Heterosexual
#
#                        Ethnicity      Accessibility  \
# CompFreq
# NaN               White;European  None of the above
# Yearly            White;European  None of the above
# Yearly             White;African  None of the above
# Yearly                     White  None of the above
# Yearly            White;European  None of the above
# ...                          ...                ...
# Yearly    White;European;African  None of the above
# NaN                African;Black  None of the above
# Yearly                     White  None of the above
# Monthly           White;Biracial  None of the above
# Monthly                    White  None of the above
#
#                                                MentalHealth TBranch  \
# CompFreq
# NaN       I have a concentration and/or memory disorder ...     NaN
# Yearly    I have a concentration and/or memory disorder ...     Yes
# Yearly    I have a mood or emotional disorder (e.g., dep...      No
# Yearly                                    None of the above      No
# Yearly                                    None of the above     Yes
# ...                                                     ...     ...
# Yearly                                    None of the above     Yes
# NaN                              I have an anxiety disorder     NaN
# Yearly    I have a mood or emotional disorder (e.g., dep...     Yes
# Monthly   I have a concentration and/or memory disorder ...     Yes
# Monthly                                   None of the above     Yes
#
#                            ICorPM  WorkExp     Knowledge_1  \
# CompFreq
# NaN                           NaN      NaN             NaN
# Yearly    Independent contributor     21.0           Agree
# Yearly                        NaN      NaN             NaN
# Yearly                        NaN      NaN             NaN
# Yearly             People manager     20.0  Strongly agree
# ...                           ...      ...             ...
# Yearly    Independent contributor     16.0  Strongly agree
# NaN                           NaN      NaN             NaN
# Yearly             People manager     12.0           Agree
# Monthly   Independent contributor     12.0           Agree
# Monthly   Independent contributor      1.0        Disagree
#
#                          Knowledge_2                 Knowledge_3  \
# CompFreq
# NaN                              NaN                         NaN
# Yearly                         Agree  Neither agree nor disagree
# Yearly                           NaN                         NaN
# Yearly                           NaN                         NaN
# Yearly             Strongly disagree              Strongly agree
# ...                              ...                         ...
# Yearly                Strongly agree  Neither agree nor disagree
# NaN                              NaN                         NaN
# Yearly                         Agree  Neither agree nor disagree
# Monthly                        Agree  Neither agree nor disagree
# Monthly   Neither agree nor disagree           Strongly disagree
#
#                          Knowledge_4     Knowledge_5  \
# CompFreq
# NaN                              NaN             NaN
# Yearly                      Disagree        Disagree
# Yearly                           NaN             NaN
# Yearly                           NaN             NaN
# Yearly                Strongly agree  Strongly agree
# ...                              ...             ...
# Yearly                      Disagree        Disagree
# NaN                              NaN             NaN
# Yearly    Neither agree nor disagree           Agree
# Monthly                     Disagree           Agree
# Monthly                     Disagree        Disagree
#
#                          Knowledge_6                 Knowledge_7  \
# CompFreq
# NaN                              NaN                         NaN
# Yearly                         Agree                       Agree
# Yearly                           NaN                         NaN
# Yearly                           NaN                         NaN
# Yearly    Neither agree nor disagree           Strongly disagree
# ...                              ...                         ...
# Yearly    Neither agree nor disagree  Neither agree nor disagree
# NaN                              NaN                         NaN
# Yearly    Neither agree nor disagree  Neither agree nor disagree
# Monthly                        Agree                       Agree
# Monthly                        Agree                       Agree
#
#                Frequency_1        Frequency_2       Frequency_3  \
# CompFreq
# NaN                    NaN                NaN               NaN
# Yearly    1-2 times a week   3-5 times a week  1-2 times a week
# Yearly                 NaN                NaN               NaN
# Yearly                 NaN                NaN               NaN
# Yearly    3-5 times a week  6-10 times a week  1-2 times a week
# ...                    ...                ...               ...
# Yearly    1-2 times a week   3-5 times a week             Never
# NaN                    NaN                NaN               NaN
# Yearly    3-5 times a week   3-5 times a week  3-5 times a week
# Monthly   3-5 times a week  6-10 times a week  1-2 times a week
# Monthly   1-2 times a week              Never  1-2 times a week
#
#                        TimeSearching         TimeAnswering     Onboarding  \
# CompFreq
# NaN                              NaN                   NaN            NaN
# Yearly           30-60 minutes a day   30-60 minutes a day      Very long
# Yearly                           NaN                   NaN            NaN
# Yearly                           NaN                   NaN            NaN
# Yearly    Less than 15 minutes a day   30-60 minutes a day  Somewhat long
# ...                              ...                   ...            ...
# Yearly    Less than 15 minutes a day   15-30 minutes a day     Just right
# NaN                              NaN                   NaN            NaN
# Yearly           30-60 minutes a day   30-60 minutes a day     Just right
# Monthly         60-120 minutes a day  60-120 minutes a day      Very long
# Monthly          15-30 minutes a day   15-30 minutes a day  Somewhat long
#
#                                            ProfessionalTech TrueFalse_1  \
# CompFreq
# NaN                                                     NaN         NaN
# Yearly                        DevOps function;Microservices          No
# Yearly                                                  NaN         NaN
# Yearly                                                  NaN         NaN
# Yearly    DevOps function;Microservices;Developer portal...         Yes
# ...                                                     ...         ...
# Yearly    Microservices;Developer portal or other centra...         Yes
# NaN                                                     NaN         NaN
# Yearly                                        None of these         Yes
# Monthly   DevOps function;Microservices;Continuous integ...         Yes
# Monthly                                       None of these         Yes
#
#          TrueFalse_2 TrueFalse_3           SurveyLength  \
# CompFreq
# NaN              NaN         NaN  Appropriate in length
# Yearly            No         Yes              Too short
# Yearly           NaN         NaN               Too long
# Yearly           NaN         NaN  Appropriate in length
# Yearly            No         Yes  Appropriate in length
# ...              ...         ...                    ...
# Yearly            No         Yes  Appropriate in length
# NaN              NaN         NaN  Appropriate in length
# Yearly            No         Yes  Appropriate in length
# Monthly           No         Yes  Appropriate in length
# Monthly          Yes         Yes  Appropriate in length
#
#                           SurveyEase  ConvertedCompYearly
# CompFreq
# NaN                             Easy                  NaN
# Yearly                          Easy              56897.0
# Yearly    Neither easy nor difficult             115000.0
# Yearly                          Easy              39449.0
# Yearly                          Easy             164370.0
# ...                              ...                  ...
# Yearly                          Easy              65748.0
# NaN                             Easy                  NaN
# Yearly                          Easy              56897.0
# Monthly                    Difficult              66756.0
# Monthly   Neither easy nor difficult              23520.0
#
# [493 rows x 78 columns]

# %%
# If you want to filter to a particular column

dus =(df['Country'] == 'Uganda')
df.loc[dus,'RemoteWork']
# Out:
# CompFreq
# NaN                                         NaN
# NaN                                Fully remote
# NaN                              Full in-person
# Monthly    Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN                                         NaN
# Monthly    Hybrid (some remote, some in-person)
# Monthly    Hybrid (some remote, some in-person)
# Monthly    Hybrid (some remote, some in-person)
# NaN                                         NaN
# Monthly                          Full in-person
# NaN                                         NaN
# Monthly                            Fully remote
# NaN        Hybrid (some remote, some in-person)
# Monthly                          Full in-person
# Monthly                          Full in-person
# Weekly                             Fully remote
# Monthly                            Fully remote
# NaN        Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN                                Fully remote
# NaN        Hybrid (some remote, some in-person)
# NaN                              Full in-person
# NaN                                         NaN
# NaN        Hybrid (some remote, some in-person)
# NaN                              Full in-person
# NaN                                         NaN
# NaN                                         NaN
# NaN        Hybrid (some remote, some in-person)
# NaN                                         NaN
# Monthly    Hybrid (some remote, some in-person)
# NaN                                         NaN
# Monthly                          Full in-person
# NaN                                         NaN
# Monthly                            Fully remote
# Monthly    Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN                              Full in-person
# NaN                                         NaN
# Monthly    Hybrid (some remote, some in-person)
# NaN        Hybrid (some remote, some in-person)
# Monthly                                     NaN
# NaN                                Fully remote
# NaN        Hybrid (some remote, some in-person)
# Monthly                          Full in-person
# Yearly     Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN        Hybrid (some remote, some in-person)
# Monthly    Hybrid (some remote, some in-person)
# Monthly                            Fully remote
# NaN                                         NaN
# NaN        Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN                                         NaN
# NaN                                         NaN
# Monthly    Hybrid (some remote, some in-person)
# NaN                                         NaN
# NaN        Hybrid (some remote, some in-person)
# Weekly                             Fully remote
# NaN        Hybrid (some remote, some in-person)
# NaN                                Fully remote
# NaN                                         NaN
# Monthly    Hybrid (some remote, some in-person)
# Name: RemoteWork, dtype: object

# %%
# filtering using ( & and |)

dus =(df['Country'] == 'Uganda') & (df['RemoteWork'] == 'Fully remote')
df.loc[dus,'LanguageHaveWorkedWith']
# Out:
# CompFreq
# NaN             HTML/CSS;Java;JavaScript;Rust;SQL;TypeScript
# Monthly       HTML/CSS;Java;JavaScript;Kotlin;SAS;TypeScript
# Weekly                    HTML/CSS;JavaScript;PHP;Python;SQL
# Monthly    Bash/Shell;HTML/CSS;JavaScript;PHP;Python;SQL;...
# NaN                      HTML/CSS;JavaScript;Ruby;TypeScript
# Monthly       HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;SQL
# NaN                           HTML/CSS;JavaScript;TypeScript
# Monthly                     JavaScript;Python;SQL;TypeScript
# Weekly             APL;C;C#;HTML/CSS;Java;JavaScript;PHP;SQL
# NaN                             Bash/Shell;C;C++;Python;Rust
# Name: LanguageHaveWorkedWith, dtype: object

# %%
# filtering those with high salaries

high_salary = (df['CompTotal'] > 70000)
df.loc[high_salary, ['Country', 'Currency','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                            Country                   Currency  \
# CompFreq
# Yearly    United States of America  USD\tUnited States dollar
# Yearly    United States of America  USD\tUnited States dollar
# Yearly                     Austria          EUR European Euro
# Yearly                      Canada       CAD\tCanadian dollar
# Yearly                     Germany          EUR European Euro
# ...                            ...                        ...
# Monthly         Russian Federation         RUB\tRussian ruble
# Yearly                   Australia     AUD\tAustralian dollar
# Yearly    United States of America  USD\tUnited States dollar
# Yearly                       India          INR\tIndian rupee
# Yearly    United States of America  USD\tUnited States dollar
#
#                                      LanguageHaveWorkedWith  CompTotal
# CompFreq
# Yearly    C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL   194400.0
# Yearly          HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala   110000.0
# Yearly                                           Python;SQL   190000.0
# Yearly                                    C#;SQL;TypeScript   125000.0
# Yearly                 Dart;Go;Java;Kotlin;Swift;TypeScript    85000.0
# ...                                                     ...        ...
# Monthly                                 Java;JavaScript;SQL   150000.0
# Yearly                                                   Go   121000.0
# Yearly                                                    R   115000.0
# Yearly                                          Go;Java;SQL  3200000.0
# Yearly            Bash/Shell;HTML/CSS;JavaScript;Python;SQL   107000.0
#
# [20183 rows x 4 columns]

# %%
# learn about the string method in pandas

# %% [markdown]
# ### Updating rows and columns -- Modifying data within Dataframes

# %% [markdown]
# ### updating the columns

# %%
dict_cream = {'email':['brimic@gmail.com','owenke@gmail.com','candpa@gmail.com'],'first': ['Brian','Owen', 'Candy'],'last':['Michael', 'Kelly','Pange'], 'weekly intake': [5,6,9], 'favourite car':['Bently','Buggati','Mercedes']}
print(dict_cream)
# Out:
# {'email': ['brimic@gmail.com', 'owenke@gmail.com', 'candpa@gmail.com'], 'first': ['Brian', 'Owen', 'Candy'], 'last': ['Michael', 'Kelly', 'Pange'], 'weekly intake': [5, 6, 9], 'favourite car': ['Bently', 'Buggati', 'Mercedes']}

# %%
poo = pd.DataFrame(dict_cream)
poo
# Out:
#               email  first     last  weekly intake favourite car
# 0  brimic@gmail.com  Brian  Michael              5        Bently
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  candpa@gmail.com  Candy    Pange              9      Mercedes

# %%
# changing columns names(.columns)

poo.columns
# Out:
# Index(['email', 'first', 'last', 'weekly intake', 'favourite car'], dtype='object')

# %%
# This only used when you want to change all the column names
poo.columns = ['EMAIL', 'FIRST', 'LAST', 'Weekly_intake', 'Favourite_car']
poo.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [56], in <cell line: 3>()
#       1 # This only used when you want to change all the column names
#       2 poo.columns = ['EMAIL', 'FIRST', 'LAST', 'Weekly_intake', 'Favourite_car']
# ----> 3 poo.column
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
# To change the column names all to uppercase

poo.columns = [x.upper() for x in poo.columns]
poo
# Out:
#               EMAIL  FIRST     LAST  WEEKLY_INTAKE FAVOURITE_CAR
# 0  brimic@gmail.com  Brian  Michael              5        Bently
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  candpa@gmail.com  Candy    Pange              9      Mercedes

# %%
# To change spaces to underscores
poo.columns = poo.columns.str.replace(' ', '_') # this won't work for us because we got no spaces on our column tittles
poo
# Out:
#               EMAIL  FIRST     LAST  WEEKLY_INTAKE FAVOURITE_CAR
# 0  brimic@gmail.com  Brian  Michael              5        Bently
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  candpa@gmail.com  Candy    Pange              9      Mercedes

# %%
# To change the uppercase to lowercase

poo.columns = [x.lower() for x in poo.columns]
poo
# Out:
#               email  first     last  weekly_intake favourite_car
# 0  brimic@gmail.com  Brian  Michael              5        Bently
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  candpa@gmail.com  Candy    Pange              9      Mercedes

# %%
# to just change specific values of the columns we will use (.rename) and pass in a dictionary

poo.rename(columns={'email_address': 'email', 'full_name': 'name'}, inplace = True)
poo
# Out:
#               email  first     last  weekly_intake favourite_car
# 0  brimic@gmail.com  Brian  Michael              5        Bently
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  candpa@gmail.com  Candy    Pange              9      Mercedes

# %% [markdown]
# ### updating rows

# %%
# to update the rows 
#This is used to change things within the rows mainly specific things

poo.loc[2, ['name', 'favourite_car']] = ['Tracy Blundo', 'Mobius']
poo
# Out:
#               email  first     last  weekly_intake favourite_car          name
# 0  brimic@gmail.com  Brian  Michael              5        Bently           NaN
# 1  owenke@gmail.com   Owen    Kelly              6       Buggati           NaN
# 2  candpa@gmail.com  Candy    Pange              9        Mobius  Tracy Blundo

# %%
# To change a single value

poo.loc[2, 'email'] = 'tracyblu@gmail.com'
poo
# Out:
#                 email  first     last  weekly_intake favourite_car  \
# 0    brimic@gmail.com  Brian  Michael              5        Bently
# 1    owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  tracyblu@gmail.com  Candy    Pange              9        Mobius
#
#            name
# 0           NaN
# 1           NaN
# 2  Tracy Blundo

# %%
# How to change multiple rows

poo
# Out:
#                 email  first     last  weekly_intake favourite_car  \
# 0    brimic@gmail.com  Brian  Michael              5        Bently
# 1    owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  tracyblu@gmail.com  Candy    Pange              9        Mobius
#
#            name
# 0           NaN
# 1           NaN
# 2  Tracy Blundo

# %%
poo
# Out:
#                 email  first     last  weekly_intake favourite_car  \
# 0    brimic@gmail.com  Brian  Michael              5        Bently
# 1    owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  tracyblu@gmail.com  Candy    Pange              9        Mobius
#
#            name
# 0           NaN
# 1           NaN
# 2  Tracy Blundo

# %% [markdown]
# # Learn Apply, map, applymap,  replace

# %%
poo['email'].apply(len)
# Out:
# 0    16
# 1    16
# 2    18
# Name: email, dtype: int64

# %% [markdown]
# ## Add/ Remove Rows and columns from dataframes

# %%
poo
# Out:
#                 email  first     last  weekly_intake favourite_car  \
# 0    brimic@gmail.com  Brian  Michael              5        Bently
# 1    owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  tracyblu@gmail.com  Candy    Pange              9        Mobius
#
#            name
# 0           NaN
# 1           NaN
# 2  Tracy Blundo

# %%
# Adding columns (use dictionaries)
# Combining two columns to form one column

poo['first'] + ' ' + poo['last']
# Out:
# 0    Brian Michael
# 1       Owen Kelly
# 2      Candy Pange
# dtype: object

# %%
poo['full_name'] = poo['first'] + ' ' + poo['last']

# %%
poo
# Out:
#                 email  first     last  weekly_intake favourite_car  \
# 0    brimic@gmail.com  Brian  Michael              5        Bently
# 1    owenke@gmail.com   Owen    Kelly              6       Buggati
# 2  tracyblu@gmail.com  Candy    Pange              9        Mobius
#
#            name      full_name
# 0           NaN  Brian Michael
# 1           NaN     Owen Kelly
# 2  Tracy Blundo    Candy Pange

# %%
# REMOVING COLUMNS (drop)

poo.drop(columns =['first','last'], inplace = True)

# %%
poo
# Out:
#                 email  weekly_intake favourite_car          name  \
# 0    brimic@gmail.com              5        Bently           NaN
# 1    owenke@gmail.com              6       Buggati           NaN
# 2  tracyblu@gmail.com              9        Mobius  Tracy Blundo
#
#        full_name
# 0  Brian Michael
# 1     Owen Kelly
# 2    Candy Pange

# %%
# SPLITING COLUMN (.str.split)
# WE WILL ALSO USE THE EXPAND FUNCTION TO MAKE THEM INTO COLUMNS(EXPAND = TRUE)


poo['full_name'].str.split(' ', expand = True)
poo[['first', 'last']] = poo['full_name'].str.split(' ', expand = True)
poo
# Out:
#                 email  weekly_intake favourite_car          name  \
# 0    brimic@gmail.com              5        Bently           NaN
# 1    owenke@gmail.com              6       Buggati           NaN
# 2  tracyblu@gmail.com              9        Mobius  Tracy Blundo
#
#        full_name  first     last
# 0  Brian Michael  Brian  Michael
# 1     Owen Kelly   Owen    Kelly
# 2    Candy Pange  Candy    Pange

# %%
# ADDING A SINGLE ROW (USE DICTIONARY)

poo.append({'first':'Tracy', 'last': 'Akinyi', 'full_name': 'Tracy Akinyi', 'favourite_car': 'Gwagon', 'weekly_intake': 8,'email': 'tracyaki@gmail.com'}, ignore_index = True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10284\765522999.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   poo.append({'first':'Tracy', 'last': 'Akinyi', 'full_name': 'Tracy Akinyi', 'favourite_car': 'Gwagon', 'weekly_intake': 8,'email': 'tracyaki@gmail.com'}, ignore_index = True)
#                 email  weekly_intake favourite_car          name  \
# 0    brimic@gmail.com              5        Bently           NaN
# 1    owenke@gmail.com              6       Buggati           NaN
# 2  tracyblu@gmail.com              9        Mobius  Tracy Blundo
# 3  tracyaki@gmail.com              8        Gwagon           NaN
#
#        full_name  first     last
# 0  Brian Michael  Brian  Michael
# 1     Owen Kelly   Owen    Kelly
# 2    Candy Pange  Candy    Pange
# 3   Tracy Akinyi  Tracy   Akinyi

# %%
poo =poo.append({'first':'Tracy', 'last': 'Akinyi', 'full_name': 'Tracy Akinyi', 'favourite_car': 'Gwagon', 'weekly_intake': 8,'email': 'tracyaki@gmail.com'}, ignore_index = True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10284\2430020464.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   poo =poo.append({'first':'Tracy', 'last': 'Akinyi', 'full_name': 'Tracy Akinyi', 'favourite_car': 'Gwagon', 'weekly_intake': 8,'email': 'tracyaki@gmail.com'}, ignore_index = True)

# %%
poo
# Out:
#                 email  weekly_intake favourite_car          name  \
# 0    brimic@gmail.com              5        Bently           NaN
# 1    owenke@gmail.com              6       Buggati           NaN
# 2  tracyblu@gmail.com              9        Mobius  Tracy Blundo
# 3  tracyaki@gmail.com              8        Gwagon           NaN
#
#        full_name  first     last
# 0  Brian Michael  Brian  Michael
# 1     Owen Kelly   Owen    Kelly
# 2    Candy Pange  Candy    Pange
# 3   Tracy Akinyi  Tracy   Akinyi

# %%
poo.drop('name', axis=1, inplace=True)

# %%
poo
# Out:
#                 email  weekly_intake favourite_car      full_name  first  \
# 0    brimic@gmail.com              5        Bently  Brian Michael  Brian
# 1    owenke@gmail.com              6       Buggati     Owen Kelly   Owen
# 2  tracyblu@gmail.com              9        Mobius    Candy Pange  Candy
# 3  tracyaki@gmail.com              8        Gwagon   Tracy Akinyi  Tracy
#
#       last
# 0  Michael
# 1    Kelly
# 2    Pange
# 3   Akinyi

# %%
#TO REMOVE ROWS (YOU WILL PASS IN THE INDEXES INSTEAD OF COLUMN USING DROP FUNCTION )

# %% [markdown]
# ## sorting data

# %%
poo
# Out:
#                 email  weekly_intake favourite_car      full_name  first  \
# 0    brimic@gmail.com              5        Bently  Brian Michael  Brian
# 1    owenke@gmail.com              6       Buggati     Owen Kelly   Owen
# 2  tracyblu@gmail.com              9        Mobius    Candy Pange  Candy
# 3  tracyaki@gmail.com              8        Gwagon   Tracy Akinyi  Tracy
#
#       last
# 0  Michael
# 1    Kelly
# 2    Pange
# 3   Akinyi

# %%
# To sort by last name

poo.sort_values(by ='last', inplace=True)
poo
# Out:
#                 email  weekly_intake favourite_car      full_name  first  \
# 3  tracyaki@gmail.com              8        Gwagon   Tracy Akinyi  Tracy
# 1    owenke@gmail.com              6       Buggati     Owen Kelly   Owen
# 0    brimic@gmail.com              5        Bently  Brian Michael  Brian
# 2  tracyblu@gmail.com              9        Mobius    Candy Pange  Candy
#
#       last
# 3   Akinyi
# 1    Kelly
# 0  Michael
# 2    Pange

# %%
# To sort in descending order

poo.sort_values(by='last', ascending=False)
# Out:
#                 email  weekly_intake favourite_car      full_name  first  \
# 2  tracyblu@gmail.com              9        Mobius    Candy Pange  Candy
# 0    brimic@gmail.com              5        Bently  Brian Michael  Brian
# 1    owenke@gmail.com              6       Buggati     Owen Kelly   Owen
# 3  tracyaki@gmail.com              8        Gwagon   Tracy Akinyi  Tracy
#
#       last
# 2    Pange
# 0  Michael
# 1    Kelly
# 3   Akinyi

# %%
# To remove the sort function you will just be required to use (.sort_index())

poo.sort_index()
# Out:
#                 email  weekly_intake favourite_car      full_name  first  \
# 0    brimic@gmail.com              5        Bently  Brian Michael  Brian
# 1    owenke@gmail.com              6       Buggati     Owen Kelly   Owen
# 2  tracyblu@gmail.com              9        Mobius    Candy Pange  Candy
# 3  tracyaki@gmail.com              8        Gwagon   Tracy Akinyi  Tracy
#
#       last
# 0  Michael
# 1    Kelly
# 2    Pange
# 3   Akinyi

# %%
df
# Out:
#           ResponseId                                         MainBranch  \
# CompFreq
# NaN                1                                      None of these
# NaN                2                     I am a developer by profession
# Yearly             3  I am not primarily a developer, but I write co...
# Monthly            4                     I am a developer by profession
# NaN                5                     I am a developer by profession
# ...              ...                                                ...
# Yearly         73264                     I am a developer by profession
# Yearly         73265                     I am a developer by profession
# NaN            73266  I am not primarily a developer, but I write co...
# Yearly         73267                     I am a developer by profession
# NaN            73268  I used to be a developer by profession, but no...
#
#                                                  Employment  \
# CompFreq
# NaN                                                     NaN
# NaN                                     Employed, full-time
# Yearly                                  Employed, full-time
# Monthly                                 Employed, full-time
# NaN                                     Employed, full-time
# ...                                                     ...
# Yearly                                  Employed, full-time
# Yearly                                  Employed, full-time
# NaN                                     Employed, full-time
# Yearly                                  Employed, full-time
# NaN       Independent contractor, freelancer, or self-em...
#
#                                     RemoteWork  \
# CompFreq
# NaN                                        NaN
# NaN                               Fully remote
# Yearly    Hybrid (some remote, some in-person)
# Monthly                           Fully remote
# NaN       Hybrid (some remote, some in-person)
# ...                                        ...
# Yearly                            Fully remote
# Yearly                          Full in-person
# NaN       Hybrid (some remote, some in-person)
# Yearly    Hybrid (some remote, some in-person)
# NaN                               Fully remote
#
#                                            CodingActivities  \
# CompFreq
# NaN                                                     NaN
# NaN                Hobby;Contribute to open-source projects
# Yearly                                                Hobby
# Monthly                        I don’t code outside of work
# NaN                                                   Hobby
# ...                                                     ...
# Yearly                              Freelance/contract work
# Yearly                                                Hobby
# NaN                           Hobby;School or academic work
# Yearly                                                Hobby
# NaN       Hobby;Contribute to open-source projects;Boots...
#
#                                                   EdLevel  \
# CompFreq
# NaN                                                   NaN
# NaN                                                   NaN
# Yearly    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Monthly      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                   ...
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# NaN          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Yearly       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# NaN          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                   LearnCode  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Books / Physical media;Friend or family member...
# Monthly   Books / Physical media;School (i.e., Universit...
# NaN       Other online resources (e.g., videos, blogs, f...
# ...                                                     ...
# Yearly    Books / Physical media;Other online resources ...
# Yearly    Other online resources (e.g., videos, blogs, f...
# NaN       Books / Physical media;Other online resources ...
# Yearly           Books / Physical media;On the job training
# NaN       Books / Physical media;Friend or family member...
#
#                                             LearnCodeOnline  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Technical documentation;Blogs;Programming Game...
# Monthly                                                 NaN
# NaN       Technical documentation;Blogs;Stack Overflow;O...
# ...                                                     ...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# Yearly    Technical documentation;Blogs;Written Tutorial...
# NaN       Technical documentation;Programming Games;Stac...
# Yearly                                                  NaN
# NaN       Technical documentation;Blogs;Programming Game...
#
#                       LearnCodeCoursesCert YearsCode YearsCodePro  \
# CompFreq
# NaN                                    NaN       NaN          NaN
# NaN                                    NaN       NaN          NaN
# Yearly                                 NaN        14            5
# Monthly                                NaN        20           17
# NaN                                    NaN         8            3
# ...                                    ...       ...          ...
# Yearly                               Udemy         8            5
# Yearly              Coursera;Udemy;Udacity         6            5
# NaN       Udemy;Codecademy;Pluralsight;edX        42           33
# Yearly                                 NaN        50           31
# NaN                      Udemy;Pluralsight        16            5
#
#                                                     DevType  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly    Data scientist or machine learning specialist;...
# Monthly                               Developer, full-stack
# NaN       Developer, front-end;Developer, full-stack;Dev...
# ...                                                     ...
# Yearly                                  Developer, back-end
# Yearly        Data scientist or machine learning specialist
# NaN       Developer, full-stack;Developer, desktop or en...
# Yearly    Developer, front-end;Developer, desktop or ent...
# NaN       Developer, front-end;Engineer, data;Engineer, ...
#
#                        OrgSize                 PurchaseInfluence  \
# CompFreq
# NaN                        NaN                               NaN
# NaN                        NaN                               NaN
# Yearly      20 to 99 employees             I have some influence
# Monthly   100 to 499 employees             I have some influence
# NaN         20 to 99 employees             I have some influence
# ...                        ...                               ...
# Yearly    100 to 499 employees             I have some influence
# Yearly            I don’t know     I have little or no influence
# NaN         20 to 99 employees  I have a great deal of influence
# Yearly      10 to 19 employees  I have a great deal of influence
# NaN                        NaN                               NaN
#
#                                                  BuyNewTool  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                                  NaN
# Monthly                             Other (please specify):
# NaN       Start a free trial;Visit developer communities...
# ...                                                     ...
# Yearly    Visit developer communities like Stack Overflo...
# Yearly    Other (please specify):;Ask developers I know/...
# NaN       Start a free trial;Ask developers I know/work ...
# Yearly    Start a free trial;Visit developer communities...
# NaN       Start a free trial;Visit developer communities...
#
#                                                     Country  \
# CompFreq
# NaN                                                     NaN
# NaN                                                  Canada
# Yearly    United Kingdom of Great Britain and Northern I...
# Monthly                                              Israel
# NaN                                United States of America
# ...                                                     ...
# Yearly                                              Nigeria
# Yearly                             United States of America
# NaN                                United States of America
# Yearly    United Kingdom of Great Britain and Northern I...
# NaN                                                  Canada
#
#                            Currency  CompTotal  \
# CompFreq
# NaN                             NaN        NaN
# NaN            CAD\tCanadian dollar        NaN
# Yearly          GBP\tPound sterling    32000.0
# Monthly     ILS\tIsraeli new shekel    60000.0
# NaN       USD\tUnited States dollar        NaN
# ...                             ...        ...
# Yearly    USD\tUnited States dollar    60000.0
# Yearly    USD\tUnited States dollar   107000.0
# NaN       USD\tUnited States dollar        NaN
# Yearly          GBP\tPound sterling    58500.0
# NaN                             NaN        NaN
#
#                                      LanguageHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                   JavaScript;TypeScript
# Yearly                    C#;C++;HTML/CSS;JavaScript;Python
# Monthly                        C#;JavaScript;SQL;TypeScript
# NaN             C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                     ...
# Yearly    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# Yearly            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# NaN                      HTML/CSS;JavaScript;PHP;Python;SQL
# Yearly                                        C#;Delphi;VBA
# NaN             C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                   LanguageWantToWorkWith  \
# CompFreq
# NaN                                                  NaN
# NaN                                      Rust;TypeScript
# Yearly             C#;C++;HTML/CSS;JavaScript;TypeScript
# Monthly                                C#;SQL;TypeScript
# NaN           C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                                  ...
# Yearly    Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# Yearly                        HTML/CSS;JavaScript;Python
# NaN                C#;HTML/CSS;JavaScript;PHP;Python;SQL
# Yearly                                            Delphi
# NaN                           PowerShell;Rust;TypeScript
#
#                                      DatabaseHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                 Microsoft SQL Server
# Monthly                                Microsoft SQL Server
# NaN       Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                     ...
# Yearly                 Elasticsearch;MySQL;PostgreSQL;Redis
# Yearly                  Elasticsearch;MongoDB;Oracle;SQLite
# NaN       MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# Yearly                  Microsoft SQL Server;MongoDB;Oracle
# NaN                        Microsoft SQL Server;Neo4j;Redis
#
#                                      DatabaseWantToWorkWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                 Microsoft SQL Server
# Monthly                                Microsoft SQL Server
# NaN       Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                     ...
# Yearly                               MySQL;PostgreSQL;Redis
# Yearly                           Elasticsearch;Neo4j;SQLite
# NaN       MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# Yearly                                                  NaN
# NaN                                             Neo4j;Redis
#
#                           PlatformHaveWorkedWith  \
# CompFreq
# NaN                                          NaN
# NaN                                          NaN
# Yearly                                       NaN
# Monthly                                      NaN
# NaN                     Firebase;Microsoft Azure
# ...                                          ...
# Yearly             AWS;DigitalOcean;Google Cloud
# Yearly                                       NaN
# NaN       Managed Hosting;Microsoft Azure;VMware
# Yearly                                       NaN
# NaN                              Microsoft Azure
#
#                                      PlatformWantToWorkWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                                  NaN
# Monthly                                                 NaN
# NaN                                Firebase;Microsoft Azure
# ...                                                     ...
# Yearly                        AWS;DigitalOcean;Google Cloud
# Yearly                                                  NaN
# NaN       Firebase;Linode;Managed Hosting;Microsoft Azur...
# Yearly                                                  NaN
# NaN              AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                                 WebframeHaveWorkedWith  \
# CompFreq
# NaN                                                NaN
# NaN                                                NaN
# Yearly                                      Angular.js
# Monthly                          ASP.NET;ASP.NET Core
# NaN       Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                                ...
# Yearly                         Express;FastAPI;Node.js
# Yearly                          FastAPI;Flask;React.js
# NaN                                   ASP.NET;React.js
# Yearly                                             NaN
# NaN       ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                      WebframeWantToWorkWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                   Angular;Angular.js
# Monthly                               ASP.NET;ASP.NET Core
# NaN                    Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                     ...
# Yearly                              Express;FastAPI;Node.js
# Yearly                                     FastAPI;React.js
# NaN       ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# Yearly                                                  NaN
# NaN                            ASP.NET Core ;Node.js;Svelte
#
#                                      MiscTechHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                               Pandas
# Monthly                                                .NET
# NaN                                                    .NET
# ...                                                     ...
# Yearly                                              Flutter
# Yearly    Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# NaN                                .NET;Pandas;React Native
# Yearly                                                  NaN
# NaN                               Apache Kafka;Apache Spark
#
#                                      MiscTechWantToWorkWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                                 .NET
# Monthly                                                .NET
# NaN                                       .NET;Apache Kafka
# ...                                                     ...
# Yearly                                                  NaN
# Yearly    NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# NaN          .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# Yearly                                                  NaN
# NaN                                                     NaN
#
#                          ToolsTechHaveWorkedWith  \
# CompFreq
# NaN                                          NaN
# NaN                                          NaN
# Yearly                                       NaN
# Monthly                                      NaN
# NaN                                          npm
# ...                                          ...
# Yearly            Docker;Homebrew;Kubernetes;npm
# Yearly                                       NaN
# NaN                                          npm
# Yearly                                       NaN
# NaN       Docker;Kubernetes;npm;Pulumi;Terraform
#
#                          ToolsTechWantToWorkWith  \
# CompFreq
# NaN                                          NaN
# NaN                                          NaN
# Yearly                                       NaN
# Monthly                                      NaN
# NaN                            Docker;Kubernetes
# ...                                          ...
# Yearly            Docker;Homebrew;Kubernetes;npm
# Yearly                                       NaN
# NaN                            npm;Unreal Engine
# Yearly                                       NaN
# NaN       Docker;Kubernetes;npm;Pulumi;Terraform
#
#                                NEWCollabToolsHaveWorkedWith  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                              Notepad++;Visual Studio
# Monthly          Notepad++;Visual Studio;Visual Studio Code
# NaN        Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                     ...
# Yearly    IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# Yearly    IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# NaN                 Spyder;Visual Studio;Visual Studio Code
# Yearly       RAD Studio (Delphi, C++ Builder);Visual Studio
# NaN                        Visual Studio;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith  \
# CompFreq
# NaN                                                  NaN
# NaN                                                  NaN
# Yearly                           Notepad++;Visual Studio
# Monthly       Notepad++;Visual Studio;Visual Studio Code
# NaN               Rider;Visual Studio;Visual Studio Code
# ...                                                  ...
# Yearly               Sublime Text;Vim;Visual Studio Code
# Yearly           Notepad++;Spyder;Vim;Visual Studio Code
# NaN              Spyder;Visual Studio;Visual Studio Code
# Yearly    RAD Studio (Delphi, C++ Builder);Visual Studio
# NaN                            Neovim;Visual Studio Code
#
#          OpSysProfessional use                  OpSysPersonal use  \
# CompFreq
# NaN                        NaN                                NaN
# NaN                      macOS  Windows Subsystem for Linux (WSL)
# Yearly                 Windows                            Windows
# Monthly                Windows                            Windows
# NaN                    Windows                      macOS;Windows
# ...                        ...                                ...
# Yearly                   macOS                  Linux-based;macOS
# Yearly     Linux-based;Windows                Linux-based;Windows
# NaN                    Windows                            Windows
# Yearly                 Windows                            Windows
# NaN        Linux-based;Windows                Linux-based;Windows
#
#                  VersionControlSystem  \
# CompFreq
# NaN                               NaN
# NaN                               Git
# Yearly                            Git
# Monthly                           Git
# NaN       Git;Other (please specify):
# ...                               ...
# Yearly                            Git
# Yearly                            Git
# NaN                               Git
# Yearly                            SVN
# NaN                               Git
#
#                                               VCInteraction  \
# CompFreq
# NaN                                                     NaN
# NaN                                                     NaN
# Yearly                                          Code editor
# Monthly   Code editor;Command-line;Version control hosti...
# NaN                                             Code editor
# ...                                                     ...
# Yearly                             Code editor;Command-line
# Yearly                             Code editor;Command-line
# NaN       Code editor;Command-line;Version control hosti...
# Yearly            Dedicated version control GUI application
# NaN       Code editor;Command-line;Version control hosti...
#
#           VCHostingPersonal use  VCHostingProfessional use  \
# CompFreq
# NaN                         NaN                        NaN
# NaN                         NaN                        NaN
# Yearly                      NaN                        NaN
# Monthly                     NaN                        NaN
# NaN                         NaN                        NaN
# ...                         ...                        ...
# Yearly                      NaN                        NaN
# Yearly                      NaN                        NaN
# NaN                         NaN                        NaN
# Yearly                      NaN                        NaN
# NaN                         NaN                        NaN
#
#                         OfficeStackAsyncHaveWorkedWith  \
# CompFreq
# NaN                                                NaN
# NaN                                                NaN
# Yearly                                             NaN
# Monthly                    Jira Work Management;Trello
# NaN                                                NaN
# ...                                                ...
# Yearly                            Jira Work Management
# Yearly                                             NaN
# NaN                                    Microsoft Lists
# Yearly                                             NaN
# NaN       Confluence;Jira Work Management;Trello;Wrike
#
#          OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# CompFreq
# NaN                                 NaN                           NaN
# NaN                                 NaN                           NaN
# Yearly                              NaN               Microsoft Teams
# Monthly     Jira Work Management;Trello                    Slack;Zoom
# NaN                                 NaN          Microsoft Teams;Zoom
# ...                                 ...                           ...
# Yearly             Jira Work Management                    Slack;Zoom
# Yearly                              NaN                    Rocketchat
# NaN                     Microsoft Lists          Microsoft Teams;Zoom
# Yearly                              NaN                          Zoom
# NaN                                 NaN    Microsoft Teams;Slack;Zoom
#
#          OfficeStackSyncWantToWorkWith        Blockchain  \
# CompFreq
# NaN                                NaN               NaN
# NaN                                NaN  Very unfavorable
# Yearly                 Microsoft Teams  Very unfavorable
# Monthly                     Slack;Zoom  Very unfavorable
# NaN                                NaN       Unfavorable
# ...                                ...               ...
# Yearly                      Slack;Zoom    Very favorable
# Yearly                             NaN            Unsure
# NaN               Microsoft Teams;Zoom  Very unfavorable
# Yearly                            Zoom       Indifferent
# NaN                         Slack;Zoom         Favorable
#
#                                                  NEWSOSites  \
# CompFreq
# NaN                                                     NaN
# NaN       Collectives on Stack Overflow;Stack Overflow f...
# Yearly    Collectives on Stack Overflow;Stack Overflow;S...
# Monthly   Collectives on Stack Overflow;Stack Overflow f...
# NaN       Collectives on Stack Overflow;Stack Overflow f...
# ...                                                     ...
# Yearly                        Stack Overflow;Stack Exchange
# Yearly                                       Stack Overflow
# NaN                           Stack Overflow;Stack Exchange
# Yearly                                       Stack Overflow
# NaN       Collectives on Stack Overflow;Stack Overflow;S...
#
#                      SOVisitFreq                SOAccount  \
# CompFreq
# NaN                          NaN                      NaN
# NaN        Daily or almost daily                      Yes
# Yearly    Multiple times per day                      Yes
# Monthly    Daily or almost daily                      Yes
# NaN       Multiple times per day                      Yes
# ...                          ...                      ...
# Yearly     Daily or almost daily                      Yes
# Yearly     Daily or almost daily  Not sure/can't remember
# NaN       Multiple times per day                      Yes
# Yearly     Daily or almost daily                      Yes
# NaN        Daily or almost daily                      Yes
#
#                                                  SOPartFreq           SOComm  \
# CompFreq
# NaN                                                     NaN              NaN
# NaN                                   Daily or almost daily         Not sure
# Yearly                               Multiple times per day          Neutral
# Monthly                                A few times per week  Yes, definitely
# NaN                                   Daily or almost daily  Yes, definitely
# ...                                                     ...              ...
# Yearly                      A few times per month or weekly  Yes, definitely
# Yearly                                                  NaN          Neutral
# NaN                     Less than once per month or monthly    Yes, somewhat
# Yearly    I have never participated in Q&A on Stack Over...   No, not at all
# NaN                     Less than once per month or monthly    Yes, somewhat
#
#                       Age Gender Trans                Sexuality  \
# CompFreq
# NaN                   NaN    NaN   NaN                      NaN
# NaN                   NaN    NaN   NaN                      NaN
# Yearly    25-34 years old    Man    No                 Bisexual
# Monthly   35-44 years old    Man    No  Straight / Heterosexual
# NaN       25-34 years old    NaN   NaN                      NaN
# ...                   ...    ...   ...                      ...
# Yearly    25-34 years old    Man    No  Straight / Heterosexual
# Yearly    25-34 years old    Man    No  Straight / Heterosexual
# NaN       55-64 years old    Man    No  Straight / Heterosexual
# Yearly    55-64 years old    Man    No  Straight / Heterosexual
# NaN       25-34 years old    Man    No  Straight / Heterosexual
#
#                        Ethnicity      Accessibility  \
# CompFreq
# NaN                          NaN                NaN
# NaN                          NaN                NaN
# Yearly                     White  None of the above
# Monthly                    White  None of the above
# NaN                          NaN                NaN
# ...                          ...                ...
# Yearly                   African  None of the above
# Yearly                     White  None of the above
# NaN                  Multiracial  None of the above
# Yearly                  European  None of the above
# NaN       Or, in your own words:  None of the above
#
#                                                MentalHealth TBranch  \
# CompFreq
# NaN                                                     NaN     NaN
# NaN                                                     NaN      No
# Yearly    I have a mood or emotional disorder (e.g., dep...      No
# Monthly                                   None of the above      No
# NaN                                                     NaN      No
# ...                                                     ...     ...
# Yearly                                    None of the above     Yes
# Yearly                                    None of the above     Yes
# NaN                                       None of the above     Yes
# Yearly                                    None of the above      No
# NaN                                       None of the above     NaN
#
#                            ICorPM  WorkExp Knowledge_1  \
# CompFreq
# NaN                           NaN      NaN         NaN
# NaN                           NaN      NaN         NaN
# Yearly                        NaN      NaN         NaN
# Monthly                       NaN      NaN         NaN
# NaN                           NaN      NaN         NaN
# ...                           ...      ...         ...
# Yearly    Independent contributor      5.0       Agree
# Yearly    Independent contributor      6.0       Agree
# NaN       Independent contributor     42.0    Disagree
# Yearly                        NaN      NaN         NaN
# NaN                           NaN      NaN         NaN
#
#                          Knowledge_2                 Knowledge_3  \
# CompFreq
# NaN                              NaN                         NaN
# NaN                              NaN                         NaN
# Yearly                           NaN                         NaN
# Monthly                          NaN                         NaN
# NaN                              NaN                         NaN
# ...                              ...                         ...
# Yearly                      Disagree              Strongly agree
# Yearly                         Agree  Neither agree nor disagree
# NaN       Neither agree nor disagree                    Disagree
# Yearly                           NaN                         NaN
# NaN                              NaN                         NaN
#
#              Knowledge_4     Knowledge_5     Knowledge_6  \
# CompFreq
# NaN                  NaN             NaN             NaN
# NaN                  NaN             NaN             NaN
# Yearly               NaN             NaN             NaN
# Monthly              NaN             NaN             NaN
# NaN                  NaN             NaN             NaN
# ...                  ...             ...             ...
# Yearly    Strongly agree  Strongly agree  Strongly agree
# Yearly          Disagree        Disagree           Agree
# NaN                Agree           Agree           Agree
# Yearly               NaN             NaN             NaN
# NaN                  NaN             NaN             NaN
#
#                          Knowledge_7       Frequency_1        Frequency_2  \
# CompFreq
# NaN                              NaN               NaN                NaN
# NaN                              NaN               NaN                NaN
# Yearly                           NaN               NaN                NaN
# Monthly                          NaN               NaN                NaN
# NaN                              NaN               NaN                NaN
# ...                              ...               ...                ...
# Yearly    Neither agree nor disagree             Never              Never
# Yearly                         Agree  1-2 times a week  6-10 times a week
# NaN       Neither agree nor disagree             Never              Never
# Yearly                           NaN               NaN                NaN
# NaN                              NaN               NaN                NaN
#
#                Frequency_3        TimeSearching               TimeAnswering  \
# CompFreq
# NaN                    NaN                  NaN                         NaN
# NaN                    NaN                  NaN                         NaN
# Yearly                 NaN                  NaN                         NaN
# Monthly                NaN                  NaN                         NaN
# NaN                    NaN                  NaN                         NaN
# ...                    ...                  ...                         ...
# Yearly               Never  30-60 minutes a day  Less than 15 minutes a day
# Yearly    10+ times a week  15-30 minutes a day        60-120 minutes a day
# NaN                  Never  30-60 minutes a day        60-120 minutes a day
# Yearly                 NaN                  NaN                         NaN
# NaN                    NaN                  NaN                         NaN
#
#           Onboarding                                   ProfessionalTech  \
# CompFreq
# NaN              NaN                                                NaN
# NaN              NaN                                                NaN
# Yearly           NaN                                                NaN
# Monthly          NaN                                                NaN
# NaN              NaN                                                NaN
# ...              ...                                                ...
# Yearly    Just right  DevOps function;Microservices;Developer portal...
# Yearly     Very long                                      None of these
# NaN       Just right                                      None of these
# Yearly           NaN                                                NaN
# NaN              NaN                                                NaN
#
#          TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# CompFreq
# NaN              NaN         NaN         NaN                    NaN
# NaN              NaN         NaN         NaN               Too long
# Yearly           NaN         NaN         NaN  Appropriate in length
# Monthly          NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN               Too long
# ...              ...         ...         ...                    ...
# Yearly           Yes         Yes         Yes               Too long
# Yearly            No         Yes         Yes               Too long
# NaN               No          No          No  Appropriate in length
# Yearly           NaN         NaN         NaN  Appropriate in length
# NaN              NaN         NaN         NaN  Appropriate in length
#
#                           SurveyEase  ConvertedCompYearly
# CompFreq
# NaN                              NaN                  NaN
# NaN                        Difficult                  NaN
# Yearly    Neither easy nor difficult              40205.0
# Monthly                         Easy             215232.0
# NaN                             Easy                  NaN
# ...                              ...                  ...
# Yearly                          Easy                  NaN
# Yearly                          Easy                  NaN
# NaN                             Easy                  NaN
# Yearly                          Easy                  NaN
# NaN                             Easy                  NaN
#
# [73268 rows x 78 columns]

# %%
# To sort by country

df.sort_values(by='Country',ascending=False, inplace =True)
df[['Country','CompTotal']].head(60)
# Out:
#            Country  CompTotal
# CompFreq
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# Weekly    Zimbabwe      200.0
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe     1100.0
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe     1000.0
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe      900.0
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe      300.0
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe      600.0
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# Monthly   Zimbabwe   750000.0
# NaN       Zimbabwe        NaN
# Weekly    Zimbabwe     1500.0
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN       Zimbabwe        NaN
# NaN         Zambia        NaN
# Monthly     Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# Monthly     Zambia     9440.0
# NaN         Zambia        NaN
# Monthly     Zambia     1200.0
# Monthly     Zambia     6200.0
# NaN         Zambia        NaN
# Monthly     Zambia        NaN
# NaN         Zambia        NaN
# Monthly     Zambia        NaN
# NaN         Zambia        NaN
# Monthly     Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# NaN         Zambia        NaN
# NaN          Yemen        NaN
# Yearly       Yemen        NaN
# Monthly      Yemen        NaN
# Monthly      Yemen   500000.0
# Monthly      Yemen      500.0
# Monthly      Yemen     1000.0
# Monthly      Yemen        NaN
# Yearly       Yemen    40000.0
# Monthly      Yemen     1500.0
# NaN          Yemen        NaN

# %%
# Sorting to see the largest and lowest values()
# Sorting by the largest values

df['CompTotal'].nlargest(10)

# %%
# To find the largest values from the whole column

df.nlargest(10,'CompTotal')

# %%
# To get the smallest values (.nsmallest)

df.nsmallest(10, 'CompTotal')
